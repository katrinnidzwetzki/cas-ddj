# %% [markdown]
# # Geodatenhandling 1
#
# **Inhalt:** Etwas mehr als nur erste Schritte mit Geopandas
#
# **Nötige Skills**
# - Basic pandas skills
# - Funktionen und pandas
# - Erste Schritte mit Geopandas
#
# **Lernziele**
# - Koordinatensysteme kennenlernen
# - Koordinaten transformieren
# - Spatial Joins
# - Choropleth maps

# %% [markdown]
# ## Das Beispiel
#
# Coop-Läden in der Schweiz.
# - Liste "gescrapt" von hier: https://www.coop.ch/de/services/standorte-und-oeffnungszeiten.html
# - Siehe File `Coop.ipynb`
#
# Wir wollen diese Läden auf einer Karte als Punkte darstellen und wollen ausserdem auswerten, in welchen Kantonen es wieviele Läden gibt!

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString
# %matplotlib inline

# %% [markdown]
# ## Import

# %% [markdown]
# **Wir verwenden wiederum ein Shapefile der Kantone**

# %%
gdf_kantone = gpd.read_file('dataprojects/Projections/shp/g1k17.shp')

# %%
gdf_kantone.plot()

# %% [markdown]
# **Liste der Coop-Läden**

# %%
df_stores = pd.read_csv('dataprojects/Coop/geschaefte.csv')

# %%
df_stores.head(10)
# Out:
#   hausnummer   latitude  longitude                       name           ort  \
# 0         42  46.837574   8.186167     coop-supermarkt-giswil        Giswil
# 1          2  46.728708   8.181781  coop-supermarkt-meiringen     Meiringen
# 2         32  46.897303   8.251211     coop-supermarkt-sarnen        Sarnen
# 3         32  46.897303   8.251211     coop-restaurant-sarnen        Sarnen
# 4          5  46.820871   8.404397  coop-supermarkt-engelberg     Engelberg
# 5          5  46.820871   8.404397  coop-restaurant-engelberg     Engelberg
# 6        139  46.754612   8.036984     coop-supermarkt-brienz        Brienz
# 7          1  46.937705   8.269723    coop-supermarkt-alpnach  Alpnach-Dorf
# 8        4/6  46.958373   8.368674      coop-supermarkt-stans         Stans
# 9        4/6  46.958373   8.368674      coop-restaurant-stans         Stans
#
#     plz            strasse         typ
# 0  6074      Brünigstrasse      retail
# 1  3860          Alpwegern      retail
# 2  6060       Marktstrasse      retail
# 3  6060       Marktstrasse  restaurant
# 4  6390      Titliszentrum      retail
# 5  6390      Titliszentrum  restaurant
# 6  3855       Hauptstrasse      retail
# 7  6055  Schoriederstrasse      retail
# 8  6370    Buochserstrasse      retail
# 9  6370    Buochserstrasse  restaurant

# %%
df_stores['typ'].value_counts()
# Out:
# retail        923
# pronto        318
# id            183
# restaurant    155
# impo          119
# vitality       78
# bh             73
# christ         66
# city           31
# livique        24
# togo           18
# lumimart       18
# takeit         15
# marche         13
# hotel          10
# capuccini       8
# burger          5
# toptip          4
# sapori          3
# cindy           3
# zopf            3
# karma           2
# halba           2
# perpiedi        1
# Name: typ, dtype: int64

# %% [markdown]
# ## Geometrie

# %% [markdown]
# Wir müssen aus unserer Liste wiederum ein GeoDataFrame erstellen.
#
# Die Schritte dazu sind:
# - Identifizieren, welche Spalte die geografischen Infos enthält
# - Geometrie-Spalte im Dataframe erstellen
# - Aus Dataframe ein GeoDataFrame machen

# %% [markdown]
# **Spalte identifizieren**

# %%
df_stores.columns
# Out:
# Index(['hausnummer', 'latitude', 'longitude', 'name', 'ort', 'plz', 'strasse',
#        'typ'],
#       dtype='object')

# %% [markdown]
# Mehr Infos zum geodetic system: https://gps-coordinates.org/

# %% [markdown]
# **Geometrie erstellen**

# %%
df_stores['Punkt'] = df_stores.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# %%
df_stores.head(10)
# Out:
#   hausnummer   latitude  longitude                       name           ort  \
# 0         42  46.837574   8.186167     coop-supermarkt-giswil        Giswil
# 1          2  46.728708   8.181781  coop-supermarkt-meiringen     Meiringen
# 2         32  46.897303   8.251211     coop-supermarkt-sarnen        Sarnen
# 3         32  46.897303   8.251211     coop-restaurant-sarnen        Sarnen
# 4          5  46.820871   8.404397  coop-supermarkt-engelberg     Engelberg
# 5          5  46.820871   8.404397  coop-restaurant-engelberg     Engelberg
# 6        139  46.754612   8.036984     coop-supermarkt-brienz        Brienz
# 7          1  46.937705   8.269723    coop-supermarkt-alpnach  Alpnach-Dorf
# 8        4/6  46.958373   8.368674      coop-supermarkt-stans         Stans
# 9        4/6  46.958373   8.368674      coop-restaurant-stans         Stans
#
#     plz            strasse         typ                                Punkt
# 0  6074      Brünigstrasse      retail  POINT (8.186166999999999 46.837574)
# 1  3860          Alpwegern      retail  POINT (8.181780999999999 46.728708)
# 2  6060       Marktstrasse      retail           POINT (8.251211 46.897303)
# 3  6060       Marktstrasse  restaurant           POINT (8.251211 46.897303)
# 4  6390      Titliszentrum      retail  POINT (8.404396999999999 46.820871)
# 5  6390      Titliszentrum  restaurant  POINT (8.404396999999999 46.820871)
# 6  3855       Hauptstrasse      retail           POINT (8.036984 46.754612)
# 7  6055  Schoriederstrasse      retail  POINT (8.269722999999999 46.937705)
# 8  6370    Buochserstrasse      retail   POINT (8.368674 46.95837299999999)
# 9  6370    Buochserstrasse  restaurant   POINT (8.368674 46.95837299999999)

# %% [markdown]
# **Geodataframe kreieren**

# %%
gdf_stores = gpd.GeoDataFrame(df_stores, geometry='Punkt')

# %%
gdf_stores.head(2)
# Out:
#   hausnummer   latitude  longitude                       name        ort  \
# 0         42  46.837574   8.186167     coop-supermarkt-giswil     Giswil
# 1          2  46.728708   8.181781  coop-supermarkt-meiringen  Meiringen
#
#     plz        strasse     typ                     Punkt
# 0  6074  Brünigstrasse  retail  POINT (8.18617 46.83757)
# 1  3860      Alpwegern  retail  POINT (8.18178 46.72871)

# %% [markdown]
# Hat es funktioniert?

# %%
gdf_stores.plot()

# %% [markdown]
# ## Koordinaten transformieren

# %% [markdown]
# Machen wir nun dasselbe wie im vorherigen Notebook: Plotten wir die Coop-Standorte auf die Schweizer Karte!

# %%
ax = gdf_kantone.plot(figsize=(14,10), color='lightgrey', edgecolor='white')
gdf_stores.plot(markersize=3, ax=ax)

# %% [markdown]
# Das Problem ist: die beiden Geodataframes verwenden verschiedene Koordinatensysteme!
#
# Das Koordinatensystem in Geodataframes ist in der Property `crs` gespeichert.

# %% [markdown]
# **Kantone: Schweizer Koordinatensystem**
# siehe: https://de.wikipedia.org/wiki/Schweizer_Landeskoordinaten

# %%
gdf_kantone.crs     ##coordinate reference system
# Out:
# {'init': 'epsg:21781'}

# %% [markdown]
# **Geschäfte: Haben noch keines!**

# %%
gdf_stores.crs

# %% [markdown]
# Allerdings wissen wir, dass die Koordinaten im world geodetic system kodiert sind. Um dies Geopandas mitzuteilen, müssen wir das Geodataframe mit einem bestimmten Code initiatilisieren:

# %%
gdf_stores.crs = {'init': 'epsg:4326'}   ### epsg: european petroleum survey group

# %%
gdf_stores.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# **EPSG-Codes**
#
# EPSG steht für European Petroleum Survey Group:
# - https://epsg.io/
#
# Jedes Koordinatensystem hat eine Nummer
# - https://de.wikipedia.org/wiki/European_Petroleum_Survey_Group_Geodesy#EPSG-Codes
#
# Ein paar gängige Nummern

# %% [markdown]
# | Code | Description |
# |------|---------------------------|
# | 4326 | #world geodetic system |
# | 3857 | #mercator |
# | 2163 | #nice aea projection for the USA |
# | 5071 | #another good one for the USA |
# | 3395 | #mercator (anotherone) |
# | 21781 | #swiss coordinate system |

# %% [markdown]
# Wir wollen das Schweizer Koordinatensystem verwenden. Um die Koordinaten zu transformieren, verwenden wir `to_crs()`:

# %%
gdf_stores = gdf_stores.to_crs(epsg=21781)
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# Jetzt sind beide Geodataframes im selben Koordinatensystem kodiert und wir können sie auf einer Karte plotten

# %%
gdf_stores
# Out:
#      hausnummer   latitude  longitude  \
# 0            42  46.837574   8.186167
# 1             2  46.728708   8.181781
# 2            32  46.897303   8.251211
# 3            32  46.897303   8.251211
# 4             5  46.820871   8.404397
# 5             5  46.820871   8.404397
# 6           139  46.754612   8.036984
# 7             1  46.937705   8.269723
# 8           4/6  46.958373   8.368674
# 9           4/6  46.958373   8.368674
# 10          101  46.624278   8.035829
# 11          101  46.624237   8.035162
# 12            2  46.981689   8.310388
# 13          NaN  46.975536   8.341713
# 14            5  46.964964   8.381035
# 15            2  46.985953   8.311483
# 16           15  46.945754   8.008060
# 17            9  46.947124   8.009205
# 18            6  46.979175   8.415774
# 19            1  46.993344   8.065780
# 20           19  47.017518   8.299724
# 21           19  47.017518   8.299724
# 22           19  47.017536   8.299725
# 23           19  47.017536   8.299725
# 24           19  47.017525   8.300001
# 25           19  47.017674   8.299372
# 26           19  47.018040   8.298509
# 27           15  47.017850   8.302189
# 28          100  47.019457   8.311015
# 29           12  47.026556   8.298869
# ...         ...        ...        ...
# 2045          1  46.182092   6.135086
# 2046        100  46.206287   6.115990
# 2047         89  46.210884   6.112068
# 2048         10  46.179936   6.128338
# 2049         10  46.179942   6.128079
# 2050         10  46.179942   6.128079
# 2051          3  46.190133   6.119375
# 2052          1  46.181904   6.120429
# 2053        171  46.221562   6.096021
# 2054        171  46.221838   6.095742
# 2055        171  46.221838   6.095742
# 2056         15  46.175689   6.120605
# 2057        2-4  46.169199   6.121098
# 2058         24  46.232397   6.082634
# 2059         24  46.232134   6.082433
# 2060         24  46.232132   6.082342
# 2061         24  46.232105   6.082330
# 2062         24  46.232050   6.082240
# 2063         13  46.227157   6.084553
# 2064          8  46.203534   6.096115
# 2065         14  46.187908   6.105387
# 2066         21  46.187701   6.104576
# 2067         21  46.187736   6.104549
# 2068         21  46.187718   6.104549
# 2069         21  46.187552   6.104165
# 2070         26  46.214595   6.082843
# 2071          1  46.228370   6.072493
# 2072         1A  46.156062   6.096533
# 2073         16  46.174747   6.083563
# 2074        319  46.174172   6.070937
#
#                                           name              ort   plz  \
# 0                       coop-supermarkt-giswil           Giswil  6074
# 1                    coop-supermarkt-meiringen        Meiringen  3860
# 2                       coop-supermarkt-sarnen           Sarnen  6060
# 3                       coop-restaurant-sarnen           Sarnen  6060
# 4                    coop-supermarkt-engelberg        Engelberg  6390
# 5                    coop-restaurant-engelberg        Engelberg  6390
# 6                       coop-supermarkt-brienz           Brienz  3855
# 7                      coop-supermarkt-alpnach     Alpnach-Dorf  6055
# 8                        coop-supermarkt-stans            Stans  6370
# 9                        coop-restaurant-stans            Stans  6370
# 10                 coop-supermarkt-grindelwald      Grindelwald  3818
# 11                   coop-vitality-grindelwald      Grindelwald  3818
# 12    coop-supermarkt-hergiswil-bahnhofstrasse        Hergiswil  6052
# 13                   coop-supermarkt-stansstad        Stansstad  6362
# 14                    coop-bau-hobby-b-h-stans            Stans  6370
# 15           coop-supermarkt-hergiswil-landweg        Hergiswil  6052
# 16                          pronto-schuepfheim       Schüpfheim  6170
# 17                 coop-supermarkt-schuepfheim       Schüpfheim  6170
# 18                      coop-supermarkt-buochs           Buochs  6374
# 19                   coop-supermarkt-entlebuch        Entlebuch  6162
# 20         coop-supermarkt-kriens-pilatusmarkt           Kriens  6010
# 21         coop-restaurant-kriens-pilatusmarkt           Kriens  6010
# 22           coop-vitality-kriens-pilatusmarkt           Kriens  6010
# 23           christ-kriens-pilatusmarkt-christ           Kriens  6010
# 24                 impo-kriens-pilatusmarkt-ip           Kriens  6010
# 25          coop-city-city-kriens-pilatusmarkt           Kriens  6010
# 26                   coop-bau-hobby-b-h-kriens           Kriens  6010
# 27                  pronto-kriens-pilatusmarkt           Kriens  6010
# 28                        coop-supermarkt-horw             Horw  6048
# 29                             lumimart-kriens           Kriens  6010
# ...                                        ...              ...   ...
# 2045                    livique-geneve-carouge          Carouge  1227
# 2046             coop-supermarkt-geneve-sports           Genève  1203
# 2047                coop-supermarkt-chatelaine          Vernier  1214
# 2048          christ-carouge-la-praille-christ          Carouge  1227
# 2049        coop-supermarkt-carouge-la-praille          Carouge  1227
# 2050        coop-restaurant-carouge-la-praille          Carouge  1227
# 2051               coop-supermarkt-petit-lancy      Petit-Lancy  1213
# 2052               coop-supermarkt-grand-lancy      Grand-Lancy  1212
# 2053          interdiscount-vernier-blandonnet          Vernier  1214
# 2054        coop-supermarkt-vernier-blandonnet          Vernier  1214
# 2055                   coop-restaurant-vernier          Vernier  1214
# 2056      coop-supermarkt-grand-lancy-palettes      Grand-Lancy  1212
# 2057           coop-supermarkt-plan-les-ouates  Plan-Les-Ouates  1228
# 2058                      interdiscount-meyrin           Meyrin  1217
# 2059          impo-meyrin-centre-commercial-ip           Meyrin  1217
# 2060                      christ-meyrin-christ           Meyrin  1217
# 2061          coop-supermarkt-city-meyrin-food           Meyrin  1217
# 2062                     coop-city-city-meyrin           Meyrin  1217
# 2063                           lumimart-meyrin           Meyrin  1217
# 2064                 coop-supermarkt-le-lignon        Le Lignon  1219
# 2065                   coop-bau-hobby-b-l-onex             Onex  1213
# 2066                      coop-restaurant-onex             Onex  1213
# 2067                              impo-onex-ip             Onex  1213
# 2068               coop-vitality-onex-vitality             Onex  1213
# 2069                      coop-supermarkt-onex             Onex  1213
# 2070                   coop-supermarkt-vernier          Vernier  1214
# 2071           coop-supermarkt-meyrin-verchere           Meyrin  1217
# 2072                              pronto-perly    Perly-Certoux  1258
# 2073                 coop-supermarkt-confignon        Confignon  1232
# 2074                    coop-supermarkt-bernex           Bernex  1233
#
#                       strasse         typ                          Punkt
# 0               Brünigstrasse      retail  POINT (657026.097 187652.432)
# 1                   Alpwegern      retail  POINT (656806.082 175547.388)
# 2                Marktstrasse      retail  POINT (661919.122 194341.411)
# 3                Marktstrasse  restaurant  POINT (661919.122 194341.411)
# 4               Titliszentrum      retail  POINT (673696.041 185977.417)
# 5               Titliszentrum  restaurant  POINT (673696.041 185977.417)
# 6                Hauptstrasse      retail  POINT (645716.079 178332.427)
# 7           Schoriederstrasse      retail  POINT (663282.145 198847.423)
# 8             Buochserstrasse      retail  POINT (670789.061 201229.466)
# 9             Buochserstrasse  restaurant  POINT (670789.061 201229.466)
# 10                Dorfstrasse      retail  POINT (645738.020 163843.358)
# 11                Dorfstrasse    vitality  POINT (645686.971 163838.412)
# 12             Bahnhofstrasse      retail  POINT (666324.089 203770.450)
# 13              Schützenmatte      retail  POINT (668715.094 203113.404)
# 14                     Rieden          bh  POINT (671721.061 201973.364)
# 15                    Landweg      retail  POINT (666402.123 204245.381)
# 16              Hindervormüli      pronto  POINT (643352.146 199564.502)
# 17              Hindervormüli      retail  POINT (643438.210 199717.435)
# 18                   Nähseydi      retail  POINT (674345.050 203585.426)
# 19              Wilgutstrasse      retail  POINT (647704.190 204888.446)
# 20                Ringstrasse      retail  POINT (665469.097 207744.426)
# 21                Ringstrasse  restaurant  POINT (665469.097 207744.426)
# 22                Ringstrasse    vitality  POINT (665469.151 207746.428)
# 23                Ringstrasse      christ  POINT (665469.151 207746.428)
# 24                Ringstrasse        impo  POINT (665490.148 207745.435)
# 25                Ringstrasse        city  POINT (665442.146 207761.474)
# 26                Ringstrasse          bh  POINT (665376.089 207801.442)
# 27                Ringstrasse      pronto  POINT (665656.098 207783.392)
# 28             Kantonsstrasse      retail  POINT (666325.124 207969.455)
# 29             Nidfeldstrasse    lumimart  POINT (665393.082 208748.427)
# ...                       ...         ...                            ...
# 2045            Rue Blavignac     livique  POINT (499348.566 115351.920)
# 2046            Avenue d'Aïre      retail  POINT (497919.658 118065.900)
# 2047     Av. de la Châtelaine      retail  POINT (497625.646 118581.972)
# 2048         Route des Jeunes      christ  POINT (498823.575 115120.973)
# 2049         Route des Jeunes      retail  POINT (498803.589 115121.974)
# 2050         Route des Jeunes  restaurant  POINT (498803.589 115121.974)
# 2051        Place des Ormeaux      retail  POINT (498150.643 116265.982)
# 2052        Place du 1er Août      retail  POINT (498216.614 115349.961)
# 2053          Route du Meyrin          id  POINT (496407.733 119789.917)
# 2054          Route de Meyrin      retail  POINT (496386.734 119820.963)
# 2055          Route de Meyrin  restaurant  POINT (496386.734 119820.963)
# 2056      Chemin des Palettes      retail  POINT (498218.579 114658.936)
# 2057           Chemin de Vers      retail  POINT (498244.513 113936.932)
# 2058     Avenue de Feuillasse          id  POINT (495395.788 121012.002)
# 2059     Avenue de Feuillasse        impo  POINT (495379.778 120983.038)
# 2060        Centre Commercial      christ  POINT (495372.755 120982.937)
# 2061     Avenue de Feuillasse      retail  POINT (495371.777 120979.952)
# 2062     Avenue de Feuillasse        city  POINT (495364.729 120973.959)
# 2063       Chemin Riantbosson    lumimart  POINT (495533.739 120427.022)
# 2064          Place du Lignon      retail  POINT (496380.645 117785.997)
# 2065     Avenue du Gros Chêne          bh  POINT (497066.648 116036.956)
# 2066          Rue des Bossons  restaurant  POINT (497003.649 116015.014)
# 2067          Rue des Bossons        impo  POINT (497001.631 116018.939)
# 2068          rue des Bossons    vitality  POINT (497001.597 116016.939)
# 2069          Rue des Bossons      retail  POINT (496971.639 115998.993)
# 2070           Rue du Village      retail  POINT (495377.664 119033.053)
# 2071  Chemin Antoine Verchère      retail  POINT (494605.774 120577.997)
# 2072    Chemin de Champ-Budin      pronto  POINT (496322.505 112508.966)
# 2073        Place de l'Eglise      retail  POINT (495356.605 114603.032)
# 2074            Rue de Bernex      retail  POINT (494380.573 114556.064)
#
# [2075 rows x 9 columns]

# %%
ax = gdf_kantone.plot(figsize=(14,10), color='lightgrey', edgecolor='white')
gdf_stores.plot(markersize=3, ax=ax)

# %% [markdown]
# **Zusatzaufgabe:** Plotten Sie die verschiedenen Geschäftstypen je in eigenen Farben!

# %%
colors = {
    'retail': 'blue',
    'pronto': 'green',
    'id': 'orange',
    'restaurant': 'red',
    'impo': 'darkblue',
    'vitality': 'darkgreen',
    'bh': 'black',
    'christ': 'black',
    'city': 'black',
    'livique': 'black',
    'togo': 'black',
    'lumimart': 'black',
    'takeit': 'black',
    'marche': 'black',
    'hotel': 'black',
    'capuccini': 'black',
    'burger': 'black',
    'toptip': 'black',
    'cindy': 'black',
    'sapori': 'black',
    'zopf': 'black',
    'karma': 'black',
    'halba': 'black',
    'perpiedi': 'black'
}

# %%
colorlist = gdf_stores['typ'].apply(lambda typ: colors[typ])

# %%
colorlist.value_counts(dropna=False)
# Out:
# blue         923
# green        318
# black        299
# orange       183
# red          155
# darkblue     119
# darkgreen     78
# Name: typ, dtype: int64

# %%
ax = gdf_kantone.plot(figsize=(14,10), color='lightgrey', edgecolor='white')
gdf_stores.plot(markersize=3, ax=ax, color=colorlist, alpha=0.6)

# %% [markdown]
# ## Geo-Selektion
#
# Was könnten wir nun mit diesen beiden Datensets anfangen, die im selben System kodiert sind (ausser sie zu plotten)?
#
# Zum Beispiel:
# - Einzelne Geschäfte selektieren (je nach Kanton)
# - Gschäfte pro Kanton zählen

# %% [markdown]
# ### spatial joins

# %% [markdown]
# Ähnlich wie `merge()` in Pandas bietet auch Geopandas eine Funktion an, um zwei Datensets zu kombinieren: `sjoin()`

# %%
gdf_merged = gpd.sjoin(gdf_stores, gdf_kantone, how='left', op='within')
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/geopandas/tools/sjoin.py:61: UserWarning: CRS of frames being joined does not match!({'init': 'epsg:21781', 'no_defs': True} != {'init': 'epsg:21781'})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# /home/pc/anaconda3/lib/python3.7/site-packages/geopandas/base.py:105: UserWarning: Cannot generate spatial index: Missing package `rtree`.
#   warn("Cannot generate spatial index: Missing package `rtree`.")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-13ca53bf2e2d> in <module>
# ----> 1 gdf_merged = gpd.sjoin(gdf_stores, gdf_kantone, how='left', op='within')
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/tools/sjoin.py in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#     107     if tree_idx_right:
#     108         idxmatch = left_df.geometry.apply(lambda x: x.bounds).apply(
# --> 109             lambda x: list(tree_idx.intersection(x)) if not x == () else []
#     110         )
#     111         idxmatch = idxmatch[idxmatch.apply(len) > 0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/tools/sjoin.py in <lambda>(x)
#     107     if tree_idx_right:
#     108         idxmatch = left_df.geometry.apply(lambda x: x.bounds).apply(
# --> 109             lambda x: list(tree_idx.intersection(x)) if not x == () else []
#     110         )
#     111         idxmatch = idxmatch[idxmatch.apply(len) > 0]
#
# AttributeError: 'NoneType' object has no attribute 'intersection'

# %% [markdown]
# Wir wählen hier zu jeder Zeile aus dem ersten GDF (gdf_stores, also die Geschäfte) die passende Zeile aus dem anderen GDF (gdf_kantone, also den passenden Kanton) aus.
#
# `how=` gibt wie in pandas an, wie wir matchen wollen:
# - "left"
# - "right"
# - "inner"
# - "outer"
#
# `op=` gibt die geometrische matching-methode an:
# - "contains" (linke geometrie enthält rechte geometrie)
# - "within" (linke geometrie ist innnerhalb rechter geometrie)
# - "intersects" (linke geometrie überschneidet sich mit rechter geometrie)

# %% [markdown]
# In unserem Fall haben wir also gesagt:
# - suche zu jedem store-punkt das passende kantons-polygon
# - wobei der punkt innerhalb des polygons liegen muss
#
# Nun haben wir ein zusammengeführtes, ziemlich breites geodataframe:

# %%
gdf_merged.columns
# Out:
# Index(['hausnummer', 'latitude', 'longitude', 'name', 'ort', 'plz', 'strasse',
#        'typ', 'Punkt', 'index_right', 'KTNR', 'KTNAME', 'GRNR', 'AREA_HA',
#        'X_MIN', 'X_MAX', 'Y_MIN', 'Y_MAX', 'X_CNTR', 'Y_CNTR', 'Z_MIN',
#        'Z_MAX', 'Z_AVG', 'Z_MED', 'E_MIN', 'E_MAX', 'N_MIN', 'N_MAX', 'E_CNTR',
#        'N_CNTR'],
#       dtype='object')

# %% [markdown]
# Und das Gute ist: zu jeder Coop-Filiale ist nun die Information enthalten, in welchem Kanton sie liegt.

# %%
gdf_merged['KTNAME']
# Out:
# 0           Obwalden
# 1       Bern / Berne
# 2           Obwalden
# 3           Obwalden
# 4           Obwalden
# 5           Obwalden
# 6       Bern / Berne
# 7           Obwalden
# 8          Nidwalden
# 9          Nidwalden
# 10      Bern / Berne
# 11      Bern / Berne
# 12         Nidwalden
# 13         Nidwalden
# 14         Nidwalden
# 15         Nidwalden
# 16            Luzern
# 17            Luzern
# 18         Nidwalden
# 19            Luzern
# 20            Luzern
# 21            Luzern
# 22            Luzern
# 23            Luzern
# 24            Luzern
# 25            Luzern
# 26            Luzern
# 27            Luzern
# 28            Luzern
# 29            Luzern
#             ...
# 2045          Genève
# 2046          Genève
# 2047          Genève
# 2048          Genève
# 2049          Genève
# 2050          Genève
# 2051          Genève
# 2052          Genève
# 2053          Genève
# 2054          Genève
# 2055          Genève
# 2056          Genève
# 2057          Genève
# 2058          Genève
# 2059          Genève
# 2060          Genève
# 2061          Genève
# 2062          Genève
# 2063          Genève
# 2064          Genève
# 2065          Genève
# 2066          Genève
# 2067          Genève
# 2068          Genève
# 2069          Genève
# 2070          Genève
# 2071          Genève
# 2072          Genève
# 2073          Genève
# 2074          Genève
# Name: KTNAME, Length: 2075, dtype: object

# %% [markdown]
# Das ermöglicht uns zB, nur Stores aus einem einzelnen Kanton zu bearbeiten:

# %%
ax = gdf_kantone[gdf_kantone['KTNAME'] == 'Zürich'].plot(color='lightgrey', edgecolor='white', figsize=(6,8))
gdf_merged[gdf_merged['KTNAME'] == 'Zürich'].plot(markersize=3, alpha=0.6, ax=ax)

# %% [markdown]
# ## Geo-Information darstellen

# %% [markdown]
# Wie viele Läden sind in welchem Kanton? Diese Frage können wir nun beantworten:

# %%
gdf_merged['KTNAME'].value_counts()
# Out:
# Zürich                              354
# Bern / Berne                        295
# Vaud                                167
# Aargau                              163
# St. Gallen                          116
# Valais / Wallis                      98
# Ticino                               89
# Luzern                               85
# Genève                               84
# Solothurn                            73
# Graubünden / Grigioni / Grischun     71
# Basel-Landschaft                     71
# Basel-Stadt                          71
# Thurgau                              69
# Fribourg / Freiburg                  64
# Neuchâtel                            47
# Zug                                  34
# Schwyz                               33
# Jura                                 21
# Schaffhausen                         20
# Glarus                               12
# Uri                                  10
# Nidwalden                             7
# Obwalden                              6
# Appenzell Ausserrhoden                5
# Appenzell Innerrhoden                 1
# Name: KTNAME, dtype: int64

# %% [markdown]
# Um diese Information wiederum geografisch darzustellen, können wir sie zurück in unser Kantone-GDF mergen.

# %% [markdown]
# **Vorbereitung:**

# %%
df_anzahl = gdf_merged['KTNAME'].value_counts().to_frame()

# %%
df_anzahl = df_anzahl.rename(columns={'KTNAME': 'Anzahl'})

# %%
df_anzahl.head(5)
# Out:
#               Anzahl
# Zürich           354
# Bern / Berne     295
# Vaud             167
# Aargau           163
# St. Gallen       116

# %% [markdown]
# **Merge:**

# %%
gdf_kantone_anzahl = gdf_kantone.merge(df_anzahl, how='inner', left_on='KTNAME', right_index=True)

# %%
gdf_kantone_anzahl.head(2)
# Out:
#    KTNR        KTNAME  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN   Y_MAX  X_CNTR  \
# 0     1        Zürich     4   172894  669244  716900  223896  283343  691800
# 1     2  Bern / Berne     2   595952  556241  677745  130585  243834  614200
#
#    Y_CNTR   ...    Z_AVG  Z_MED    E_MIN    E_MAX    N_MIN    N_MAX   E_CNTR  \
# 0  252000   ...      533    504  2669244  2716900  1223896  1283343  2691800
# 1  185600   ...     1198    979  2556241  2677745  1130585  1243834  2614200
#
#     N_CNTR                                           geometry  Anzahl
# 0  1252000  POLYGON ((692429.2019999996 281173.7069999985,...     354
# 1  1185600  (POLYGON ((573502.2039999999 194804.7199999988...     295
#
# [2 rows x 22 columns]

# %% [markdown]
# **Plot:**
#
# Siehe auch: http://geopandas.org/mapping.html
#
# Wir können Geopandas in der `plot()`-Funktion angeben, wie die Farbcodierung erstellt werden soll.
#
# - `column=` - welche Spalte verwendet werden soll: in unserem Fall, "Anzahl"
# - `cmap=` - welche Colormap werwendet werden soll: https://matplotlib.org/examples/color/colormaps_reference.html
# - `scheme=` - kann "equal_interval" oder "quantiles" sein. Standardzahl der Schritte ist 5.

# %%
ax = gdf_kantone_anzahl.plot(column='Anzahl', cmap='Blues', scheme='quantiles', edgecolor='white', legend=True, figsize=(12,12))
ax.set_title('Anzahl Coop-Filialen pro Kanton')
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Anzahl Coop-Filialen pro Kanton')
