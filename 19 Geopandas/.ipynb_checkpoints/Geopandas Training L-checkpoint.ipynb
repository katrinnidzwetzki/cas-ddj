# %% [markdown]
# # Geopandas Training

# %% [markdown]
# **Inhalt:**
# - Geodaten laden
# - Koordinaten transformieren
# - Einfache Datenanalyse mit Denkmalgeschützten Objekten
# - Food deserts mit Schweizer Daten replizieren
#
# **Nötige Skills**
# - Geodatenhandling 1 und 2

# %% [markdown]
# ## Setup

# %% [markdown]
# Importieren Sie die nötigen Libraries: pandas, geopandas, shapely-geometrien

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString, Polygon
# %matplotlib inline

# %% [markdown]
# ## Import

# %% [markdown]
# **Schweizer Gemeinden**

# %% [markdown]
# Ein shapefile mit den Schweizer Gemeinden ist unter folgendem Pfad abgelegt:
# `'dataprojects/Projections/shp/g1g17.shp'`
#
# Lesen Sie es ein, zeigen Sie die ersten Zeilen an und machen Sie einen einfachen Plot

# %%
gdf_gem = gpd.read_file('dataprojects/Projections/shp/g1g17.shp')

# %%
gdf_gem.head(2)
# Out:
#    GMDNR          GMDNAME  BZNR  KTNR  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN  \
# 0      1  Aeugst am Albis   101     1     4      791  678110  681154  234561
# 1     10         Obfelden   101     1     4      754  672793  676118  232987
#
#     Y_MAX  ...  Z_AVG  Z_MED  Z_CNTR    E_MIN    E_MAX    N_MIN    N_MAX  \
# 0  238544  ...    684    673     699  2678110  2681154  1234561  1238544
# 1  237091  ...    439    439     452  2672793  2676118  1232987  1237091
#
#     E_CNTR   N_CNTR                                           geometry
# 0  2679300  1235700  POLYGON ((680805.251 237763.620, 681154.070 23...
# 1  2675100  1235300  POLYGON ((676118.253 235522.704, 675847.098 23...
#
# [2 rows x 24 columns]

# %%
gdf_gem.plot()

# %% [markdown]
# **Denkmalschutz**

# %% [markdown]
# Ein Shapefile aller Denkmalgeschützten Objekte im Kanton Zürich ist unter folgendem Pfad abgelegt:
# `dataprojects/Denkmalschutz/Denkmalschutzobjekte/ARV_KAZ_DENKMALSCHUTZOBJEKTE_P.shp`
#
# Lesen Sie es ein, zeigen Sie die ersten Zeilen an und machen Sie einen einfachen Plot

# %%
gdf_ds = gpd.read_file('dataprojects/Denkmalschutz/Denkmalschutzobjekte/ARV_KAZ_DENKMALSCHUTZOBJEKTE_P.shp')

# %%
gdf_ds.head(2)
# Out:
#          GEMEINDE             ORT   PLZ         STRASSE  \
# 0  Niederweningen  Niederweningen  8166         Steig 4
# 1  Niederweningen  Niederweningen  8166  Dorfstrasse 61
#
#                             ENSEMBLE                      OBJEKT    GVZ_NR  \
# 0  Niederweningen: Bauernhaus, ehem.                  Hausteil 2  09100140
# 1                               None  Speicher, ehem. mit Trotte  09100133
#
#   BAUJAHR EINSTUFUNG FESTSETZUN ERLASS SCHUTZ GRUNDBUCHE           OST  \
# 0    1760          -       None   None     PD   19790809  2.670068e+06
# 1    1885          -       None   None     PD   19890313  2.670151e+06
#
#            NORD                         geometry
# 0  1.261839e+06  POINT (2670067.991 1261838.998)
# 1  1.261830e+06  POINT (2670150.991 1261829.997)

# %%
gdf_ds.plot()

# %% [markdown]
# Wie viele denkmalgeschützte Objekte gibt es im Kanton Zürich?

# %%
len(gdf_ds)
# Out:
# 6566

# %% [markdown]
# In welchem Koordinatensystem sind die Geodaten codiert?

# %%
gdf_ds.crs
# Out:
# {'init': 'epsg:2056'}

# %% [markdown]
# Transformieren Sie die Daten ins Schweizer Koordinatensystem

# %%
gdf_ds = gdf_ds.to_crs(epsg=21781)
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ## Ein einfacher Plot

# %% [markdown]
# Welche Kantonsnummer haben die Gemeinden aus dem Kanton Zürich im Gemeinde-Geodatenfile?

# %%
gdf_gem[gdf_gem['GMDNAME'] == 'Zürich']
# Out:
#      GMDNR GMDNAME  BZNR  KTNR  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN   Y_MAX  \
# 497    261  Zürich   112     1     4     8793  676224  689665  241584  254306
#
#      ...  Z_AVG  Z_MED  Z_CNTR    E_MIN    E_MAX    N_MIN    N_MAX   E_CNTR  \
# 497  ...    483    453     409  2676224  2689665  1241584  1254306  2683100
#
#       N_CNTR                                           geometry
# 497  1247100  POLYGON ((684249.637 253917.051, 684430.504 25...
#
# [1 rows x 24 columns]

# %% [markdown]
# Filtern Sie die Zürcher Gemeinden heraus und speichern Sie diese in einem neuen GDF

# %%
gdf_zh = gdf_gem[gdf_gem['KTNR'] == 1]

# %% [markdown]
# Plotten Sie das Zürcher Gemeinde-GDF zusammen mit den denkmalgeschützten Objekten

# %%
ax = gdf_zh.plot(figsize=(15,15), color='lightgrey', linewidth=0.25, edgecolor='white')
gdf_ds.plot(ax=ax, color='red', markersize=8, alpha = 0.8)

# %% [markdown]
# ## Analyse: Denkmalschutz
#
# Uns interessiert: In welcher Gemeinde gibt es wieviele denkmalgeschützte Objekte?

# %% [markdown]
# ### Daten kombinieren 1

# %% [markdown]
# Fügen Sie jeder Zeile im Denkmalschutz-GDF die passende Geoinformation aus dem Gemeinden-GDF hinzu.
#
# **Tipp:** Sie brauchen dazu einen Spatial Join.
#
# Speichern Sie die kombinierten Infos in einem neuen GDF.

# %%
gdf_ds_gem = gpd.sjoin(gdf_ds, gdf_zh, how='left', op='within')
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/geopandas/tools/sjoin.py:61: UserWarning: CRS of frames being joined does not match!({'init': 'epsg:21781', 'no_defs': True} != {'init': 'epsg:21781'})
#   "(%s != %s)" % (left_df.crs, right_df.crs)

# %% [markdown]
# Checken Sie annhand der ersten zwei Objekte, ob es funktioniert hat

# %%
gdf_ds_gem.head(2)
# Out:
#          GEMEINDE             ORT   PLZ         STRASSE  \
# 0  Niederweningen  Niederweningen  8166         Steig 4
# 1  Niederweningen  Niederweningen  8166  Dorfstrasse 61
#
#                             ENSEMBLE                      OBJEKT    GVZ_NR  \
# 0  Niederweningen: Bauernhaus, ehem.                  Hausteil 2  09100140
# 1                               None  Speicher, ehem. mit Trotte  09100133
#
#   BAUJAHR EINSTUFUNG FESTSETZUN  ...  Z_MAX  Z_AVG  Z_MED  Z_CNTR      E_MIN  \
# 0    1760          -       None  ...  859.0  555.0  538.0   457.0  2669244.0
# 1    1885          -       None  ...  859.0  555.0  538.0   457.0  2669244.0
#
#        E_MAX      N_MIN      N_MAX     E_CNTR     N_CNTR
# 0  2671807.0  1259309.0  1264668.0  2670700.0  1262000.0
# 1  2671807.0  1259309.0  1264668.0  2670700.0  1262000.0
#
# [2 rows x 40 columns]

# %% [markdown]
# Gibt es Objekte, denen keine Gemeinde zugewiesen wurde? Wenn ja, warum nicht?

# %%
gdf_ds_gem[gdf_ds_gem['GMDNAME'].isnull()]
# Out:
#              GEMEINDE          ORT         PLZ  \
# 92        Glattfelden         None        8192
# 279     Küsnacht (ZH)     Küsnacht        8700
# 291     Küsnacht (ZH)     Küsnacht        8700
# 311    Erlenbach (ZH)    Erlenbach        8703
# 347            Horgen       Horgen        8810
# 405       Feuerthalen  Feuerthalen        8245
# 406       Feuerthalen  Feuerthalen        8245
# 510         Männedorf    Männedorf        8708
# 523         Männedorf    Männedorf        8708
# 643             Stäfa        Stäfa        8712
# 644             Stäfa        Stäfa        8712
# 699             Stäfa      Uerikon        8713
# 822              Elgg         None        8355
# 988            Zürich       Zürich        8001
# 1013           Zürich       Zürich        8002
# 1035   Kilchberg (ZH)    Kilchberg        8802
# 1070          Thalwil      Thalwil        8800
# 1077    Küsnacht (ZH)     Küsnacht        8700
# 1079    Küsnacht (ZH)     Küsnacht        8700
# 1091   Erlenbach (ZH)    Erlenbach        8703
# 1110       Herrliberg   Herrliberg        8704
# 1136           Meilen       Meilen        8706
# 1175      Feuerthalen  Feuerthalen        8245
# 1177      Feuerthalen         None        None
# 1178        Wädenswil           Au        8804
# 1179        Wädenswil           Au        8804
# 1182           Meilen       Meilen        8706
# 1210           Meilen       Meilen        8706
# 1233        Wädenswil    Wädenswil        8820
# 1235        Wädenswil    Wädenswil        8820
# ...               ...          ...         ...
# 5342  Laufen-Uhwiesen     Uhwiesen        8248
# 5363        Wädenswil    Wädenswil        8820
# 5374        Männedorf    Männedorf        8708
# 5419            Stäfa        Stäfa        8712
# 5510            Stäfa        Stäfa        8712
# 5577    Hombrechtikon     Feldbach        8714
# 5677             Elgg         None        8355
# 5748      Maschwanden  Maschwanden        8933
# 5756      Maschwanden         None        8933
# 5881           Zürich       Zürich        8001
# 5890          Eglisau         None        8193
# 5902           Zürich       Zürich        8002
# 5956          Thalwil      Thalwil        8800
# 5957          Thalwil      Thalwil        8800
# 5966         Zollikon     Zollikon        8702
# 5976    Küsnacht (ZH)     Küsnacht        8700
# 5977    Küsnacht (ZH)     Küsnacht        8700
# 5992   Erlenbach (ZH)    Erlenbach        8703
# 6001       Herrliberg   Herrliberg        8704
# 6093           Meilen       Meilen        8706
# 6121           Meilen       Meilen        8706
# 6152        Wädenswil    Wädenswil        8820
# 6154        Wädenswil    Wädenswil        8820
ional       None  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6154          -       None  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6155          -       None  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6180   regional       None  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6195   kantonal   19791219  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6418   regional   19791219  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6441   regional   19921228  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6482   regional       None  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
# 6565   regional   19791219  ...   NaN   NaN   NaN     NaN    NaN   NaN    NaN
#
#       N_MAX E_CNTR  N_CNTR
# 92      NaN    NaN     NaN
# 279     NaN    NaN     NaN
# 291     NaN    NaN     NaN
# 311     NaN    NaN     NaN
# 347     NaN    NaN     NaN
# 405     NaN    NaN     NaN
# 406     NaN    NaN     NaN
# 510     NaN    NaN     NaN
# 523     NaN    NaN     NaN
# 643     NaN    NaN     NaN
# 644     NaN    NaN     NaN
# 699     NaN    NaN     NaN
# 822     NaN    NaN     NaN
# 988     NaN    NaN     NaN
# 1013    NaN    NaN     NaN
# 1035    NaN    NaN     NaN
# 1070    NaN    NaN     NaN
# 1077    NaN    NaN     NaN
# 1079    NaN    NaN     NaN
# 1091    NaN    NaN     NaN
# 1110    NaN    NaN     NaN
# 1136    NaN    NaN     NaN
# 1175    NaN    NaN     NaN
# 1177    NaN    NaN     NaN
# 1178    NaN    NaN     NaN
# 1179    NaN    NaN     NaN
# 1182    NaN    NaN     NaN
# 1210    NaN    NaN     NaN
# 1233    NaN    NaN     NaN
# 1235    NaN    NaN     NaN
# ...     ...    ...     ...
# 5342    NaN    NaN     NaN
# 5363    NaN    NaN     NaN
# 5374    NaN    NaN     NaN
# 5419    NaN    NaN     NaN
# 5510    NaN    NaN     NaN
# 5577    NaN    NaN     NaN
# 5677    NaN    NaN     NaN
# 5748    NaN    NaN     NaN
# 5756    NaN    NaN     NaN
# 5881    NaN    NaN     NaN
# 5890    NaN    NaN     NaN
# 5902    NaN    NaN     NaN
# 5956    NaN    NaN     NaN
# 5957    NaN    NaN     NaN
# 5966    NaN    NaN     NaN
# 5976    NaN    NaN     NaN
# 5977    NaN    NaN     NaN
# 5992    NaN    NaN     NaN
# 6001    NaN    NaN     NaN
# 6093    NaN    NaN     NaN
# 6121    NaN    NaN     NaN
# 6152    NaN    NaN     NaN
# 6154    NaN    NaN     NaN
# 6155    NaN    NaN     NaN
# 6180    NaN    NaN     NaN
# 6195    NaN    NaN     NaN
# 6418    NaN    NaN     NaN
# 6441    NaN    NaN     NaN
# 6482    NaN    NaN     NaN
# 6565    NaN    NaN     NaN
#
# [154 rows x 40 columns]

# %%
#Es handelt sich um Objekte im Seegebiet, die nicht innerhalb der Gemeindegrenzen liegen

# %% [markdown]
# Erstellen Sie anhand des neuen GDF eine Liste, die für jede Gemeinde die Anzahl der Denkmalschutz-Objekte enthält.
#
# Speichern Sie die Liste wiederum als neues Dataframe.

# %%
df_anzahl = gdf_ds_gem['GMDNAME'].value_counts().to_frame().rename(columns={'GMDNAME': 'Anzahl'})

# %% [markdown]
# Welches sind die fünf Gemeinden, die am meisten Objekte haben?

# %%
df_anzahl.head(5)
# Out:
#             Anzahl
# Winterthur     777
# Zürich         357
# Wädenswil      226
# Wald (ZH)      161
# Uster          147

# %% [markdown]
# ### Daten kombinieren 2
#
# Fügen Sie nun dem urspünglichen Zürcher Gemeinde-GDF die Infos zur Anzahl Denkmalschutzobjekte aus dem soeben erstellten DF hinzu

# %%
gdf_zh_anz = gdf_zh.merge(df_anzahl, how='left', left_on='GMDNAME', right_index=True)

# %% [markdown]
# Checken Sie das Ergebnis anhand der Gemeinde Zürich

# %%
gdf_zh_anz[gdf_zh_anz['GMDNAME'] == 'Zürich']
# Out:
#      GMDNR GMDNAME  BZNR  KTNR  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN   Y_MAX  \
# 497    261  Zürich   112     1     4     8793  676224  689665  241584  254306
#
#      ...  Z_MED  Z_CNTR    E_MIN    E_MAX    N_MIN    N_MAX   E_CNTR   N_CNTR  \
# 497  ...    453     409  2676224  2689665  1241584  1254306  2683100  1247100
#
#                                               geometry  Anzahl
# 497  POLYGON ((684249.637 253917.051, 684430.504 25...   357.0
#
# [1 rows x 25 columns]

# %% [markdown]
# Gibt es Gemeinden, zu denen keine Information hinzugefügt wurde?

# %%
gdf_zh_anz[gdf_zh_anz['Anzahl'].isnull()]
# Out:
#       GMDNR  GMDNAME  BZNR  KTNR  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN  \
# 2151     85  Dänikon   104     1     4      287  671734  674000  254209
#
#        Y_MAX  ...  Z_MED  Z_CNTR    E_MIN    E_MAX    N_MIN    N_MAX   E_CNTR  \
# 2151  256174  ...    446     441  2671734  2674000  1254209  1256174  2672900
#
#        N_CNTR                                           geometry  Anzahl
# 2151  1255400  POLYGON ((673786.137 256006.995, 673987.140 25...     NaN
#
# [1 rows x 25 columns]

# %% [markdown]
# Wenn ja, ersetzen Sie in der entsprechenden Spalte die NaN-Werte durch Nullen.

# %%
gdf_zh_anz['Anzahl'] = gdf_zh_anz['Anzahl'].fillna(0)

# %% [markdown]
# ### Plot
#
# Wir möchten eine Choropleth-Map der Zürcher Gemeinden zeichnen.
# Die Farbcodierung der Gemeinden richtet sich nach der Anzahl Objekte.

# %%
ax = gdf_zh_anz.plot(column='Anzahl', cmap='Blues', scheme='quantiles', edgecolor='white', legend=True, figsize=(12,12))
ax.set_title('Anzahl denkmalgeschützte Objekte pro Gemeinde')
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/pysal/explore/segregation/network/network.py:16: UserWarning: You need pandana and urbanaccess to work with segregation's network module
# You can install them with  `pip install urbanaccess pandana` or `conda install -c udst pandana urbanaccess`
#   "You need pandana and urbanaccess to work with segregation's network module\n"
# /home/pc/anaconda3/lib/python3.7/site-packages/pysal/model/spvcm/abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql
# Text(0.5, 1, 'Anzahl denkmalgeschützte Objekte pro Gemeinde')

# %% [markdown]
# ## Analyse 2: Geschäfte
#
# Hier interessiert uns die Lage der Coop-Geschäfte im Kanton Zürich.

# %% [markdown]
# ### Import

# %% [markdown]
# Eine Liste der Coop-Filialen ist abgelegt unter: `'dataprojects/Coop/geschaefte.csv'`

# %%
df_stores = pd.read_csv('dataprojects/Coop/geschaefte.csv')

# %%
df_stores.head(2)
# Out:
#   hausnummer   latitude  longitude                       name        ort  \
# 0         42  46.837574   8.186167     coop-supermarkt-giswil     Giswil
# 1          2  46.728708   8.181781  coop-supermarkt-meiringen  Meiringen
#
#     plz        strasse     typ
# 0  6074  Brünigstrasse  retail
# 1  3860      Alpwegern  retail

# %% [markdown]
# Welche Spalten beinhalten die relevante Information? Um was für Koordinatentypen handelt es sich?

# %% [markdown]
# ### Geometrie definieren

# %% [markdown]
# Erstellen Sie aus dem DF der Geschäfte ein GDF, indem Sie
# - eine Geometrie-Spalte mit Punkten erstellen
# - ein GDF kreieren, mithilfe dieser Spalte
# - das Koordinatensystem dieses GDF initiieren
# - die Koordinaten ins Schweizer System umrechnen

# %%
df_stores['Punkt'] = df_stores.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# %%
gdf_stores = gpd.GeoDataFrame(df_stores, geometry='Punkt')

# %%
gdf_stores.crs = {'init': 'epsg:4326'}

# %%
gdf_stores = gdf_stores.to_crs(epsg=21781)
# Out:
# /home/pc/anaconda3/lib/python3.7/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### Auswählen

# %% [markdown]
# Uns interessieren nur die Geschäfte im Kanton zürich. Filtern Sie diese heraus und speichern sie in einem neuen GDF.

# %%
gdf_stores_zh = gdf_stores[gdf_stores.within(gdf_zh.unary_union)]

# %% [markdown]
# Zum checken, ob es funktioniert hat: einfacher plot

# %%
gdf_stores_zh.plot()

# %% [markdown]
# ### Plot

# %% [markdown]
# Plotten Sie die Coop-Läden im Kanton Zürich auf dem Hintergrund der Gemeindekarte

# %%
ax = gdf_zh.plot(figsize=(15,15), color='lightgrey', linewidth=0.25, edgecolor='white')
gdf_stores_zh.plot(ax=ax, color='darkblue', markersize=8, alpha = 0.8)

# %% [markdown]
# ### Filter 1
#
# In welchen Gemeinden gibt es keinen Coop?

# %% [markdown]
# Zur Vorbereitung: alle Coop-Filialen zu einem einzigen Shape zusammenfügen

# %%
gdf_stores_zh.unary_union

# %% [markdown]
# Filtern Sie nun die Zürcher Gemeinden: Welche davon haben keinen Berührungspunkt mit dem Coop-Filialen-Shape? Speichern Sie die gefilterte Liste in einem neuen GDF.

# %%
gdf_zh_nostores = gdf_zh[gdf_zh.disjoint(gdf_stores_zh.unary_union)]

# %% [markdown]
# Plot:
# - Alle Zürcher Gemeinden
# - Alle Coop-Filialen im Kt ZH
# - in besonderer Farbe: die Gemeinden ohne Coop

# %%
ax = gdf_zh.plot(figsize=(15,15), color='lightgrey', linewidth=0.25, edgecolor='white')
gdf_stores_zh.plot(ax=ax, color='darkblue', markersize=8, alpha = 0.8)
gdf_zh_nostores.plot(ax=ax, color='green', linewidth=0.25, edgecolor='white', alpha=0.3)

# %% [markdown]
# ### Filter 2
#
# Analoges Vorgehen zu Filter 1. Aber mit einer anderen Abgrenzung: Welche Gemeinden sind mindestens 2km von einer Coop-Filiale entfernt?

# %% [markdown]
# Shape:

# %%
gdf_stores_zh.buffer(2000).unary_union

# %% [markdown]
# Filter:

# %%
gdf_zh_nostores_2 = gdf_zh[gdf_zh.disjoint(gdf_stores_zh.buffer(2000).unary_union)]

# %% [markdown]
# Plot:
# - Alle Zürcher Gemeinden
# - Alle Coop-Filialen im Kt ZH
# - Ein Umkreis von 2km rund um die Coop-Filialen
# - in besonderer Farbe: die Gemeinden ohne Coop

# %%
ax = gdf_zh.plot(figsize=(15,15), color='lightgrey', linewidth=0.25, edgecolor='white')
gdf_stores_zh.buffer(2000).plot(ax=ax, color='lightblue', alpha=0.3)
gdf_stores_zh.plot(ax=ax, color='darkblue', markersize=8, alpha = 0.8)
gdf_zh_nostores_2.plot(ax=ax, color='green', linewidth=0.25, edgecolor='white', alpha=0.3)
ax.set_title('Gemeinden ohne Coop-Filiale next 2 km')
# Out:
# Text(0.5, 1, 'Gemeinden ohne Coop-Filiale next 2 km')

# %% [markdown]
# ## Analyse 3 - Bonus
#
# Gibt es Coop-Geschäfte in denkmalgeschützten Häusern? Überlegen Sie sich ein mögliches Vorgehen, um dies anhand der vorhandenen Datenquellen zu überprüfen. Zum Beispiel: Gibt es Punkte aus dem Coop-GDF und dem Denkmalschutz-GDF, die weniger als 10 Meter auseinander liegen?

# %% [markdown]
# (Achtung, je nach dem, wie man vorgeht, brauchen die Checks jeweils ein paar Minuten Rechenzeit!)

# %%
ds_gebäude = gdf_ds.buffer(10).unary_union

# %%
gdf_stores_dm = gdf_stores_zh[gdf_stores_zh.within(ds_gebäude)]

# %%
gdf_ds[gdf_ds['STRASSE'] == 'Hofwiesenstrasse 369']
# Out:
#      GEMEINDE     ORT   PLZ               STRASSE  \
# 5115   Zürich  Zürich  8050  Hofwiesenstrasse 369
#
#                                          ENSEMBLE           OBJEKT    GVZ_NR  \
# 5115  Zürich: Bahnhof SBB Station Zürich Oerlikon  Aufnahmegebäude  27200068
#
#      BAUJAHR EINSTUFUNG FESTSETZUN ERLASS SCHUTZ GRUNDBUCHE           OST  \
# 5115    1913   kantonal       None   None      -       None  2.683437e+06
#
#               NORD                       geometry
# 5115  1.251772e+06  POINT (683436.923 251771.847)

# %%
gdf_ds[gdf_ds['STRASSE'] == 'Stadelhoferstrasse 8']
# Out:
#      GEMEINDE     ORT   PLZ               STRASSE  \
# 4294   Zürich  Zürich  8001  Stadelhoferstrasse 8
#
#                                                ENSEMBLE           OBJEKT  \
# 4294  Zürich: Bahnhofanlage SBB Station Zürich Stade...  Aufnahmegebäude
#
#         GVZ_NR    BAUJAHR EINSTUFUNG FESTSETZUN ERLASS SCHUTZ GRUNDBUCHE  \
# 4294  28101031  1892~1894   kantonal       None   None      -       None
#
#                OST          NORD                       geometry
# 4294  2.683823e+06  1.246780e+06  POINT (683822.901 246779.835)

# %%
#Es zeigt sich, dass die Bahnhofsgebäude in Zürich und Winterthur,
#in denen auch ein Coop untergebracht ist, denkmalgeschützt sind.
