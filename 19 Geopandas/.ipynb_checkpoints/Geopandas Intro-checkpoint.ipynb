# %% [markdown]
# # Geopandas Intro

# %% [markdown]
# **Inhalt:** Erste Schritte mit Geopandas
#
# **Nötige Skills**
# - Basic pandas skills
# - Funktionen und pandas
#
# **Lernziele**
# - Shapes kennenlernen
# - Punkte und Linien erstellen
# - Geodataframes erstellen
# - Geometrien definieren
# - Plotten in Geopandas

# %% [markdown]
# ## Das Beispiel
#
# Bergbahnen in der Schweiz. Wir laden die geografischen Informationen sämtlicher Bergbahnen und stellen sie auf einer Karte dar.

# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
import geopandas as gpd
from shapely.geometry import Point, LineString

# %%
# %matplotlib inline

# %% [markdown]
# ## Import

# %% [markdown]
# **Ein Shapefile für die Schweizer Kantone**
#
# Dieses File brauchen wir erst ganz am Schluss.

# %%
gdf_kantone = gpd.read_file('dataprojects/Projections/shp/g1k17.shp')

# %%
gdf_kantone.head(2)
# Out:
#    KTNR        KTNAME  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN   Y_MAX  X_CNTR  \
# 0     1        Zürich     4   172894  669244  716900  223896  283343  691800
# 1     2  Bern / Berne     2   595952  556241  677745  130585  243834  614200
#
#    Y_CNTR  ...  Z_MAX  Z_AVG  Z_MED    E_MIN    E_MAX    N_MIN    N_MAX  \
# 0  252000  ...   1291    533    504  2669244  2716900  1223896  1283343
# 1  185600  ...   4271   1198    979  2556241  2677745  1130585  1243834
#
#     E_CNTR   N_CNTR                                           geometry
# 0  2691800  1252000  POLYGON ((692429.202 281173.707, 692993.467 28...
# 1  2614200  1185600  MULTIPOLYGON (((573502.204 194804.720, 573996....
#
# [2 rows x 21 columns]

# %% [markdown]
# **Eine Liste der Bergbahnen**
#
# Mit dieser Liste werden wir hauptsächlich arbeiten.

# %%
df_bergbahnen = pd.read_excel('dataprojects/Projections/data/bergbahnen3D.xlsx')

# %%
df_bergbahnen.head(10)
# Out:
#       OBJEKTART                             NAME   MIN_E   MIN_N  MIN_Z  \
# 0       Skilift                        Grenzlift  621759   85777   3713
# 1       Skilift                Plateau Breithorn  622730   86797   3800
# 2  Luftseilbahn  Trockener Steg-Klein Matterhorn  621991   91079   2939
# 3       Skilift                   Plateau Rosa 1  621542   87239   3415
# 4       Skilift                   Plateau Rosa 2  621517   87222   3417
# 5       Skilift                        Allalin 3  635480  100882   3272
# 6       Skilift                        Allalin 2  635509  100873   3274
# 7       Skilift                   Plateau Rosa 3  621494   87233   3417
# 8  Luftseilbahn  Laghi Cime Bianche Plateau Rosà  618779   86517   2828
# 9       Skilift                            Testa  621184   88240   3229
#
#     MAX_E   MAX_N  MAX_Z
# 0  622992   85864   3902
# 1  622992   85867   3902
# 2  622561   87549   3824
# 3  621973   85824   3738
# 4  621903   85823   3732
# 5  635559  100090   3568
# 6  635567  100091   3567
# 7  621656   86612   3514
# 8  620865   87025   3477
# 9  620925   86925   3462

# %%
df_bergbahnen['OBJEKTART'].value_counts()
# Out:
# Skilift         841
# Sesselbahn      365
# Luftseilbahn    327
# Gondelbahn      124
# Name: OBJEKTART, dtype: int64

# %% [markdown]
# ## Geometrien in Geopandas

# %% [markdown]
# In unserem Shapefile der Kantone (\*.shp) ist bereits eine Geometrie definiert: Eine separate Spalte in jedem Kanton ist dafür reserviert.

# %%
gdf_kantone.columns
# Out:
# Index(['KTNR', 'KTNAME', 'GRNR', 'AREA_HA', 'X_MIN', 'X_MAX', 'Y_MIN', 'Y_MAX',
#        'X_CNTR', 'Y_CNTR', 'Z_MIN', 'Z_MAX', 'Z_AVG', 'Z_MED', 'E_MIN',
#        'E_MAX', 'N_MIN', 'N_MAX', 'E_CNTR', 'N_CNTR', 'geometry'],
#       dtype='object')

# %% [markdown]
# In der Geometrie-Spalte sind (Überraschung!) geometrische Informationen drin. In diesem Fall: ein Polygon.

# %%
gdf_kantone.head(10)
# Out:
#    KTNR               KTNAME  GRNR  AREA_HA   X_MIN   X_MAX   Y_MIN   Y_MAX  \
# 0     1               Zürich     4   172894  669244  716900  223896  283343
# 1     2         Bern / Berne     2   595952  556241  677745  130585  243834
# 2     3               Luzern     6   149352  630127  681764  180569  237691
# 3     4                  Uri     6   107654  673344  715795  153452  205339
# 4     5               Schwyz     6    90788  672166  718719  193657  231067
# 5     6             Obwalden     6    49058  646044  681478  178345  203583
# 6     7            Nidwalden     6    27585  659303  686448  180483  208075
# 7     8               Glarus     5    68531  709273  738138  183891  225967
# 8     9                  Zug     6    23873  672418  695749  215061  233506
# 9    10  Fribourg / Freiburg     2   167142  546837  595531  143053  206219
#
#    X_CNTR  Y_CNTR  ...  Z_MAX  Z_AVG  Z_MED    E_MIN    E_MAX    N_MIN  \
# 0  691800  252000  ...   1291    533    504  2669244  2716900  1223896
# 1  614200  185600  ...   4271   1198    979  2556241  2677745  1130585
# 2  651000  213100  ...   2348    770    680  2630127  2681764  1180569
# 3  690800  180700  ...   3628   1900   1975  2673344  2715795  1153452
# 4  700100  213100  ...   2800   1096   1053  2672166  2718719  1193657
# 5  658700  189900  ...   3238   1337   1368  2646044  2681478  1178345
# 6  673600  197700  ...   2898   1071    986  2659303  2686448  1180483
# 7  723700  204600  ...   3608   1579   1594  2709273  2738138  1183891
# 8  683300  223500  ...   1579    664    638  2672418  2695749  1215061
# 9  573800  173100  ...   2388    855    750  2546837  2595531  1143053
#
#      N_MAX   E_CNTR   N_CNTR  \
# 0  1283343  2691800  1252000
# 1  1243834  2614200  1185600
# 2  1237691  2651000  1213100
# 3  1205339  2690800  1180700
# 4  1231067  2700100  1213100
# 5  1203583  2658700  1189900
# 6  1208075  2673600  1197700
# 7  1225967  2723700  1204600
# 8  1233506  2683300  1223500
# 9  1206219  2573800  1173100
#
#                                             geometry
# 0  POLYGON ((692429.202 281173.707, 692993.467 28...
# 1  MULTIPOLYGON (((573502.204 194804.720, 573996....
# 2  POLYGON ((662037.558 237690.723, 662271.728 23...
# 3  POLYGON ((688456.999 203340.000, 688740.000 20...
# 4  POLYGON ((705202.678 229721.111, 706142.258 22...
# 5  MULTIPOLYGON (((671653.400 190588.001, 671407....
# 6  POLYGON ((671798.251 206022.836, 672021.878 20...
# 7  POLYGON ((723477.400 221272.410, 723896.499 22...
# 8  POLYGON ((674191.900 231111.999, 674454.750 23...
# 9  MULTIPOLYGON (((549140.980 178013.761, 549375....
#
# [10 rows x 21 columns]

# %%
gdf_kantone.geometry
# Out:
# 0     POLYGON ((692429.202 281173.707, 692993.467 28...
# 1     MULTIPOLYGON (((573502.204 194804.720, 573996....
# 2     POLYGON ((662037.558 237690.723, 662271.728 23...
# 3     POLYGON ((688456.999 203340.000, 688740.000 20...
# 4     POLYGON ((705202.678 229721.111, 706142.258 22...
# 5     MULTIPOLYGON (((671653.400 190588.001, 671407....
# 6     POLYGON ((671798.251 206022.836, 672021.878 20...
# 7     POLYGON ((723477.400 221272.410, 723896.499 22...
# 8     POLYGON ((674191.900 231111.999, 674454.750 23...
# 9     MULTIPOLYGON (((549140.980 178013.761, 549375....
# 10    MULTIPOLYGON (((619250.502 223755.124, 619395....
# 11    POLYGON ((619154.867 272278.575, 617536.204 27...
# 12    MULTIPOLYGON (((595269.700 251478.499, 594298....
# 13    MULTIPOLYGON (((686912.793 272390.067, 686814....
# 14    POLYGON ((758852.593 259182.820, 758918.982 25...
# 15    MULTIPOLYGON (((746530.217 250212.577, 746449....
# 16    POLYGON ((759598.570 267841.931, 760034.120 26...
# 17    POLYGON ((760618.874 213990.948, 760944.580 21...
# 18    POLYGON ((659054.129 273230.311, 659213.596 27...
# 19    MULTIPOLYGON (((753544.589 261836.096, 752664....
# 20    POLYGON ((716299.000 165467.000, 716755.410 16...
# 21    MULTIPOLYGON (((546732.841 193708.470, 546599....
# 22    POLYGON ((675051.883 165431.940, 675335.731 16...
# 23    POLYGON ((556971.205 217029.141, 556582.810 21...
# 24    MULTIPOLYGON (((500975.320 128340.310, 502271....
# 25    POLYGON ((569711.731 261016.440, 569732.725 26...
# Name: geometry, dtype: geometry

# %% [markdown]
# Daher können wir die 26 Schweizer Kantone auch ganz einfach plotten. Und zwar mit`plot()`:

# %%
gdf_kantone.plot()

# %% [markdown]
# Unsere Bergbahnen-Liste hat allerdings noch keine Geometrie-Spalte:

# %%
df_bergbahnen.columns
# Out:
# Index(['OBJEKTART', 'NAME', 'MIN_E', 'MIN_N', 'MIN_Z', 'MAX_E', 'MAX_N',
#        'MAX_Z'],
#       dtype='object')

# %%
df_bergbahnen.head(10)
# Out:
#       OBJEKTART                             NAME   MIN_E   MIN_N  MIN_Z  \
# 0       Skilift                        Grenzlift  621759   85777   3713
# 1       Skilift                Plateau Breithorn  622730   86797   3800
# 2  Luftseilbahn  Trockener Steg-Klein Matterhorn  621991   91079   2939
# 3       Skilift                   Plateau Rosa 1  621542   87239   3415
# 4       Skilift                   Plateau Rosa 2  621517   87222   3417
# 5       Skilift                        Allalin 3  635480  100882   3272
# 6       Skilift                        Allalin 2  635509  100873   3274
# 7       Skilift                   Plateau Rosa 3  621494   87233   3417
# 8  Luftseilbahn  Laghi Cime Bianche Plateau Rosà  618779   86517   2828
# 9       Skilift                            Testa  621184   88240   3229
#
#     MAX_E   MAX_N  MAX_Z
# 0  622992   85864   3902
# 1  622992   85867   3902
# 2  622561   87549   3824
# 3  621973   85824   3738
# 4  621903   85823   3732
# 5  635559  100090   3568
# 6  635567  100091   3567
# 7  621656   86612   3514
# 8  620865   87025   3477
# 9  620925   86925   3462

# %% [markdown]
# Daher kommt mit dem `plot()`-Befehl auch noch nichts sinnvolles raus:

# %%
df_bergbahnen.plot()

# %% [markdown]
# Bevor wir irgendwas plotten können, müssen wir erst eine Geometrie erstellen!
#
# **Dazu müssen wir einige Dinge klären:**
# - Welche Art von Geometrie wollen wir kreieren?
# - Gibt es mehrere Möglichkeiten?
# - Welches sind die nötigen Informationen dafür?

# %% [markdown]
# ### Geometrie erstellen

# %% [markdown]
# **Zur Erinnerung: Points()-Funktion**
#
# Diese Funktion brauchen wir, um eine Punkt-Geometrie zu erstellen.
#
# So erstellen Sie einen Punkt am Ort (5, -7)

# %%
x = 5
y = -7

# %%
punkt = Point(x, y)

# %%
punkt

# %% [markdown]
# **In Pandas arbeiten mit apply()**
#
# Unser Ziel ist: eine Spalte in unserem Dataframe zu haben, die für jede Bergbahn eine Punkt-Geometrie enthält.
#
# Mit anderen Worten: Wir müssen die x- und y-Koordinaten für jeden Eintrag aus der Tabelle auslesen und mit `Point()` zu einer Punkt-Geometrie machen.
#
# In Pandas funktioniert das folgendermassen:

# %%
df_bergbahnen['Punkt1'] = df_bergbahnen.apply(lambda row: Point(row['MIN_E'], row['MIN_N']), axis=1)
## neue spalte in df mit Punktwert

# lambda: funktion nicht extra definiert, funktioniert direkt
# apply: anwenden

# %% [markdown]
# Siehe: Teil 3, Kurstag 11, Pandas und Funktionen

# %% [markdown]
# def make_point(x,y)
#     return Point(x,y)

# %% [markdown]
# make_point(2,3)

# %% [markdown]
# x = 3
# y = 5

# %%
x = 3
y = 5

# %%
lambda x,y: Point(x,y)
# Out:
# <function __main__.<lambda>(x, y)>

# %%
(lambda x,y: Point(x, y))(3, 5)     ## Point ist fest definierte Funtion für zwei Punkte

# %%
df_bergbahnen.head(10)
# Out:
#       OBJEKTART                             NAME   MIN_E   MIN_N  MIN_Z  \
# 0       Skilift                        Grenzlift  621759   85777   3713
# 1       Skilift                Plateau Breithorn  622730   86797   3800
# 2  Luftseilbahn  Trockener Steg-Klein Matterhorn  621991   91079   2939
# 3       Skilift                   Plateau Rosa 1  621542   87239   3415
# 4       Skilift                   Plateau Rosa 2  621517   87222   3417
# 5       Skilift                        Allalin 3  635480  100882   3272
# 6       Skilift                        Allalin 2  635509  100873   3274
# 7       Skilift                   Plateau Rosa 3  621494   87233   3417
# 8  Luftseilbahn  Laghi Cime Bianche Plateau Rosà  618779   86517   2828
# 9       Skilift                            Testa  621184   88240   3229
#
#     MAX_E   MAX_N  MAX_Z                 Punkt1
# 0  622992   85864   3902   POINT (621759 85777)
# 1  622992   85867   3902   POINT (622730 86797)
# 2  622561   87549   3824   POINT (621991 91079)
# 3  621973   85824   3738   POINT (621542 87239)
# 4  621903   85823   3732   POINT (621517 87222)
# 5  635559  100090   3568  POINT (635480 100882)
# 6  635567  100091   3567  POINT (635509 100873)
# 7  621656   86612   3514   POINT (621494 87233)
# 8  620865   87025   3477   POINT (618779 86517)
# 9  620925   86925   3462   POINT (621184 88240)

# %% [markdown]
# Zum technischen Verständnis:
# - Wir haben mit dem `lambda`-Keyword eine Funktion definiert, welche die `Points()`-Funktion aufruft
# - Dann haben wir diese (namenlose) Funktion mit `apply()` für jede Zeile in der Tabelle angewandt
#
# Das Ergebnis ist: Wir haben jetzt eine Geometrie erstellt
#
# Jetzt müssen wir Geopandas noch mitteilen, dass wir diese Geometrie verwenden wollen!

# %% [markdown]
# ### Geometrie anwenden in Geopandas

# %% [markdown]
# Mit anderen Worten: Wir müssen aus dem Dataframe erst ein Geodataframe erstellen!
#
# **Geodataframe konstruieren**
#
# Die Konstruktor-Funktion heisst `GeoDataFrame()`. Zwei Infos sind nötig:
# - Aus welchem Dataframe soll ein Geodataframe werden
# - Welche Spalte soll die Geometrie definieren

# %%
gdf_bergbahnen = gpd.GeoDataFrame(df_bergbahnen, geometry='Punkt1')     #geometry definieren!

# %%
gdf_bergbahnen.head(10)
# Out:
#       OBJEKTART                             NAME   MIN_E   MIN_N  MIN_Z  \
# 0       Skilift                        Grenzlift  621759   85777   3713
# 1       Skilift                Plateau Breithorn  622730   86797   3800
# 2  Luftseilbahn  Trockener Steg-Klein Matterhorn  621991   91079   2939
# 3       Skilift                   Plateau Rosa 1  621542   87239   3415
# 4       Skilift                   Plateau Rosa 2  621517   87222   3417
# 5       Skilift                        Allalin 3  635480  100882   3272
# 6       Skilift                        Allalin 2  635509  100873   3274
# 7       Skilift                   Plateau Rosa 3  621494   87233   3417
# 8  Luftseilbahn  Laghi Cime Bianche Plateau Rosà  618779   86517   2828
# 9       Skilift                            Testa  621184   88240   3229
#
#     MAX_E   MAX_N  MAX_Z                         Punkt1
# 0  622992   85864   3902   POINT (621759.000 85777.000)
# 1  622992   85867   3902   POINT (622730.000 86797.000)
# 2  622561   87549   3824   POINT (621991.000 91079.000)
# 3  621973   85824   3738   POINT (621542.000 87239.000)
# 4  621903   85823   3732   POINT (621517.000 87222.000)
# 5  635559  100090   3568  POINT (635480.000 100882.000)
# 6  635567  100091   3567  POINT (635509.000 100873.000)
# 7  621656   86612   3514   POINT (621494.000 87233.000)
# 8  620865   87025   3477   POINT (618779.000 86517.000)
# 9  620925   86925   3462   POINT (621184.000 88240.000)

# %% [markdown]
# Jetzt können wir plotten:

# %%
gdf_bergbahnen.geometry
# Out:
# 0        POINT (621759.000 85777.000)
# 1        POINT (622730.000 86797.000)
# 2        POINT (621991.000 91079.000)
# 3        POINT (621542.000 87239.000)
# 4        POINT (621517.000 87222.000)
# 5       POINT (635480.000 100882.000)
# 6       POINT (635509.000 100873.000)
# 7        POINT (621494.000 87233.000)
# 8        POINT (618779.000 86517.000)
# 9        POINT (621184.000 88240.000)
# 10      POINT (642130.000 155229.000)
# 11       POINT (628987.000 93322.000)
# 12      POINT (635482.000 101412.000)
# 13       POINT (621939.000 91007.000)
# 14       POINT (619879.000 88521.000)
# 15      POINT (589429.000 103726.000)
# 16      POINT (783301.000 145084.000)
# 17       POINT (627027.000 95334.000)
# 18       POINT (628865.000 92876.000)
# 19       POINT (628634.000 94280.000)
# 20       POINT (621984.000 90973.000)
# 21      POINT (635286.000 103618.000)
# 22      POINT (640622.000 109797.000)
# 23      POINT (704665.000 161047.000)
# 24      POINT (641390.000 138598.000)
# 25       POINT (626887.000 96228.000)
# 26       POINT (627720.000 97646.000)
# 27      POINT (624520.000 141678.000)
# 28      POINT (675497.000 181088.000)
# 29      POINT (674736.000 181726.000)
#                     ...
# 1627    POINT (605706.000 175443.000)
# 1628    POINT (681760.000 240819.000)
# 1629    POINT (697803.000 204487.000)
# 1630    POINT (711863.000 241188.000)
# 1631    POINT (557405.000 132171.000)
# 1632    POINT (722219.000 212923.000)
# 1633    POINT (690699.000 196282.000)
# 1634    POINT (626427.000 218153.000)
# 1635    POINT (693526.000 111583.000)
# 1636    POINT (694223.000 113638.000)
# 1637    POINT (716856.000 253581.000)
# 1638    POINT (696467.000 114709.000)
# 1639    POINT (712899.000 244838.000)
# 1640    POINT (687908.000 194812.000)
# 1641    POINT (721484.000 202039.000)
# 1642     POINT (710190.000 96421.000)
# 1643    POINT (723587.000 210602.000)
# 1644    POINT (689711.000 203914.000)
# 1645    POINT (737845.000 219630.000)
# 1646     POINT (716040.000 86901.000)
# 1647    POINT (674796.000 258824.000)
# 1648    POINT (697461.000 114962.000)
# 1649    POINT (722894.000 123868.000)
# 1650    POINT (690761.000 190705.000)
# 1651    POINT (637045.000 259861.000)
# 1652    POINT (697094.000 115996.000)
# 1653    POINT (722244.000 213641.000)
# 1654    POINT (565980.000 118163.000)
# 1655    POINT (566282.000 119385.000)
# 1656    POINT (701713.000 114240.000)
# Name: Punkt1, Length: 1657, dtype: geometry

# %%
gdf_bergbahnen.plot(figsize=(14,10), markersize=3)

# %% [markdown]
# Oder zB auch nur einzele, ausgewählte Objekte:

# %%
gdf_bergbahnen[gdf_bergbahnen['OBJEKTART'] == 'Luftseilbahn'].plot(figsize=(14,10), markersize=3)  ##tabelle gefiltert

# %% [markdown]
# ## Geometrien 2
#
# Allerdings - moment mal. Unsere Seilbahnen sind eigentlich keine Punkte, sondern müssten eigentlich eine Linie sein - mit einem Anfang und einem Ende.
#
# ### Linie (again!)

# %% [markdown]
# **Quiz:** Erstellen Sie eine Linie durch die Punkte (8, 6) und (4, 10)

# %%
#df_bergbahnen['Punkt1'] = df_bergbahnen.apply(lambda row: Point(row['MIN_E'], row['MIN_N']), axis=1)
#df_bergbahnen['Punkt2'] = df_bergbahnen.apply(lambda row: Point(row['MAX_E'], row['MAX_N']), axis=1)

# %%
####linien = LineString([Point('Punkt1'), Point('Punkt2')])

# %%
df_bergbahnen['Linien'] = df_bergbahnen.apply(lambda row: LineString([Point(row['MIN_E'], row['MIN_N']), Point(row['MAX_E'], row['MAX_N'])]),axis=1)

                        #df_bergbahnen.apply(lambda row: LineString([Point(row['MIN_E'], row['MIN_N']), Point(row['MAX_E'], row['MAX_N'])]), axis = 1)

# %%
df_bergbahnen.head(10)
# Out:
#       OBJEKTART                             NAME   MIN_E   MIN_N  MIN_Z  \
# 0       Skilift                        Grenzlift  621759   85777   3713
# 1       Skilift                Plateau Breithorn  622730   86797   3800
# 2  Luftseilbahn  Trockener Steg-Klein Matterhorn  621991   91079   2939
# 3       Skilift                   Plateau Rosa 1  621542   87239   3415
# 4       Skilift                   Plateau Rosa 2  621517   87222   3417
# 5       Skilift                        Allalin 3  635480  100882   3272
# 6       Skilift                        Allalin 2  635509  100873   3274
# 7       Skilift                   Plateau Rosa 3  621494   87233   3417
# 8  Luftseilbahn  Laghi Cime Bianche Plateau Rosà  618779   86517   2828
# 9       Skilift                            Testa  621184   88240   3229
#
#     MAX_E   MAX_N  MAX_Z                 Punkt1                 Punkt2  \
# 0  622992   85864   3902   POINT (621759 85777)   POINT (622992 85864)
# 1  622992   85867   3902   POINT (622730 86797)   POINT (622992 85867)
# 2  622561   87549   3824   POINT (621991 91079)   POINT (622561 87549)
# 3  621973   85824   3738   POINT (621542 87239)   POINT (621973 85824)
# 4  621903   85823   3732   POINT (621517 87222)   POINT (621903 85823)
# 5  635559  100090   3568  POINT (635480 100882)  POINT (635559 100090)
# 6  635567  100091   3567  POINT (635509 100873)  POINT (635567 100091)
# 7  621656   86612   3514   POINT (621494 87233)   POINT (621656 86612)
# 8  620865   87025   3477   POINT (618779 86517)   POINT (620865 87025)
# 9  620925   86925   3462   POINT (621184 88240)   POINT (620925 86925)
#
#                                       Linien
# 0    LINESTRING (621759 85777, 622992 85864)
# 1    LINESTRING (622730 86797, 622992 85867)
# 2    LINESTRING (621991 91079, 622561 87549)
# 3    LINESTRING (621542 87239, 621973 85824)
# 4    LINESTRING (621517 87222, 621903 85823)
# 5  LINESTRING (635480 100882, 635559 100090)
# 6  LINESTRING (635509 100873, 635567 100091)
# 7    LINESTRING (621494 87233, 621656 86612)
# 8    LINESTRING (618779 86517, 620865 87025)
# 9    LINESTRING (621184 88240, 620925 86925)

# %%
gdf_bergbahnen = gpd.GeoDataFrame(df_bergbahnen, geometry='Linien')

# %%
gdf_bergbahnen
# Out:
#          OBJEKTART                              NAME   MIN_E   MIN_N  MIN_Z  \
# 0          Skilift                         Grenzlift  621759   85777   3713
# 1          Skilift                 Plateau Breithorn  622730   86797   3800
# 2     Luftseilbahn   Trockener Steg-Klein Matterhorn  621991   91079   2939
# 3          Skilift                    Plateau Rosa 1  621542   87239   3415
# 4          Skilift                    Plateau Rosa 2  621517   87222   3417
# 5          Skilift                         Allalin 3  635480  100882   3272
# 6          Skilift                         Allalin 2  635509  100873   3274
# 7          Skilift                    Plateau Rosa 3  621494   87233   3417
# 8     Luftseilbahn   Laghi Cime Bianche Plateau Rosà  618779   86517   2828
# 9          Skilift                             Testa  621184   88240   3229
# 10         Skilift                      Jungfraujoch  642130  155229   3437
# 11         Skilift                         Stockhorn  628987   93322   3039
# 12         Skilift                         Allalin 1  635482  101412   3147
# 13      Sesselbahn                       Furggsattel  621939   91007   2913
# 14      Sesselbahn                         Bontadini  619879   88521   3045
# 15    Luftseilbahn               Gentianes-Mont Fort  589429  103726   2906
# 16    Luftseilbahn                  Murtèl-Corvatsch  783301  145084   2708
# 17    Luftseilbahn                     Gant-Hohtälli  627027   95334   2224
# 18    Luftseilbahn                         Rote Nase  628865   92876   3262
# 19         Skilift                           Triftji  628634   94280   2721
# 20         Skilift                           Gandegg  621984   90973   2917
# 21         Skilift                          Feechatz  635286  103618   2887
# 22      Gondelbahn                           Hohsaas  640622  109797   2408
# 23    Luftseilbahn                  La Stadera-Scopi  704665  161047   1804
# 1643  LINESTRING (723587.000 210602.000, 723462.000 ...
# 1644  LINESTRING (689711.000 203914.000, 689745.000 ...
# 1645  LINESTRING (737845.000 219630.000, 738028.000 ...
# 1646  LINESTRING (716040.000 86901.000, 716195.000 8...
# 1647  LINESTRING (674796.000 258824.000, 674679.000 ...
# 1648  LINESTRING (697461.000 114962.000, 696477.000 ...
# 1649  LINESTRING (722894.000 123868.000, 723153.000 ...
# 1650  LINESTRING (690761.000 190705.000, 690287.000 ...
# 1651  LINESTRING (637045.000 259861.000, 636842.000 ...
# 1652  LINESTRING (697094.000 115996.000, 696551.000 ...
# 1653  LINESTRING (722244.000 213641.000, 722058.000 ...
# 1654  LINESTRING (565980.000 118163.000, 565845.000 ...
# 1655  LINESTRING (566282.000 119385.000, 566207.000 ...
# 1656  LINESTRING (701713.000 114240.000, 701621.000 ...
#
# [1657 rows x 11 columns]

# %%
gdf_bergbahnen.plot(figsize=(30,20), markersize=3)

# %% [markdown]
# ### in Pandas

# %% [markdown]
# **Einen zweiten Punkt erstellen**
#
# Quiz: Erstellen Sie für jede Zeile einen Punkt2 anhand der Spalten 'MAX_E' und 'MAX_N'
#
# Tipp: Wir wollen eine lambda-Funktion dafür verwenden

# %%
# Out:
#   OBJEKTART               NAME   MIN_E  MIN_N  MIN_Z   MAX_E  MAX_N  MAX_Z  \
# 0   Skilift          Grenzlift  621759  85777   3713  622992  85864   3902
# 1   Skilift  Plateau Breithorn  622730  86797   3800  622992  85867   3902
#
#                  Punkt1                Punkt2
# 0  POINT (621759 85777)  POINT (622992 85864)
# 1  POINT (622730 86797)  POINT (622992 85867)

# %% [markdown]
# **Eine Linie daraus machen**
#
# Quiz: Erstellen Sie für jede Zeile eine Linie anhand der beiden Punkt-Spalten, die wir zuvor erstellt haben

# %%
# Out:
#   OBJEKTART               NAME   MIN_E  MIN_N  MIN_Z   MAX_E  MAX_N  MAX_Z  \
# 0   Skilift          Grenzlift  621759  85777   3713  622992  85864   3902
# 1   Skilift  Plateau Breithorn  622730  86797   3800  622992  85867   3902
#
#                  Punkt1                Punkt2  \
# 0  POINT (621759 85777)  POINT (622992 85864)
# 1  POINT (622730 86797)  POINT (622992 85867)
#
#                                      Linie
# 0  LINESTRING (621759 85777, 622992 85864)
# 1  LINESTRING (622730 86797, 622992 85867)

# %% [markdown]
# **Geometrie neu setzen**

# %% [markdown]
# Quiz: Stellen Sie die Geometrie des GDF um auf die Linien-Spalte

# %% [markdown]
# **Und Plot:**
#
# Quiz: Ein Plot von allen Luftseilbahnen

# %%
gdf_bergbahnen.geometry
# Out:
# 0         LINESTRING (621759 85777, 622992 85864)
# 1         LINESTRING (622730 86797, 622992 85867)
# 2         LINESTRING (621991 91079, 622561 87549)
# 3         LINESTRING (621542 87239, 621973 85824)
# 4         LINESTRING (621517 87222, 621903 85823)
# 5       LINESTRING (635480 100882, 635559 100090)
# 6       LINESTRING (635509 100873, 635567 100091)
# 7         LINESTRING (621494 87233, 621656 86612)
# 8         LINESTRING (618779 86517, 620865 87025)
# 9         LINESTRING (621184 88240, 620925 86925)
# 10      LINESTRING (642130 155229, 642204 155320)
# 11        LINESTRING (628987 93322, 629781 92863)
# 12      LINESTRING (635482 101412, 635931 100871)
# 13        LINESTRING (621939 91007, 620612 88847)
# 14        LINESTRING (619879 88521, 620899 88189)
# 15      LINESTRING (589429 103726, 590692 103181)
# 16      LINESTRING (783301 145084, 783162 143536)
# 17        LINESTRING (627027 95334, 628164 93115)
# 18        LINESTRING (628865 92876, 628191 93082)
# 19        LINESTRING (628634 94280, 628852 92872)
# 20        LINESTRING (621984 90973, 621178 88101)
# 21      LINESTRING (635286 103618, 635435 101344)
# 22      LINESTRING (640622 109797, 642684 109956)
# 23      LINESTRING (704665 161047, 706650 158851)
# 24      LINESTRING (641390 138598, 640374 139485)
# 25        LINESTRING (626887 96228, 627782 96723)
# 26        LINESTRING (627720 97646, 627835 96706)
# 27      LINESTRING (624520 141678, 623782 142100)
# 28      LINESTRING (675497 181088, 675442 180434)
# 29      LINESTRING (674736 181726, 675173 180416)
#                           ...
# 1627    LINESTRING (605706 175443, 605443 175242)
# 1628    LINESTRING (681760 240819, 680820 240476)
# 1629    LINESTRING (697803 204487, 697755 204789)
# 1630    LINESTRING (711863 241188, 711973 241206)
# 1631    LINESTRING (557405 132171, 556947 132816)
# 1632    LINESTRING (722219 212923, 721711 212828)
# 1633    LINESTRING (690699 196282, 690939 196775)
# 1634    LINESTRING (626427 218153, 626336 217777)
# 1635    LINESTRING (693526 111583, 694042 111885)
# 1636    LINESTRING (694223 113638, 694663 112812)
# 1637    LINESTRING (716856 253581, 716497 252997)
# 1638    LINESTRING (696467 114709, 696326 115060)
# 1639    LINESTRING (712899 244838, 712887 244718)
# 1640    LINESTRING (687908 194812, 687304 194694)
# 1641    LINESTRING (721484 202039, 721821 201785)
# 1642      LINESTRING (710190 96421, 710415 96189)
# 1643    LINESTRING (723587 210602, 723462 209921)
# 1644    LINESTRING (689711 203914, 689745 203690)
# 1645    LINESTRING (737845 219630, 738028 218512)
# 1646      LINESTRING (716040 86901, 716195 86071)
# 1647    LINESTRING (674796 258824, 674679 258588)
# 1648    LINESTRING (697461 114962, 696477 114713)
# 1649    LINESTRING (722894 123868, 723153 124074)
# 1650    LINESTRING (690761 190705, 690287 190233)
# 1651    LINESTRING (637045 259861, 636842 259651)
# 1652    LINESTRING (697094 115996, 696551 115908)
# 1653    LINESTRING (722244 213641, 722058 213605)
# 1654    LINESTRING (565980 118163, 565845 118083)
# 1655    LINESTRING (566282 119385, 566207 119286)
# 1656    LINESTRING (701713 114240, 701621 114174)
# Name: Linie, Length: 1657, dtype: object

# %% [markdown]
# ## Mehrere Layer

# %% [markdown]
# Was sich immer gut macht, ist, eine Liste von Punkten auf irgendeinen geografischen Basislayer zu plotten.
#
# An dieser Stelle verwenden wir:
# - Das Geodataframe mit den Kantonen
# - Das Geodagaframe mit den Bergbahnen

# %%
ax = gdf_kantone.plot(figsize=(14,10), color='lightgrey', edgecolor='white')
gdf_bergbahnen[gdf_bergbahnen['OBJEKTART'] == 'Luftseilbahn'].plot(figsize=(14,10), markersize=3, ax=ax)

# %%
#  df[(df['Player'] == 'Michael Jordan') | (df['GP'] > 1500)]
