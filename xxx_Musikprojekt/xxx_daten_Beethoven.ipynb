# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
path = 'Werke_Beethoven_Sheet1.csv'

# %%
with open(path) as table:
    dateiinhalt = table.read()

# %%
print(dateiinhalt)
# Out:
# Op.,WoO,Hess,Biam-onti,Title,Key,Date,Scoring,Genre,Notes,
# 1/1,—,—,62/1,,,,,,,
# Piano Trio,,,,,,,,,,
# E♭ major,1792-93,vn vc pf,Chamber,,,,,,,
# 1/2,—,—,62/2,,,,,,,
# Piano Trio,,,,,,,,,,
# G major,1792-94,vn vc pf,Chamber,,,,,,,
# 1/3,—,—,62/3,,,,,,,
# Piano Trio,,,,,,,,,,
# C minor,1792-94,vn vc pf,Chamber,arr. for 2vn va vc as Op.104,,,,,,
# 2,—,—,87,Piano Sonatas (3):,,1793-95,pf,Keyboard,,
# 2/1,—,—,87/1,,,,,,,
# Piano Sonata No.1,,,,,,,,,,
# F minor,1793-95,pf,Keyboard,,,,,,,
# 2/2,—,—,87/2,,,,,,,
# Piano Sonata No.2,,,,,,,,,,
# A major,1794-95,pf,Keyboard,,,,,,,
# 2/3,—,—,87/3,,,,,,,
# Piano Sonata No.3,,,,,,,,,,
# C major,1794-95,pf,Keyboard,,,,,,,
# 3,—,—,105,String Trio,E♭ major,1794,vn va vc,Chamber,see also Op.64,
# 4,—,—,115,String Quintet,E♭ major,1795,2vn 2va vc,Chamber,based on Op.103, see also Op.63
# 5,—,—,106,Cello Sonatas (2),,1796,vc pf,Chamber,,
# 5/1,—,—,106/1,,,,,,,
# Cello Sonata No.1,,,,,,,,,,
# F major,1796,vc pf,Chamber,,,,,,,
# 5/2,—,—,106/2,,,,,,,
# ...

# %%
pd.read_csv(path)
# Out:
#                    Op.      WoO      Hess Biam-onti  \
# 0                  1/1        —         —      62/1
# 1           Piano Trio      NaN       NaN       NaN
# 2             E♭ major  1792-93  vn vc pf   Chamber
# 3                  1/2        —         —      62/2
# 4           Piano Trio      NaN       NaN       NaN
# 5              G major  1792-94  vn vc pf   Chamber
# 6                  1/3        —         —      62/3
# 7           Piano Trio      NaN       NaN       NaN
# 8              C minor  1792-94  vn vc pf   Chamber
# 9                    2        —         —        87
# 10                 2/1        —         —      87/1
# 11   Piano Sonata No.1      NaN       NaN       NaN
# 12             F minor  1793-95        pf  Keyboard
# 13                 2/2        —         —      87/2
# 14   Piano Sonata No.2      NaN       NaN       NaN
# 15             A major  1794-95        pf  Keyboard
# 16                 2/3        —         —      87/3
# ...

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (857, 11)

# %%
len(df)
# Out:
# 857

# %%
df.dtypes
# Out:
# Op.            object
# WoO            object
# Hess           object
# Biam-onti      object
# Title          object
# Key            object
# Date           object
# Scoring        object
# Genre          object
# Notes          object
# Unnamed: 10    object
# dtype: object

# %%
df.columns
# Out:
# Index(['Op.', 'WoO', 'Hess', 'Biam-onti', 'Title', 'Key', 'Date', 'Scoring',
#        'Genre', 'Notes', 'Unnamed: 10'],
#       dtype='object')

# %%
#df['Key'].count()
df['Key'].value_Counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ff9442c6272d> in <module>
#       1 #df['Key'].count()
# ----> 2 df['Key'].value_Counts()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_Counts'

# %%
#### bezeichnungen aendern
states = {
    'CA': 'California',
    'AR': 'Arkansas',
    'NV': 'Nevada',
    'TX': 'Texas',
    'AZ': 'Arizona',
    'FL': 'Florida',
    'OK': 'Oklahoma',
    'AL': 'Alabama',
    'PA': 'Pennsylvania',
    'OH': 'Ohio',
    'MS': 'Missouri',
    'MO': 'Montana',
    'ID': 'Idaho',
    'NE': 'Nebraska',
    'OKlahoma': 'Oklahoma'
}
df['state'].replace(states, inplace=True
# Out:
#   File "<ipython-input-20-99bcb0a21a81>", line 22
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
auswahl = ['Title', 'Key', 'Date']

# %%
df[auswahl].count()
# Out:
# Title    428
# Key      320
# Date     396
# dtype: int64

# %%
df.groupby(['Title', 'Key'])['Date'].sum()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in f(self, **kwargs)
#    1256                     return self._cython_agg_general(
# -> 1257                         alias, alt=npfunc, **kwargs)
#    1258                 except AssertionError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     837         if len(output) == 0:
# --> 838             raise DataError('No numeric types to aggregate')
#     839
#
# DataError: No numeric types to aggregate
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-80a9ba261ffe> in <module>
# ----> 1 df.groupby(['Title', 'Key'])['Date'].sum()
#       2
# ...

# %%
df.sort_values('Date', ascending=True)      #.head(50)['University'].value_counts()
# Out:
#                             Op.      WoO     Hess Biam-onti  \
# 856                           —        —        —         —
# 729                           —      107        —         7
# 607                           —       63        —         1
# 730                           —      108        —         9
# 591                           —       49        —         5
# 590                           —       48       51         4
# 580                           —       47        —         2
# 552                           —       31        —         6
# 510                           —        4        —        10
# 557                           —       36        —        12
# 568                           —       38        —        31
# 175                          52        —        —        34
# 567                           —       37        —        19
# 93                           19        —        —       166
# 138                          39        —        —       375
# ...

# %%
word = ('Key')
df['Key'].count()
# Out:
# 320

# %%
query = '(word1, word2)
word1 = 'major'
word2 = 'minor'
print(query)
# Out:
#   File "<ipython-input-29-579d53e6af46>", line 1
#     query = '(word1, word2)
#                            ^
# SyntaxError: EOL while scanning string literal
