# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
pathM = 'Werke_Mozart_Sheet1.csv'
with open(pathM) as table:
    dateiM = table.read()

# %%
pathB = 'Werke_Beethoven_Sheet1.csv'
with open(pathB) as table:
    dateiB = table.read()

# %%
dfM = pd.read_csv(pathM)

# %%
dfM
# Out:
#           K           K6                                 Title  \
# 0         —           1a                               Andante
# 1         —           1b                               Allegro
# 2         —           1c                               Allegro
# 3         —           1d                                Minuet
# 4         1           1e                                Minuet
# 5         —           1f                                Minuet
# 6         2            2                                Minuet
# 7         3            3                               Allegro
# 8         4            4                                Minuet
# 9         5            5                                Minuet
# 10       9a           5a                               Allegro
# 11       9b           5b                               Andante
# 12        6            6                 Violin Sonata("No.1")
# 13        7            7                 Violin Sonata("No.2")
# ...

# %%
dfB = pd.read_csv(pathB)

# %%
dfB
# Out:
#       Op.      WoO     Hess Biam-onti  \
# 0       1        —        —        62
# 1     1/1        —        —      62/1
# 2     1/2        —        —      62/2
# 3     1/3        —        —      62/3
# 4       2        —        —        87
# 5     2/1        —        —      87/1
# 6     2/2        —        —      87/2
# 7     2/3        —        —      87/3
# 8       3        —        —       105
# 9       4        —        —       115
# 10      5        —        —       106
# 11    5/1        —        —     106/1
# 12    5/2        —        —     106/2
# 13      6        —        —       134
# 14      7        —        —       136
# 15      8        —        —       135
# 16      9        —        —       153
# 17    9/1        —        —     153/1
# 18    9/2        —        —     153/2
# 19    9/3        —        —     153/3
# 20     10        —        —       157
# 21   10/1        —        —     157/1
# 22   10/2        —        —     157/2
# ...

# %%
dfM['KeyM'].value_counts(ascending=False).plot(kind='barh',figsize=(10, 8))

# %%
dfB['KeyB'].value_counts(ascending=False).plot(kind='barh',figsize=(10, 8), color='red')

# %%
###df.plot(kind='scatter', x='Key', y='????')

# %%
#df['Key'].value_counts(ascending=False).plot(kind='barh',figsize=(10, 8))

# %%
#ax = df1.plot()
#df2.plot(ax=ax)
