# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
path = 'Mozart_Sheet1.csv'

# %%
with open(path) as table:
    dateiinhalt = table.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-5dd29f44d5e9> in <module>
# ----> 1 with open(path) as table:
#       2     dateiinhalt = table.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Mozart_Sheet1.csv'

# %%
print(dateiinhalt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3987c0be5044> in <module>
# ----> 1 print(dateiinhalt)
#
# NameError: name 'dateiinhalt' is not defined

# %%
pd.read_csv(path)
# Out:
#           K           K6                                 Title  \
# 0         —           1a                               Andante
# 1         —           1b                               Allegro
# 2         —           1c                               Allegro
# 3         —           1d                                Minuet
# 4         1           1e                                Minuet
# 5         —           1f                                Minuet
# 6         2            2                                Minuet
# 7         3            3                               Allegro
# 8         4            4                                Minuet
# 9         5            5                                Minuet
# 10       9a           5a                               Allegro
# 11       9b           5b                               Andante
# 12        6            6                 Violin Sonata("No.1")
# 13        7            7                 Violin Sonata("No.2")
# 14        8            8                 Violin Sonata("No.3")
# 15        9            9                 Violin Sonata("No.4")
# 16       10           10                 Violin Sonata("No.5")
# 17       11           11                 Violin Sonata("No.6")
# 18       12           12                 Violin Sonata("No.7")
# 19       13           13                 Violin Sonata("No.8")
# 20       14           14                 Violin Sonata("No.9")
# 21       15           15                Violin Sonata("No.10")
# 22        —          15a                               Allegro
# 23        —          15b                             Andantino
# 24        —          15c                                Minuet
# 25        —          15d                                 Rondo
# 26        —          15e                         Country Dance
# 27        —          15f                                Minuet
# 28        —          15g                               Prelude
# 29        —          15h                         Country Dance
# ..      ...          ...                                   ...
# 736      93     Anh.A 22                  De profundis clamavi
# 737      18     Anh.A 51                         Symphony No.3
# 738     291     Anh.A 52                                 Fugue
# 739     140    Anh.C1.12                          Missa brevis
# 740     142    Anh.C3.04                           Tantum ergo
# 741     197    Anh.C3.05                           Tantum ergo
# 742     198    Anh.C3.08                   Sub tuum praesidium
# 743     177    Anh.C3.09                 Convertentur sedentes
# 744       —    Anh.C3.15                          Sancta Maria
# 745     350    Anh.C8.48  Wiegenlied("Schlafe mein Prinzchen")
# 746      17  Anh.C 11.02                         Symphony No.2
# 747      98  Anh.C 11.04                      Symphony F major
# 748     510  Anh.C 13.02      Country Dances (9)("Quadrilles")
# 749    297b  Anh.C 14.01                  Sinfonia concertante
# 750    297b  Anh.C 14.06         Oboe Concerto in E-flat major
# 751     187  Anh.C 17.12                  Divertimento("No.5")
# 752     268  Anh.C 14.04                       Violin Concerto
# 753      55  Anh.C 23.01                         Violin Sonata
# 754      56  Anh.C 23.02                         Violin Sonata
# 755      57  Anh.C 23.03                         Violin Sonata
# 756      58  Anh.C 23.04                         Violin Sonata
# 757      59  Anh.C 23.05                         Violin Sonata
# 758      60  Anh.C 23.06                         Violin Sonata
# 759      61  Anh.C 23.07                         Violin Sonata
# 760  498a/1  Anh.C 25.04                               Allegro
# 761  498a/3  Anh.C 25.05                                Minuet
# 762       —  Anh.C 27.03                              Fantasia
# 763       —  Anh.C 27.04                               Romance
# 764       —  Anh.C 27.10                                 Fugue
# 765      46            —                               Quintet
#
#                Forces      Key      Date       Genre  \
# 0                  pf  C major      1761    Keyboard
# 1                  pf  C major      1761    Keyboard
# 2                  pf  F major      1761    Keyboard
# 3                  pf  F major      1761    Keyboard
# 4                  pf  G major   1761–62    Keyboard
# 5                  pf  C major   1761–62    Keyboard
# 6                  pf  F major      1762    Keyboard
# 7                  pf  B♭major      1762    Keyboard
# 8                  pf  F major      1762    Keyboard
# 9                  pf  F major      1762    Keyboard
# 10                 pf  C major   1763–64    Keyboard
# 11                 pf  B♭major   1763–64    Keyboard
# 12              vn pf  C major   1762–63     Chamber
# 13              vn pf  D major   1763–64     Chamber
# 14              vn pf  B♭major      1763     Chamber
# 15              vn pf  G major      1764     Chamber
# 16        vn/fl vc pf  B♭major      1764     Chamber
# 17        vn/fl vc pf  G major      1764     Chamber
# 18        vn/fl vc pf  A major      1764     Chamber
# 19        vn/fl vc pf  F major      1764     Chamber
# 20        vn/fl vc pf  C major      1764     Chamber
# 21        vn/fl vc pf  B♭major      1764     Chamber
# 22                 pf  F major      1764    Keyboard
# 23                 pf  C major      1764    Keyboard
# 24                 pf  G major      1764    Keyboard
# 25                 pf  D major      1764    Keyboard
# 26                 pf  G major      1764    Keyboard
# 27                 pf  C major      1764    Keyboard
# 28                org  G major      1764    Keyboard
# 29                 pf  F major      1764    Keyboard
# ..                ...      ...       ...         ...
# 736            ch org  C major         —      Choral
# 737              orch  E♭major         —  Orchestral
# 738              orch  D major         —  Orchestral
# 739          4vv orch  G major     1770?       Vocal
# 740           ch orch  B♭major  1772–74?      Choral
# 741           ch orch  D major  1772–74?      Choral
# 742          2vv orch  F major     1774?       Vocal
# 743          2vv orch      NaN         —       Vocal
# 744  sop/ten org/harm  G major         —       Vocal
# 745              v pf      NaN         —       Vocal
# 746              orch  B♭major         —  Orchestral
# 747              orch  F major         —  Orchestral
# 748              orch      NaN     1787?  Orchestral
# 749  ob cl bn hn orch  E♭major     1778?  Orchestral
# 750  ob cl bn hn orch  E♭major         ?  Orchestral
# 751     2fl 5tpt timp  C major         —     Chamber
# 752           vn orch  E♭major     1790?  Orchestral
# 753             vn pf  C major         —     Chamber
# 754             vn pf  C major         —     Chamber
# 755             vn pf  C major         —     Chamber
# 756             vn pf  E♭major         —     Chamber
# 757             vn pf  C major         —     Chamber
# 758             vn pf  E minor         —     Chamber
# 759             vn pf  A major         —     Chamber
# 760                pf  B♭major         ?    Keyboard
# 761                pf  B♭major         ?    Keyboard
# 762               org  G minor      1787    Keyboard
# 763                pf  A♭major         ?    Keyboard
# 764                pf  E major         ?    Keyboard
# 765        2vn 2va vc  B♭major         —     Chamber
#
#                                                  Notes
# 0                                                  NaN
# 1                          No.2 inNannerl's Music Book
# 2                          No.3 inNannerl's Music Book
# 3                          No.4 inNannerl's Music Book
# 4                          No.5 inNannerl's Music Book
# 5                          No.6 inNannerl's Music Book
# 6                          No.7 inNannerl's Music Book
# 7                          No.8 inNannerl's Music Book
# 8                          No.9 inNannerl's Music Book
# 9                         No.10 inNannerl's Music Book
# 10                        No.11 inNannerl's Music Book
# 11            No.12 inNannerl's Music Book; incomplete
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 736                         spurious (byGeorg Reutter)
# 737                   spurious (byCarl Friedrich Abel)
# 738                         spurious (byMichael Haydn)
# 739                       Mozart's authorship doubtful
# 740                       Mozart's authorship doubtful
# 741                       Mozart's authorship doubtful
# 742                       Mozart's authorship doubtful
# 743                        spurious (byLeopold Mozart)
# 744                        spurious (composer unknown)
# 745                        spurious (byBernhard Flies)
# 746                        spurious (byLeopold Mozart)
# 747                                           doubtful
# 748                       Mozart's authorship doubtful
# 749                       Mozart's authorship doubtful
# 750                       Mozart's authorship doubtful
# 751                        spurious (composer unknown)
# 752                       Mozart's authorship doubtful
# 753                        spurious (composer unknown)
# 754                        spurious (composer unknown)
# 755                        spurious (composer unknown)
# 756                        spurious (composer unknown)
# 757                        spurious (composer unknown)
# 758                        spurious (composer unknown)
# 759             spurious (byHermann Friedrich Raupach)
# 760  published as part of spuriousPiano Sonata in B...
# 761  published as part of spuriousPiano Sonata in B...
# 762                                         incomplete
# 763           incomplete; Mozart's authorship doubtful
# 764                                         incomplete
# 765  spurious, anonymous arrangement of parts of K....
#
# [766 rows x 8 columns]

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (766, 8)

# %%
len(df)
# Out:
# 766

# %%
df.dtypes
# Out:
# K         object
# K6        object
# Title     object
# Forces    object
# Key       object
# Date      object
# Genre     object
# Notes     object
# dtype: object

# %%
df.columns
# Out:
# Index(['K', 'K6', 'Title', 'Forces', 'Key', 'Date', 'Genre', 'Notes'], dtype='object')

# %%
#df['Key'].count()
df['Key'].value_Counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-ff9442c6272d> in <module>
#       1 #df['Key'].count()
# ----> 2 df['Key'].value_Counts()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_Counts'

# %%
#### bezeichnungen aendern
states = {
    'CA': 'California',
    'AR': 'Arkansas',
    'NV': 'Nevada',
    'TX': 'Texas',
    'AZ': 'Arizona',
    'FL': 'Florida',
    'OK': 'Oklahoma',
    'AL': 'Alabama',
    'PA': 'Pennsylvania',
    'OH': 'Ohio',
    'MS': 'Missouri',
    'MO': 'Montana',
    'ID': 'Idaho',
    'NE': 'Nebraska',
    'OKlahoma': 'Oklahoma'
}
df['state'].replace(states, inplace=True
# Out:
#   File "<ipython-input-43-99bcb0a21a81>", line 22
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
auswahl = ['Title', 'Key', 'Date']

# %%
df[auswahl].count()
# Out:
# Title    766
# Key      687
# Date     766
# dtype: int64

# %%
df.groupby(['Title', 'Key'])['Date'].sum()
# Out:
# Title                                         Key
# 3 String Trios                                E♭major                —
# A questo seno deh vieni("Or che il cielo")    E♭major             1781
# Abendempfindung("Abend ist's")                F major             1787
# Adagio                                        B minor             1788
#                                               B♭major          1783–84
#                                               C major     1783–85?1791
#                                               D minor        1786?1790
#                                               E major             1776
#                                               F major    1787–89?1785?
# Adagio and Allegro                            F minor             1790
# Adagio and Fugue                              C minor             1788
# Adagio and Rondo                              C minor             1791
# Adoramus te                                   C minor                —
# Ah se in ciel                                 F major             1788
# Ah, lo previdi                                C minor             1777
# Ah, più tremar non voglio                     F major             1769
# Ah, spiegarti, oh Dio                         A major             1783
# Al desio, di chi t'adora                      F major             1789
# Alcandro, Io confesso("Non só d'onde viene")  F major             1787
# Allegretto                                    B♭major             1790
# Allegro                                       B♭major    176217811782?
#                                               C major      17611763–64
#                                               C minor          1785–86
#                                               F major         17611764
#                                               G major          1769–70
#                                               G minor             1790
# Allegro assai                                 B♭major            1786?
# Allegro("Symphony No.51")                     D major             1775
# Allemande                                     B♭major             1764
# Alma Dei creatoris                            F major             1777
#                                                              ...
# Violin Sonata("No.2")                         D major          1763–64
# Violin Sonata("No.20")                        C major             1778
# Violin Sonata("No.21")                        E minor             1778
# Violin Sonata("No.22")                        A major             1778
# Violin Sonata("No.23")                        D major             1778
# Violin Sonata("No.24")                        F major             1781
# Violin Sonata("No.25")                        F major             1781
# Violin Sonata("No.26")                        B♭major             1779
# Violin Sonata("No.27")                        G major             1781
# Violin Sonata("No.28")                        E♭major             1781
# Violin Sonata("No.29")                        A major         1781–82?
# Violin Sonata("No.3")                         B♭major             1763
# Violin Sonata("No.30")                        C major             1784
# Violin Sonata("No.31")                        C major         1785–86?
# Violin Sonata("No.32" or "For Beginners ")    F major             1788
# Violin Sonata("No.32")                        B♭major             1784
# Violin Sonata("No.33")                        E♭major             1785
# Violin Sonata("No.35")                        A major             1787
# Violin Sonata("No.4")                         G major             1764
# Violin Sonata("No.5")                         B♭major             1764
# Violin Sonata("No.6")                         G major             1764
# Violin Sonata("No.7")                         A major             1764
# Violin Sonata("No.8")                         F major             1764
# Violin Sonata("No.9")                         C major             1764
# Voi avete un cor fedele                       G major             1775
# Vorrei spiegarvi, oh Dio                      A major             1783
# Warnung("Männer suchen stets zu naschen")     F major             1783
# Welch ängstliches Beben                       E♭major          1781–82
# Wie unglucklich bin ich nit                   F major             1772
# Zerfliesset heut', geliebte Brüder            B♭major             1785
# Name: Date, Length: 607, dtype: object

# %%
df.sort_values('Date', ascending=True)      #.head(50)['University'].value_counts()
# Out:
#            K           K6                                 Title  \
# 0          —           1a                               Andante
# 1          —           1b                               Allegro
# 2          —           1c                               Allegro
# 3          —           1d                                Minuet
# 4          1           1e                                Minuet
# 5          —           1f                                Minuet
# 6          2            2                                Minuet
# 7          3            3                               Allegro
# 8          4            4                                Minuet
# 9          5            5                                Minuet
# 12         6            6                 Violin Sonata("No.1")
# 14         8            8                 Violin Sonata("No.3")
# 13         7            7                 Violin Sonata("No.2")
# 10        9a           5a                               Allegro
# 11        9b           5b                               Andante
# 38         —          15r                               Andante
# 33         —          15m                                Minuet
# 34         —          15n                               Andante
# 35         —          15o                               Andante
# 36         —          15p                          Piano Sonata
# 37         —          15q                               Andante
# 39         —          15s                                 Rondo
# 46         —          15z                                Gigues
# 41         —          15u                            Sicilianos
# 42         —          15v                          Piano Sonata
# 43         —          15w                             Allemande
# 44         —          15x                          Piano Sonata
# 45         —          15y                                Minuet
# 32         —          15l                         Country Dance
# 40         —          15t                          Piano Sonata
# ..       ...          ...                                   ...
# 760   498a/1  Anh.C 25.04                               Allegro
# 761   498a/3  Anh.C 25.05                                Minuet
# 764        —  Anh.C 27.10                                 Fugue
# 757       59  Anh.C 23.05                         Violin Sonata
# 756       58  Anh.C 23.04                         Violin Sonata
# 755       57  Anh.C 23.03                         Violin Sonata
# 754       56  Anh.C 23.02                         Violin Sonata
# 753       55  Anh.C 23.01                         Violin Sonata
# 751      187  Anh.C 17.12                  Divertimento("No.5")
# 166      115         166d                          Missa brevis
# 759       61  Anh.C 23.07                         Violin Sonata
# 758       60  Anh.C 23.06                         Violin Sonata
# 184      150         125e                         Geheime Liebe
# 746       17  Anh.C 11.02                         Symphony No.2
# 285      288         246c                          Divertimento
# 510  Anh.163            —                        3 String Trios
# 733      221       Anh.A1                                 Kyrie
# 734   Anh.21       Anh.A2                             Lacrimosa
# 735      327     Anh.A 10                           Adoramus te
# 736       93     Anh.A 22                  De profundis clamavi
# 747       98  Anh.C 11.04                      Symphony F major
# 737       18     Anh.A 51                         Symphony No.3
# 259      152         210a                      Ridente la calma
# 183      149         125d          Die grossmütige Gelassenheit
# 167      116          90a                          Missa brevis
# 743      177    Anh.C3.09                 Convertentur sedentes
# 744        —    Anh.C3.15                          Sancta Maria
# 745      350    Anh.C8.48  Wiegenlied("Schlafe mein Prinzchen")
# 738      291     Anh.A 52                                 Fugue
# 765       46            —                               Quintet
#
#                Forces      Key     Date       Genre  \
# 0                  pf  C major     1761    Keyboard
# 1                  pf  C major     1761    Keyboard
# 2                  pf  F major     1761    Keyboard
# 3                  pf  F major     1761    Keyboard
# 4                  pf  G major  1761–62    Keyboard
# 5                  pf  C major  1761–62    Keyboard
# 6                  pf  F major     1762    Keyboard
# 7                  pf  B♭major     1762    Keyboard
# 8                  pf  F major     1762    Keyboard
# 9                  pf  F major     1762    Keyboard
# 12              vn pf  C major  1762–63     Chamber
# 14              vn pf  B♭major     1763     Chamber
# 13              vn pf  D major  1763–64     Chamber
# 10                 pf  C major  1763–64    Keyboard
# 11                 pf  B♭major  1763–64    Keyboard
# 38                 pf  G minor     1764    Keyboard
# 33                 pf  F major     1764    Keyboard
# 34                 pf  C major     1764    Keyboard
# 35                 pf  D major     1764    Keyboard
# 36                 pf  G minor     1764    Keyboard
# 37                 pf  B♭major     1764    Keyboard
# 39                 pf  C major     1764    Keyboard
# 46                 pf  C minor     1764    Keyboard
# 41                 pf  D minor     1764    Keyboard
# 42                 pf  F major     1764    Keyboard
# 43                 pf  B♭major     1764    Keyboard
# 44                 pf  F major     1764    Keyboard
# 45                 pf  G major     1764    Keyboard
# 32                 pf  A major     1764    Keyboard
# 40                 pf  F major     1764    Keyboard
# ..                ...      ...      ...         ...
# 760                pf  B♭major        ?    Keyboard
# 761                pf  B♭major        ?    Keyboard
# 764                pf  E major        ?    Keyboard
# 757             vn pf  C major        —     Chamber
# 756             vn pf  E♭major        —     Chamber
# 755             vn pf  C major        —     Chamber
# 754             vn pf  C major        —     Chamber
# 753             vn pf  C major        —     Chamber
# 751     2fl 5tpt timp  C major        —     Chamber
# 166            ch org  C major        —      Choral
# 759             vn pf  A major        —     Chamber
# 758             vn pf  E minor        —     Chamber
# 184              v pf  G major        —       Vocal
# 746              orch  B♭major        —  Orchestral
# 285              orch  F major        —  Orchestral
# 510          vn va vc  E♭major        —     Chamber
# 733             ch bc  C major        —      Choral
# 734             ch bc  C minor        —      Choral
# 735             ch bc  C minor        —      Choral
# 736            ch org  C major        —      Choral
# 747              orch  F major        —  Orchestral
# 737              orch  E♭major        —  Orchestral
# 259              v pf  F major        —       Vocal
# 183              v pf  B♭major        —       Vocal
# 167            ch org  F major        —      Choral
# 743          2vv orch      NaN        —       Vocal
# 744  sop/ten org/harm  G major        —       Vocal
# 745              v pf      NaN        —       Vocal
# 738              orch  D major        —  Orchestral
# 765        2vn 2va vc  B♭major        —     Chamber
#
#                                                  Notes
# 0                                                  NaN
# 1                          No.2 inNannerl's Music Book
# 2                          No.3 inNannerl's Music Book
# 3                          No.4 inNannerl's Music Book
# 4                          No.5 inNannerl's Music Book
# 5                          No.6 inNannerl's Music Book
# 6                          No.7 inNannerl's Music Book
# 7                          No.8 inNannerl's Music Book
# 8                          No.9 inNannerl's Music Book
# 9                         No.10 inNannerl's Music Book
# 12                                                 NaN
# 14                                                 NaN
# 13                                                 NaN
# 10                        No.11 inNannerl's Music Book
# 11            No.12 inNannerl's Music Book; incomplete
# 38                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 39                                                 NaN
# 46                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 32                                                 NaN
# 40                                                 NaN
# ..                                                 ...
# 760  published as part of spuriousPiano Sonata in B...
# 761  published as part of spuriousPiano Sonata in B...
# 764                                         incomplete
# 757                        spurious (composer unknown)
# 756                        spurious (composer unknown)
# 755                        spurious (composer unknown)
# 754                        spurious (composer unknown)
# 753                        spurious (composer unknown)
# 751                        spurious (composer unknown)
# 166                        spurious (byLeopold Mozart)
# 759             spurious (byHermann Friedrich Raupach)
# 758                        spurious (composer unknown)
# 184                        spurious (byLeopold Mozart)
# 746                        spurious (byLeopold Mozart)
# 285                                         incomplete
# 510  Arranged from K.454, K.481 and K.533. Not comp...
# 733                  spurious (byJohann Ernst Eberlin)
# 734                  spurious (byJohann Ernst Eberlin)
# 735                   spurious (byFrancesco Gasparini)
# 736                         spurious (byGeorg Reutter)
# 747                                           doubtful
# 737                   spurious (byCarl Friedrich Abel)
# 259                      spurious (byJosef Mysliveček)
# 183                        spurious (byLeopold Mozart)
# 167                        spurious (byLeopold Mozart)
# 743                        spurious (byLeopold Mozart)
# 744                        spurious (composer unknown)
# 745                        spurious (byBernhard Flies)
# 738                         spurious (byMichael Haydn)
# 765  spurious, anonymous arrangement of parts of K....
#
# [766 rows x 8 columns]

# %%
word = ('Key')
df['Key'].count()
# Out:
# 687

# %%
query = '(word1, word2)
word1 = 'major'
word2 = 'minor'
print(query)
# Out:
#   File "<ipython-input-77-579d53e6af46>", line 1
#     query = '(word1, word2)
#                            ^
# SyntaxError: EOL while scanning string literal
