# %%
import camelot
import tabula

# %%
import os
import tqdm
import textract
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
#    https://europawahlergebnis.eu/sitze-fraktion-land/2019-2024/

# %%
path_1 = ('Sitze_nach_Fraktion/1979-1984.csv')

# %%
with open(path_1) as f:
    inhalt_1 = f.read()

# %%
df_1 = pd.read_csv(path_1)

# %%
df_1
# Out:
#                      Land    S    PPE    ED   COM     L   DEP   CDI    NI  \
# 0                 Belgien    7   10.0   NaN   NaN   4.0   NaN   1.0   2.0
# 1                Dänemark    4    NaN   2.0   1.0   3.0   1.0   4.0   1.0
# 2             Deutschland   35   42.0   NaN   NaN   4.0   NaN   NaN   NaN
# 3              Frankreich   21    9.0   NaN  19.0  17.0  15.0   NaN   NaN
# 4                  Irland    4    4.0   NaN   NaN   1.0   5.0   1.0   NaN
# 5                 Italien   13   30.0   NaN  24.0   5.0   NaN   5.0   4.0
# 6               Luxemburg    1    3.0   NaN   NaN   2.0   NaN   NaN   NaN
# 7             Niederlande    9   10.0   NaN   NaN   4.0   NaN   NaN   2.0
# 8  Vereinigtes Königreich   18    NaN  61.0   NaN   NaN   1.0   NaN   1.0
# 9       Europäische Union  112  108.0  63.0  44.0  40.0  22.0  11.0  10.0
#
#    Anzahl der Sitze
# 0                24
# 1                16
# 2                81
# 3                81
# 4                15
# 5                81
# ...

# %%
df_1b = df_1.swapaxes("index", "columns")

# %%
df_1b
# Out:
#                         0         1            2           3       4        5  \
# Land              Belgien  Dänemark  Deutschland  Frankreich  Irland  Italien
# S                       7         4           35          21       4       13
# PPE                    10       NaN           42           9       4       30
# ED                    NaN         2          NaN         NaN     NaN      NaN
# COM                   NaN         1          NaN          19     NaN       24
# L                       4         3            4          17       1        5
# DEP                   NaN         1          NaN          15       5      NaN
# CDI                     1         4          NaN         NaN       1        5
# NI                      2         1          NaN         NaN     NaN        4
# Anzahl der Sitze       24        16           81          81      15       81
#
#                           6            7                       8  \
# ...

# %%
df_1.dtypes
# Out:
# Land                 object
# S                     int64
# PPE                 float64
# ED                  float64
# COM                 float64
# L                   float64
# DEP                 float64
# CDI                 float64
# NI                  float64
# Anzahl der Sitze      int64
# dtype: object

# %% [markdown]
# #convert Series
# my_series = pd.to_numeric(my_series)
#
# #convert column "a" of a DataFrame
# df["a"] = pd.to_numeric(df["a"])
#
# #convert all columns of DataFrame
# df = df.apply(pd.to_numeric) # convert all columns of DataFrame
#
# #convert just columns "a" and "b"
# df[["a", "b"]] = df[["a", "b"]].apply(pd.to_numeric)

# %%
df_1c = df_1[["S","PPE","ED","COM","L","DEP","CDI","NI"]].apply(pd.to_numeric)

# %%
####df_1d = df_1.groupby("Land")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-4cb3f7b05449> in <module>
# ----> 1 df_1d = df_1.groupby("Land", df_1c)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7627         if level is None and by is None:
#    7628             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7629         axis = self._get_axis_number(axis)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     349     @classmethod
#     350     def _get_axis_number(cls, axis):
# --> 351         axis = cls._AXIS_ALIASES.get(axis, axis)
# ...

# %%
df_1c
# Out:
#      S    PPE    ED   COM     L   DEP   CDI    NI
# 0    7   10.0   NaN   NaN   4.0   NaN   1.0   2.0
# 1    4    NaN   2.0   1.0   3.0   1.0   4.0   1.0
# 2   35   42.0   NaN   NaN   4.0   NaN   NaN   NaN
# 3   21    9.0   NaN  19.0  17.0  15.0   NaN   NaN
# 4    4    4.0   NaN   NaN   1.0   5.0   1.0   NaN
# 5   13   30.0   NaN  24.0   5.0   NaN   5.0   4.0
# 6    1    3.0   NaN   NaN   2.0   NaN   NaN   NaN
# 7    9   10.0   NaN   NaN   4.0   NaN   NaN   2.0
# 8   18    NaN  61.0   NaN   NaN   1.0   NaN   1.0
# 9  112  108.0  63.0  44.0  40.0  22.0  11.0  10.0

# %%
df_1.plot()
