# %%
import nltk
from nltk.tokenize import word_tokenize
import pandas as pd

# %%
maerchen = '''Hans Christian Andersen
Sämtliche Märchen, 1862
Das kleine Mädchen mit den Schwefelhölzchen

Es war entsetzlich kalt; es schneite und war beinahe schon ganz dunkel und Abend, der letzte Abend des Jahres.
In dieser Kälte und Finsterniß ging auf der Straße ein kleines, armes Mädchen, mit bloßem Kopfe und nackten Füßen. Als sie das Haus verließ, hatte sie freilich Pantoffeln angehabt: aber was half das? Es waren sehr große Pantoffeln gewesen, die ihre Mutter bisher benutzt hatte, so groß waren sie. Die Kleine aber verlor dieselben, als sie über die Straße weg huschte, weil zwei Wagen schrecklich schnell vorüberrollten. Der eine Pantoffel war nicht wieder zu finden, den andern hatte ein Junge erwischt und lief damit fort; er meinte, er könne ihn recht gut als Wiege benutzen, wenn er selbst erst Kinder hätte.
Da ging nun das kleine Mädchen mit den kleinen, nackten Füßen, die ganz rot und blau vor Kälte waren. In einer alten Schürze trug sie eine Menge Schwefelhölzer und ein Bund davon in der Hand. Niemand hatte den ganzen langen Tag ihr etwas abgekauft, Niemand ihr einen Pfennig geschenkt.
Zitternd vor Kälte und Hunger schlich sie einher, ein Bild des Jammers, die arme Kleine!
Die Schneeflocken bedeckten ihr langes, blondes Haar, welches in schönen Locken um den Hals fiel; aber daran dachte sie nun freilich nicht.
Aus allen Fenstern glänzten die Lichter, und es roch ganz herrlich nach Gänsebraten: es war ja Sylvesterabend. Ja, daran dachte sie!
In einem Winkel, von zwei Häusern gebildet, von denen das eine etwas mehr vorsprang als das andere, setzte sie sich hin und kauerte sich zusammen. Die kleinen Füße hatte sie an sich gezogen; aber es fror sie noch mehr, und nach Hause zu gehen wagte sie nicht: sie hatte ja keine Schwefelhölzchen verkauft und brachte keinen Pfennig Geld.
Von ihrem Vater würde sie gewiß Schläge bekommen, und zu Hause war es auch kalt; über sich hatten sie nur das Dach, durch welches der Wind pfiff, wenn auch die größten Spalten mit Stroh und Lumpen zugestopft waren.
Ihre kleinen Hände waren beinahe vor Kälte erstarrt.
Ach! ein Schwefelhölzchen konnte ihr gar wohl thun, wenn sie nur ein einziges aus dem Bunde herausziehen, es an die Wand streichen und sich die Finger erwärmen dürfte.
Sie zog eins heraus. Rrscht! wie sprühte, wie brannte es! Es war eine warme, helle Flamme, wie ein Lichtchen, als sie die Hände darüber hielt; es war ein wunderbares Lichtchen! Es schien wirklich dem kleinen Mädchen, als säße sie vor einem großen, eisernen Ofen mit polirten Messingfüßen und einem messingenen Aufsatze. Das Feuer brannte so gesegnet, es wärmte so schön; die Kleine streckte schon die Füße aus, um auch diese zu wärmen; - doch - da erlosch das Flämmchen, der Ofen verschwand, sie hatte nur die kleinen Ueberreste des abgebrannten Schwefelhölzchens in der Hand.
Ein zweites wurde an der Wand abgestrichen; es leuchtete, und wo der Schein auf die Mauer fiel, wurde diese durchsichtig wie ein Schleier: sie konnte in das Zimmer hineinsehen.
Auf dem Tische war ein schneeweißes Tischtuch ausgebreitet, darauf stand glänzendes Porzellangeschirr, und herrlich dampfte die gebratene Gans, mit Aepfeln und getrockneten Pflaumen gefüllt. Und was noch prächtiger anzusehen war: die Gans hüpfte von der Schüssel herunter und wackelte auf dem Fußboden, Messer und Gabel in der Brust, bis zu dem armen Mädchen hin.
Da erlosch das Schwefelhölzchen, und es blieb nur die dicke, feuchtkalte Mauer zurück.
Sie zündete noch ein Hölzchen an. Da saß sie nun unter dem herrlichsten Christbaume; er war noch größer und geputzter als der, den sie durch die Glasthüre bei dem reichen Kaufmanne gesehen hatte. Tausende von Lichterchen brannten auf den grünen Zweigen, und bunte Bilder, wie sie an Schaufenstern zu sehen waren, blickten auf sie herab. Die Kleine streckte ihre Hände danach aus: da erlosch das Schwefelhölzchen.
Die Weihnachtslichter stiegen höher und höher; sie sah sie jetzt als Sterne am Himmel; einer davon fiel herunter und bildete einen langen Feuerstreifen.
"Jetzt stirbt Jemand!" dachte das kleine Mädchen, denn ihre alte Großmutter, die Einzige, die sie lieb gehabt hatte, und die jetzt gestorben war, hatte ihr erzählt, daß, wenn ein Stern herunterfällt, eine Seele zu Gott emporsteigt.
Sie strich wieder ein Hölzchen an der Mauer ab, es wurde wieder hell, und in dem Glanze stand die alte Großmutter so klar und schimmernd, so mild und liebevoll.
"Großmutter!" rief die Kleine. "O! nimm mich mit! Ich weiß, Du entfernst Dich, wenn das Schwefelhölzchen erlischt; Du verschwindest, wie der warme Ofen, wie der herrliche Gänsebraten und der große, prächtige Weihnachtsbaum!"
Und sie strich schnell das ganze Bund Schwefelhölzchen, denn sie wollte die Großmutter recht fest halten.
Und die Schwefelhölzchen leuchteten mit einem solchen Glanze, daß es heller wurde, als mitten am Tage; die Großmutter war nie früher so schön, so groß gewesen; sie nahm das kleine Mädchen auf ihre Arme, und Beide flogen in Glanz und Freude so hoch, so hoch; und dort war weder Kälte, noch Hunger, noch Angst - sie waren bei Gott.
Aber im Winkel an die Mauer gelehnt, saß in der kalten Morgenstunde das arme Mädchen mit rothen Backen und mit lächelndem Munde - erfroren an des alten Jahres letztem Abend.
Die Neujahrssonne ging auf über der kleinen Leiche.
Starr saß das Kind dort mit den Schwefelhölzchen, von denen ein Bund abgebrannt war.
"Sie hat sich erwärmen wollen!" sagte man.
Niemand ahnte, was sie Schönes gesehen hatte, in welchem Glanze sie mit der Großmutter zur Neujahrsfreude eingegangen war.

Hans Christian Andersen (1805-1875)
'''

# %%
tokens = word_tokenize(maerchen)
#tokens = [word.lower() for word in tokens if word.isalpha()]
tokens = [word for word in tokens if word.isalpha()]

maerchen_clean = (" ").join(tokens)
#tokens
maerchen_clean  #text ohne satzzeichen in kleinbuchstaben
# Out:
# 'Hans Christian Andersen Sämtliche Märchen Das kleine Mädchen mit den Schwefelhölzchen Es war entsetzlich kalt es schneite und war beinahe schon ganz dunkel und Abend der letzte Abend des Jahres In dieser Kälte und Finsterniß ging auf der Straße ein kleines armes Mädchen mit bloßem Kopfe und nackten Füßen Als sie das Haus verließ hatte sie freilich Pantoffeln angehabt aber was half das Es waren sehr große Pantoffeln gewesen die ihre Mutter bisher benutzt hatte so groß waren sie Die Kleine aber verlor dieselben als sie über die Straße weg huschte weil zwei Wagen schrecklich schnell vorüberrollten Der eine Pantoffel war nicht wieder zu finden den andern hatte ein Junge erwischt und lief damit fort er meinte er könne ihn recht gut als Wiege benutzen wenn er selbst erst Kinder hätte Da ging nun das kleine Mädchen mit den kleinen nackten Füßen die ganz rot und blau vor Kälte waren In einer alten Schürze trug sie eine Menge Schwefelhölzer und ein Bund davon in der Hand Niemand hatte den ganzen langen Tag ihr etwas abgekauft Niemand ihr einen Pfennig geschenkt Zitternd vor Kälte und Hunger schlich sie einher ein Bild des Jammers die arme Kleine Die Schneeflocken bedeckten ihr langes blondes Haar welches in schönen Locken um den Hals fiel aber daran dachte sie nun freilich nicht Aus allen Fenstern glänzten die Lichter und es roch ganz herrlich nach Gänsebraten es war ja Sylvesterabend Ja daran dachte sie In einem Winkel von zwei Häusern gebildet von denen das eine etwas mehr vorsprang als das andere setzte sie sich hin und kauerte sich zusammen Die kleinen Füße hatte sie an sich gezogen aber es fror sie noch mehr und nach Hause zu gehen wagte sie nicht sie hatte ja keine Schwefelhölzchen verkauft und brachte keinen Pfennig Geld Von ihrem Vater würde sie gewiß Schläge bekommen und zu Hause war es auch kalt über sich hatten sie nur das Dach durch welches der Wind pfiff wenn auch die größten Spalten mit Stroh und Lumpen zugestopft waren Ihre kleinen Hände waren beinahe vor Kälte erstarrt Ach ein Schwefelhölzchen konnte ihr gar wohl thun wenn sie nur ein einziges aus dem Bunde herausziehen es an die Wand streichen und sich die Finger erwärmen dürfte Sie zog eins heraus Rrscht wie sprühte wie brannte es Es war eine warme helle Flamme wie ein Lichtchen als sie die Hände darüber hielt es war ein wunderbares Lichtchen Es schien wirklich dem kleinen Mädchen als säße sie vor einem großen eisernen Ofen mit polirten Messingfüßen und einem messingenen Aufsatze Das Feuer brannte so gesegnet es wärmte so schön die Kleine streckte schon die Füße aus um auch diese zu wärmen doch da erlosch das Flämmchen der Ofen verschwand sie hatte nur die kleinen Ueberreste des abgebrannten Schwefelhölzchens in der Hand Ein zweites wurde an der Wand abgestrichen es leuchtete und wo der Schein auf die Mauer fiel wurde diese durchsichtig wie ein Schleier sie konnte in das Zimmer hineinsehen Auf dem Tische war ein schneeweißes Tischtuch ausgebreitet darauf stand glänzendes Porzellangeschirr und herrlich dampfte die gebratene Gans mit Aepfeln und getrockneten Pflaumen gefüllt Und was noch prächtiger anzusehen war die Gans hüpfte von der Schüssel herunter und wackelte auf dem Fußboden Messer und Gabel in der Brust bis zu dem armen Mädchen hin Da erlosch das Schwefelhölzchen und es blieb nur die dicke feuchtkalte Mauer zurück Sie zündete noch ein Hölzchen an Da saß sie nun unter dem herrlichsten Christbaume er war noch größer und geputzter als der den sie durch die Glasthüre bei dem reichen Kaufmanne gesehen hatte Tausende von Lichterchen brannten auf den grünen Zweigen und bunte Bilder wie sie an Schaufenstern zu sehen waren blickten auf sie herab Die Kleine streckte ihre Hände danach aus da erlosch das Schwefelhölzchen Die Weihnachtslichter stiegen höher und höher sie sah sie jetzt als Sterne am Himmel einer davon fiel herunter und bildete einen langen Feuerstreifen Jetzt stirbt Jemand dachte das kleine Mädchen denn ihre alte Großmutter die Einzige die sie lieb gehabt h ...

# %%
from textblob_de import TextBlobDE
from textblob_de import PatternParser
blob = TextBlobDE(maerchen_clean, parser=PatternParser(pprint=False, lemmata=True))
blob.parse()
list(blob.words.lemmatize())[0:20]
# Out:
# ['Hans',
#  'Christian',
#  'Andersen',
#  'Sämtlich',
#  'Märchen',
#  'Das',
#  'klein',
#  'Mädchen',
#  'mit',
#  'den',
#  'Schwefelhölzchen',
#  'Es',
#  'war',
#  'entsetzlich',
#  'kalt',
#  'es',
#  'schneite',
#  'und',
#  'sein',
#  'beinahe']

# %%
blob = TextBlobDE(maerchen_clean, parser=PatternParser(pprint=False, lemmata=True))
blob.tags
# Out:
# [('Hans', 'NNP'),
#  ('Christian', 'NNP'),
#  ('Andersen', 'NNP'),
#  ('Sämtliche', 'JJ'),
#  ('Märchen', 'NN'),
#  ('Das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('den', 'DT'),
#  ('Schwefelhölzchen', 'VB'),
#  ('Es', 'PRP'),
#  ('war', 'RB'),
#  ('entsetzlich', 'JJ'),
#  ('kalt', 'JJ'),
#  ('es', 'PRP'),
#  ('schneite', 'NN'),
#  ('und', 'CC'),
#  ('war', 'VB'),
#  ('beinahe', 'RB'),
#  ('schon', 'RB'),
#  ('ganz', 'RB'),
#  ('dunkel', 'JJ'),
#  ('und', 'CC'),
#  ('Abend', 'NN'),
#  ('der', 'DT'),
#  ('letzte', 'JJ'),
#  ('Abend', 'NN'),
#  ('des', 'DT'),
#  ('Jahres', 'NN'),
#  ('In', 'IN'),
#  ('dieser', 'DT'),
#  ('Kälte', 'NN'),
#  ('und', 'CC'),
#  ('Finsterniß', 'NN'),
#  ('ging', 'VB'),
#  ('auf', 'IN'),
#  ('der', 'DT'),
#  ('Straße', 'NN'),
#  ('ein', 'DT'),
#  ('kleines', 'JJ'),
#  ('armes', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('bloßem', 'NN'),
#  ('Kopfe', 'NN'),
#  ('und', 'CC'),
#  ('nackten', 'JJ'),
#  ('Füßen', 'NNP'),
#  ('Als', 'IN'),
#  ('sie', 'PRP'),
#  ('das', 'DT'),
#  ('Haus', 'NN'),
#  ('verließ', 'NN'),
#  ('hatte', 'VB'),
#  ('sie', 'PRP'),
#  ('freilich', 'IN'),
#  ('Pantoffeln', 'NN'),
#  ('angehabt', 'NN'),
#  ('aber', 'VB'),
#  ('was', 'DT'),
#  ('half', 'VB'),
#  ('das', 'DT'),
#  ('Es', 'PRP$'),
#  ('waren', 'VB'),
#  ('sehr', 'RB'),
#  ('große', 'JJ'),
#  ('Pantoffeln', 'NN'),
#  ('gewesen', 'VBN'),
#  ('die', 'DT'),
#  ('ihre', 'PRP$'),
#  ('Mutter', 'NN'),
#  ('bisher', 'RB'),
#  ('benutzt', 'VBN'),
#  ('hatte', 'VB'),
#  ('so', 'RB'),
#  ('groß', 'JJ'),
#  ('waren', 'VB'),
#  ('sie', 'PRP'),
#  ('Die', 'DT'),
#  ('Kleine', 'NN'),
#  ('aber', 'IN'),
#  ('verlor', 'NN'),
#  ('dieselben', 'DT'),
#  ('als', 'IN'),
#  ('sie', 'PRP'),
#  ('über', 'IN'),
#  ('die', 'DT'),
#  ('Straße', 'NN'),
#  ('weg', 'IN'),
#  ('huschte', 'NN'),
#  ('weil', 'IN'),
#  ('zwei', 'CD'),
#  ('Wagen', 'NN'),
#  ('schrecklich', 'JJ'),
#  ('schnell', 'JJ'),
#  ('vorüberrollten', 'NN'),
#  ('Der', 'DT'),
#  ('eine', 'DT'),
#  ('Pantoffel', 'NN'),
#  ('war', 'VB'),
#  ('nicht', 'RB'),
#  ('wieder', 'RB'),
#  ('zu', 'TO'),
#  ('finden', 'VB'),
#  ('den', 'DT'),
#  ('andern', 'DT'),
#  ('hatte', 'VB'),
#  ('ein', 'DT'),
#  ('Junge', 'NN'),
#  ('erwischt', 'NN'),
#  ('und', 'CC'),
#  ('lief', 'VB'),
#  ('damit', 'RB'),
#  ('fort', 'RP'),
#  ('er', 'PRP'),
#  ('meinte', 'VB'),
#  ('er', 'PRP'),
#  ('könne', 'RB'),
#  ('ihn', 'PRP'),
#  ('recht', 'VB'),
#  ('gut', 'JJ'),
#  ('als', 'IN'),
#  ('Wiege', 'NN'),
#  ('benutzen', 'VB'),
#  ('wenn', 'IN'),
#  ('er', 'JJ'),
#  ('selbst', 'JJ'),
#  ('erst', 'IN'),
#  ('Kinder', 'NN'),
#  ('hätte', 'VB'),
#  ('Da', 'RB'),
#  ('ging', 'VBN'),
#  ('nun', 'RB'),
#  ('das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('den', 'DT'),
#  ('kleinen', 'JJ'),
#  ('nackten', 'JJ'),
#  ('Füßen', 'NN'),
#  ('die', 'DT'),
#  ('ganz', 'RB'),
#  ('rot', 'JJ'),
#  ('und', 'CC'),
#  ('blau', 'JJ'),
#  ('vor', 'IN'),
#  ('Kälte', 'NN'),
#  ('waren', 'VB'),
#  ('In', 'IN'),
#  ('einer', 'DT'),
#  ('alten', 'JJ'),
#  ('Schürze', 'NN'),
#  ('trug', 'NN'),
#  ('sie', 'PRP'),
#  ('eine', 'DT'),
#  ('Menge', 'NN'),
#  ('Schwefelhölzer', 'NN'),
#  ('und', 'CC'),
#  ('ein', 'DT'),
#  ('Bund', 'NN'),
#  ('davon', 'VB'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Hand', 'NN'),
#  ('Niemand', 'NN'),
#  ('hatte', 'VB'),
#  ('den', 'DT'),
#  ('ganzen', 'JJ'),
#  ('langen', 'JJ'),
#  ('Tag', 'NN'),
#  ('ihr', 'PRP'),
#  ('etwas', 'JJ'),
#  ('abgekauft', 'NN'),
#  ('Niemand', 'NN'),
#  ('ihr', 'PRP'),
#  ('einen', 'DT'),
#  ('Pfennig', 'NN'),
#  ('geschenkt', 'VB'),
#  ('Zitternd', 'NN'),
#  ('vor', 'IN'),
#  ('Kälte', 'NN'),
#  ('und', 'CC'),
#  ('Hunger', 'NN'),
#  ('schlich', 'JJ'),
#  ('sie', 'PRP'),
#  ('einher', 'NN'),
#  ('ein', 'DT'),
#  ('Bild', 'NN'),
#  ('des', 'DT'),
#  ('Jammers', 'NN'),
#  ('die', 'DT'),
#  ('arme', 'NN'),
#  ('Kleine', 'NN'),
#  ('Die', 'DT'),
#  ('Schneeflocken', 'NNP'),
#  ('bedeckten', 'NNP'),
#  ('ihr', 'PRP'),
#  ('langes', 'NN'),
#  ('blondes', 'JJ'),
#  ('Haar', 'NN'),
#  ('welches', 'WDT'),
#  ('in', 'TO'),
#  ('schönen', 'PRP$'),
#  ('Locken', 'NN'),
#  ('um', 'IN'),
#  ('den', 'DT'),
#  ('Hals', 'NN'),
#  ('fiel', 'VB'),
#  ('aber', 'RB'),
#  ('daran', 'RB'),
#  ('dachte', 'VB'),
#  ('sie', 'PRP'),
#  ('nun', 'RB'),
#  ('freilich', 'RB'),
#  ('nicht', 'RB'),
#  ('Aus', 'IN'),
#  ('allen', 'JJ'),
#  ('Fenstern', 'NN'),
#  ('glänzten', 'NN'),
#  ('die', 'DT'),
#  ('Lichter', 'JJ'),
#  ('und', 'CC'),
#  ('es', 'PRP'),
#  ('roch', 'RB'),
#  ('ganz', 'RB'),
#  ('herrlich', 'JJ'),
#  ('nach', 'IN'),
#  ('Gänsebraten', 'NN'),
#  ('es', 'PRP'),
#  ('war', 'VB'),
#  ('ja', 'RB'),
#  ('Sylvesterabend', 'JJ'),
#  ('Ja', 'NN'),
#  ('daran', 'VB'),
#  ('dachte', 'VB'),
#  ('sie', 'PRP'),
#  ('In', 'IN'),
#  ('einem', 'DT'),
#  ('Winkel', 'NN'),
#  ('von', 'IN'),
#  ('zwei', 'CD'),
#  ('Häusern', 'NN'),
#  ('gebildet', 'JJ'),
#  ('von', 'IN'),
#  ('denen', 'WDT'),
#  ('das', 'DT'),
#  ('eine', 'DT'),
#  ('etwas', 'DT'),
#  ('mehr', 'IN'),
#  ('vorsprang', 'NN'),
#  ('als', 'IN'),
#  ('das', 'WDT'),
#  ('andere', 'JJ'),
#  ('setzte', 'VB'),
#  ('sie', 'PRP'),
#  ('sich', 'PRP'),
#  ('hin', 'IN'),
#  ('und', 'CC'),
#  ('kauerte', 'VB'),
#  ('sich', 'PRP'),
#  ('zusammen', 'RB'),
#  ('Die', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Füße', 'NNS'),
#  ('hatte', 'VB'),
#  ('sie', 'PRP'),
#  ('an', 'IN'),
#  ('sich', 'PRP'),
#  ('gezogen', 'VB'),
#  ('aber', 'WRB'),
#  ('es', 'PRP'),
#  ('fror', 'NN'),
#  ('sie', 'PRP'),
#  ('noch', 'RB'),
#  ('mehr', 'NNP'),
#  ('und', 'CC'),
#  ('nach', 'IN'),
#  ('Hause', 'NN'),
#  ('zu', 'IN'),
#  ('gehen', 'PRP$'),
#  ('wagte', 'NN'),
#  ('sie', 'PRP'),
#  ('nicht', 'RB'),
#  ('sie', 'PRP'),
#  ('hatte', 'VB'),
#  ('ja', 'RB'),
#  ('keine', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('verkauft', 'VB'),
#  ('und', 'CC'),
#  ('brachte', 'RB'),
#  ('keinen', 'JJ'),
#  ('Pfennig', 'JJ'),
#  ('Geld', 'NN'),
#  ('Von', 'IN'),
#  ('ihrem', 'PRP$'),
#  ('Vater', 'NN'),
#  ('würde', 'VB'),
#  ('sie', 'PRP'),
#  ('gewiß', 'NN'),
#  ('Schläge', 'NN'),
#  ('bekommen', 'VB'),
#  ('und', 'CC'),
#  ('zu', 'IN'),
#  ('Hause', 'NN'),
#  ('war', 'VB'),
#  ('es', 'PRP'),
#  ('auch', 'RB'),
#  ('kalt', 'JJ'),
#  ('über', 'IN'),
#  ('sich', 'PRP'),
#  ('hatten', 'VB'),
#  ('sie', 'PRP'),
#  ('nur', 'RB'),
#  ('das', 'DT'),
#  ('Dach', 'NN'),
#  ('durch', 'IN'),
#  ('welches', 'WDT'),
#  ('der', 'DT'),
#  ('Wind', 'NN'),
#  ('pfiff', 'RB'),
#  ('wenn', 'IN'),
#  ('auch', 'RB'),
#  ('die', 'DT'),
#  ('größten', 'JJ'),
#  ('Spalten', 'NNS'),
#  ('mit', 'IN'),
#  ('Stroh', 'NN'),
#  ('und', 'CC'),
#  ('Lumpen', 'NN'),
#  ('zugestopft', 'NN'),
#  ('waren', 'VB'),
#  ('Ihre', 'PRP$'),
#  ('kleinen', 'JJ'),
#  ('Hände', 'NN'),
#  ('waren', 'VB'),
#  ('beinahe', 'RB'),
#  ('vor', 'IN'),
#  ('Kälte', 'NN'),
#  ('erstarrt', 'NN'),
#  ('Ach', 'NN'),
#  ('ein', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('konnte', 'VB'),
#  ('ihr', 'PRP'),
#  ('gar', 'RB'),
#  ('wohl', 'RB'),
#  ('thun', 'VB'),
#  ('wenn', 'IN'),
#  ('sie', 'JJ'),
#  ('nur', 'RB'),
#  ('ein', 'DT'),
#  ('einziges', 'NN'),
#  ('aus', 'IN'),
#  ('dem', 'DT'),
#  ('Bunde', 'NN'),
#  ('herausziehen', 'NN'),
#  ('es', 'PRP'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Wand', 'NN'),
#  ('streichen', 'VB'),
#  ('und', 'CC'),
#  ('sich', 'PRP'),
#  ('die', 'DT'),
#  ('Finger', 'NN'),
#  ('erwärmen', 'VB'),
#  ('dürfte', 'VB'),
#  ('Sie', 'PRP'),
#  ('zog', 'VB'),
#  ('eins', 'CD'),
#  ('heraus', 'IN'),
#  ('Rrscht', 'NN'),
#  ('wie', 'IN'),
#  ('sprühte', 'NN'),
#  ('wie', 'IN'),
#  ('brannte', 'NN'),
#  ('es', 'PRP'),
#  ('Es', 'PRP'),
#  ('war', 'VB'),
#  ('eine', 'DT'),
#  ('warme', 'JJ'),
#  ('helle', 'JJ'),
#  ('Flamme', 'NN'),
#  ('wie', 'IN'),
#  ('ein', 'DT'),
#  ('Lichtchen', 'JJ'),
#  ('als', 'IN'),
#  ('sie', 'PRP'),
#  ('die', 'DT'),
#  ('Hände', 'NN'),
#  ('darüber', 'VB'),
#  ('hielt', 'RB'),
#  ('es', 'PRP'),
#  ('war', 'VB'),
#  ('ein', 'DT'),
#  ('wunderbares', 'JJ'),
#  ('Lichtchen', 'VB'),
#  ('Es', 'PRP'),
#  ('schien', 'RB'),
#  ('wirklich', 'JJ'),
#  ('dem', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('als', 'IN'),
#  ('säße', 'JJ'),
#  ('sie', 'PRP'),
#  ('vor', 'IN'),
#  ('einem', 'DT'),
#  ('großen', 'JJ'),
#  ('eisernen', 'JJ'),
#  ('Ofen', 'NN'),
#  ('mit', 'IN'),
#  ('polirten', 'NN'),
#  ('Messingfüßen', 'NN'),
#  ('und', 'CC'),
#  ('einem', 'DT'),
#  ('messingenen', 'NN'),
#  ('Aufsatze', 'NN'),
#  ('Das', 'DT'),
#  ('Feuer', 'NN'),
#  ('brannte', 'NN'),
#  ('so', 'IN'),
#  ('gesegnet', 'NN'),
#  ('es', 'PRP'),
#  ('wärmte', 'NN'),
#  ('so', 'RB'),
#  ('schön', 'JJ'),
#  ('die', 'DT'),
#  ('Kleine', 'NN'),
#  ('streckte', 'VB'),
#  ('schon', 'RB'),
#  ('die', 'DT'),
#  ('Füße', 'NNS'),
#  ('aus', 'IN'),
#  ('um', 'IN'),
#  ('auch', 'RB'),
#  ('diese', 'DT'),
#  ('zu', 'RB'),
#  ('wärmen', 'VB'),
#  ('doch', 'RB'),
#  ('da', 'IN'),
#  ('erlosch', 'VB'),
#  ('das', 'DT'),
#  ('Flämmchen', 'NN'),
#  ('der', 'DT'),
#  ('Ofen', 'NN'),
#  ('verschwand', 'VB'),
#  ('sie', 'PRP'),
#  ('hatte', 'VB'),
#  ('nur', 'RB'),
#  ('die', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Ueberreste', 'NN'),
#  ('des', 'DT'),
#  ('abgebrannten', 'JJ'),
#  ('Schwefelhölzchens', 'NN'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Hand', 'NN'),
#  ('Ein', 'DT'),
#  ('zweites', 'VB'),
#  ('wurde', 'VB'),
#  ('an', 'IN'),
#  ('der', 'DT'),
#  ('Wand', 'NN'),
#  ('abgestrichen', 'VB'),
#  ('es', 'PRP'),
#  ('leuchtete', 'NN'),
#  ('und', 'CC'),
#  ('wo', 'WRB'),
#  ('der', 'DT'),
#  ('Schein', 'NN'),
#  ('auf', 'IN'),
#  ('die', 'DT'),
#  ('Mauer', 'NN'),
#  ('fiel', 'VBN'),
#  ('wurde', 'VB'),
#  ('diese', 'DT'),
#  ('durchsichtig', 'JJ'),
#  ('wie', 'IN'),
#  ('ein', 'DT'),
#  ('Schleier', 'NN'),
#  ('sie', 'PRP'),
#  ('konnte', 'VB'),
#  ('in', 'IN'),
#  ('das', 'DT'),
#  ('Zimmer', 'JJ'),
#  ('hineinsehen', 'NN'),
#  ('Auf', 'IN'),
#  ('dem', 'DT'),
#  ('Tische', 'JJ'),
#  ('war', 'VB'),
#  ('ein', 'DT'),
#  ('schneeweißes', 'NN'),
#  ('Tischtuch', 'NN'),
#  ('ausgebreitet', 'NN'),
#  ('darauf', 'VB'),
#  ('stand', 'RB'),
#  ('glänzendes', 'NN'),
#  ('Porzellangeschirr', 'NN'),
#  ('und', 'CC'),
#  ('herrlich', 'JJ'),
#  ('dampfte', 'VB'),
#  ('die', 'DT'),
#  ('gebratene', 'JJ'),
#  ('Gans', 'NN'),
#  ('mit', 'IN'),
#  ('Aepfeln', 'NN'),
#  ('und', 'CC'),
#  ('getrockneten', 'NN'),
#  ('Pflaumen', 'NN'),
#  ('gefüllt', 'VBN'),
#  ('Und', 'CC'),
#  ('was', 'WP'),
#  ('noch', 'RB'),
#  ('prächtiger', 'NNP'),
#  ('anzusehen', 'VB'),
#  ('war', 'VB'),
#  ('die', 'DT'),
#  ('Gans', 'JJ'),
#  ('hüpfte', 'NN'),
#  ('von', 'IN'),
#  ('der', 'DT'),
#  ('Schüssel', 'NN'),
#  ('herunter', 'NNP'),
#  ('und', 'CC'),
#  ('wackelte', 'NNP'),
#  ('auf', 'IN'),
#  ('dem', 'DT'),
#  ('Fußboden', 'NN'),
#  ('Messer', 'NN'),
#  ('und', 'CC'),
#  ('Gabel', 'NN'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Brust', 'NN'),
#  ('bis', 'IN'),
#  ('zu', 'IN'),
#  ('dem', 'DT'),
#  ('armen', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('hin', 'IN'),
#  ('Da', 'IN'),
#  ('erlosch', 'VB'),
#  ('das', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('und', 'CC'),
#  ('es', 'PRP'),
#  ('blieb', 'NN'),
#  ('nur', 'RB'),
#  ('die', 'DT'),
#  ('dicke', 'NN'),
#  ('feuchtkalte', 'NN'),
#  ('Mauer', 'NN'),
#  ('zurück', 'RP'),
#  ('Sie', 'PRP'),
#  ('zündete', 'NN'),
#  ('noch', 'RB'),
#  ('ein', 'DT'),
#  ('Hölzchen', 'JJ'),
#  ('an', 'IN'),
#  ('Da', 'IN'),
#  ('saß', 'VB'),
#  ('sie', 'PRP'),
#  ('nun', 'RB'),
#  ('unter', 'IN'),
#  ('dem', 'DT'),
#  ('herrlichsten', 'NN'),
#  ('Christbaume', 'NN'),
#  ('er', 'PRP'),
#  ('war', 'VB'),
#  ('noch', 'RB'),
#  ('größer', 'JJ'),
#  ('und', 'CC'),
#  ('geputzter', 'NN'),
#  ('als', 'IN'),
#  ('der', 'WDT'),
#  ('den', 'DT'),
#  ('sie', 'PRP$'),
#  ('durch', 'IN'),
#  ('die', 'DT'),
#  ('Glasthüre', 'NN'),
#  ('bei', 'IN'),
#  ('dem', 'DT'),
#  ('reichen', 'PRP$'),
#  ('Kaufmanne', 'NN'),
#  ('gesehen', 'VB'),
#  ('hatte', 'VB'),
#  ('Tausende', 'NNS'),
#  ('von', 'IN'),
#  ('Lichterchen', 'JJ'),
#  ('brannten', 'NN'),
#  ('auf', 'IN'),
#  ('den', 'DT'),
#  ('grünen', 'PRP$'),
#  ('Zweigen', 'NN'),
#  ('und', 'CC'),
#  ('bunte', 'JJ'),
#  ('Bilder', 'NN'),
#  ('wie', 'IN'),
#  ('sie', 'PRP'),
#  ('an', 'IN'),
#  ('Schaufenstern', 'NN'),
#  ('zu', 'TO'),
#  ('sehen', 'VB'),
#  ('waren', 'VB'),
#  ('blickten', 'VB'),
#  ('auf', 'IN'),
#  ('sie', 'PRP'),
#  ('herab', 'NN'),
#  ('Die', 'DT'),
#  ('Kleine', 'NN'),
#  ('streckte', 'VB'),
#  ('ihre', 'PRP$'),
#  ('Hände', 'NN'),
#  ('danach', 'VB'),
#  ('aus', 'IN'),
#  ('da', 'RB'),
#  ('erlosch', 'VB'),
#  ('das', 'DT'),
#  ('Schwefelhölzchen', 'VB'),
#  ('Die', 'DT'),
#  ('Weihnachtslichter', 'NN'),
#  ('stiegen', 'NN'),
#  ('höher', 'JJ'),
#  ('und', 'CC'),
#  ('höher', 'JJ'),
#  ('sie', 'PRP'),
#  ('sah', 'VB'),
#  ('sie', 'PRP'),
#  ('jetzt', 'RB'),
#  ('als', 'IN'),
#  ('Sterne', 'NNS'),
#  ('am', 'IN'),
#  ('Himmel', 'NN'),
#  ('einer', 'DT'),
#  ('davon', 'RB'),
#  ('fiel', 'VB'),
#  ('herunter', 'NNP'),
#  ('und', 'CC'),
#  ('bildete', 'VB'),
#  ('einen', 'DT'),
#  ('langen', 'JJ'),
#  ('Feuerstreifen', 'NN'),
#  ('Jetzt', 'NN'),
#  ('stirbt', 'VB'),
#  ('Jemand', 'RB'),
#  ('dachte', 'VB'),
#  ('das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('denn', 'RB'),
#  ('ihre', 'PRP$'),
#  ('alte', 'JJ'),
#  ('Großmutter', 'NN'),
#  ('die', 'DT'),
#  ('Einzige', 'NN'),
#  ('die', 'DT'),
#  ('sie', 'PRP$'),
#  ('lieb', 'JJ'),
#  ('gehabt', 'NN'),
#  ('hatte', 'VB'),
#  ('und', 'CC'),
#  ('die', 'DT'),
#  ('jetzt', 'RB'),
#  ('gestorben', 'VBN'),
#  ('war', 'VBN'),
#  ('hatte', 'VB'),
#  ('ihr', 'PRP'),
#  ('erzählt', 'VBN'),
#  ('daß', 'IN'),
#  ('wenn', 'RB'),
#  ('ein', 'DT'),
#  ('Stern', 'NN'),
#  ('herunterfällt', 'NN'),
#  ('eine', 'DT'),
#  ('Seele', 'NN'),
#  ('zu', 'IN'),
#  ('Gott', 'NN'),
#  ('emporsteigt', 'VB'),
#  ('Sie', 'PRP'),
#  ('strich', 'NNP'),
#  ('wieder', 'RB'),
#  ('ein', 'DT'),
#  ('Hölzchen', 'JJ'),
#  ('an', 'IN'),
#  ('der', 'DT'),
#  ('Mauer', 'NN'),
#  ('ab', 'RP'),
#  ('es', 'PRP'),
#  ('wurde', 'VB'),
#  ('wieder', 'RB'),
#  ('hell', 'JJ'),
#  ('und', 'CC'),
#  ('in', 'IN'),
#  ('dem', 'DT'),
#  ('Glanze', 'NN'),
#  ('stand', 'VB'),
#  ('die', 'DT'),
#  ('alte', 'JJ'),
#  ('Großmutter', 'NN'),
#  ('so', 'RB'),
#  ('klar', 'JJ'),
#  ('und', 'CC'),
#  ('schimmernd', 'NN'),
#  ('so', 'RB'),
#  ('mild', 'JJ'),
#  ('und', 'CC'),
#  ('liebevoll', 'JJ'),
#  ('Großmutter', 'NN'),
#  ('rief', 'VB'),
#  ('die', 'DT'),
#  ('Kleine', 'NN'),
#  ('O', 'NN'),
#  ('nimm', 'NN'),
#  ('mich', 'PRP'),
#  ('mit', 'IN'),
#  ('Ich', 'PRP'),
#  ('weiß', 'VB'),
#  ('Du', 'NN'),
#  ('entfernst', 'NN'),
#  ('Dich', 'VB'),
#  ('wenn', 'RB'),
#  ('das', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('erlischt', 'VB'),
#  ('Du', 'NN'),
#  ('verschwindest', 'RB'),
#  ('wie', 'IN'),
#  ('der', 'DT'),
#  ('warme', 'JJ'),
#  ('Ofen', 'NN'),
#  ('wie', 'IN'),
#  ('der', 'DT'),
#  ('herrliche', 'JJ'),
#  ('Gänsebraten', 'NN'),
#  ('und', 'CC'),
#  ('der', 'DT'),
#  ('große', 'JJ'),
#  ('prächtige', 'NN'),
#  ('Weihnachtsbaum', 'NN'),
#  ('Und', 'RB'),
#  ('sie', 'PRP'),
#  ('strich', 'NNP'),
#  ('schnell', 'JJ'),
#  ('das', 'DT'),
#  ('ganze', 'JJ'),
#  ('Bund', 'NN'),
#  ('Schwefelhölzchen', 'VB'),
#  ('denn', 'WRB'),
#  ('sie', 'PRP'),
#  ('wollte', 'MD'),
#  ('die', 'DT'),
#  ('Großmutter', 'NN'),
#  ('recht', 'VB'),
#  ('fest', 'JJ'),
#  ('halten', 'VB'),
#  ('Und', 'CC'),
#  ('die', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('leuchteten', 'NN'),
#  ('mit', 'IN'),
#  ('einem', 'DT'),
#  ('solchen', 'DT'),
#  ('Glanze', 'NN'),
#  ('daß', 'IN'),
#  ('es', 'JJ'),
#  ('heller', 'VB'),
#  ('wurde', 'VB'),
#  ('als', 'IN'),
#  ('mitten', 'RB'),
#  ('am', 'IN'),
#  ('Tage', 'NN'),
#  ('die', 'DT'),
#  ('Großmutter', 'NN'),
#  ('war', 'VB'),
#  ('nie', 'RB'),
#  ('früher', 'RB'),
#  ('so', 'RB'),
#  ('schön', 'JJ'),
#  ('so', 'RB'),
#  ('groß', 'JJ'),
#  ('gewesen', 'VBN'),
#  ('sie', 'PRP'),
#  ('nahm', 'VB'),
#  ('das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('auf', 'IN'),
#  ('ihre', 'PRP$'),
#  ('Arme', 'NNS'),
#  ('und', 'CC'),
#  ('Beide', 'DT'),
#  ('flogen', 'VB'),
#  ('in', 'IN'),
#  ('Glanz', 'NN'),
#  ('und', 'CC'),
#  ('Freude', 'NN'),
#  ('so', 'RB'),
#  ('hoch', 'JJ'),
#  ('so', 'RB'),
#  ('hoch', 'JJ'),
#  ('und', 'CC'),
#  ('dort', 'RB'),
#  ('war', 'VB'),
#  ('weder', 'CC'),
#  ('Kälte', 'NN'),
#  ('noch', 'IN'),
#  ('Hunger', 'NN'),
#  ('noch', 'IN'),
#  ('Angst', 'NN'),
#  ('sie', 'PRP'),
#  ('waren', 'VB'),
#  ('bei', 'IN'),
#  ('Gott', 'NN'),
#  ('Aber', 'RB'),
#  ('im', 'IN'),
#  ('Winkel', 'NN'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Mauer', 'NN'),
#  ('gelehnt', 'VBN'),
#  ('saß', 'VB'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('kalten', 'JJ'),
#  ('Morgenstunde', 'NN'),
#  ('das', 'DT'),
#  ('arme', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('rothen', 'NN'),
#  ('Backen', 'NN'),
#  ('und', 'CC'),
#  ('mit', 'IN'),
#  ('lächelndem', 'RB'),
#  ('Munde', 'JJ'),
#  ('erfroren', 'NN'),
#  ('an', 'IN'),
#  ('des', 'DT'),
#  ('alten', 'JJ'),
#  ('Jahres', 'NN'),
#  ('letztem', 'JJ'),
#  ('Abend', 'NN'),
#  ('Die', 'DT'),
#  ('Neujahrssonne', 'NN'),
#  ('ging', 'VB'),
#  ('auf', 'IN'),
#  ('über', 'IN'),
#  ('der', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Leiche', 'NN'),
#  ('Starr', 'JJ'),
#  ('saß', 'VB'),
#  ('das', 'DT'),
#  ('Kind', 'NN'),
#  ('dort', 'RB'),
#  ('mit', 'IN'),
#  ('den', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('von', 'IN'),
#  ('denen', 'WDT'),
#  ('ein', 'DT'),
#  ('Bund', 'NN'),
#  ('abgebrannt', 'NN'),
#  ('war', 'VB'),
#  ('Sie', 'PRP'),
#  ('hat', 'VB'),
#  ('sich', 'PRP'),
#  ('erwärmen', 'VB'),
#  ('wollen', 'MD'),
#  ('sagte', 'VB'),
#  ('man', 'DT'),
#  ('Niemand', 'NN'),
#  ('ahnte', 'NN'),
#  ('was', 'WDT'),
#  ('sie', 'PRP'),
#  ('Schönes', 'NN'),
#  ('gesehen', 'VBN'),
#  ('hatte', 'VB'),
#  ('in', 'IN'),
#  ('welchem', 'WP'),
#  ('Glanze', 'NN'),
#  ('sie', 'PRP'),
#  ('mit', 'IN'),
#  ('der', 'DT'),
#  ('Großmutter', 'NN'),
#  ('zur', 'IN'),
#  ('Neujahrsfreude', 'NN'),
#  ('eingegangen', 'VBN'),
#  ('war', 'VB'),
#  ('Hans', 'NNP'),
#  ('Christian', 'NNP'),
#  ('Andersen', 'NNP')]

# %%
substantive = []
adjektive = []
verben = []
blob = TextBlobDE(maerchen_clean, parser=PatternParser(pprint=False, lemmata=True))
for word in blob.tags:
    if "NN" in word[1]:
        substantive.append(word[0])
    if "V" in word[1]:
        verben.append(word[0])
    if "JJ" in word[1]:
        adjektive.append(word[0])

# %%
substantive
# Out:
# ['Hans',
#  'Christian',
#  'Andersen',
#  'Märchen',
#  'Mädchen',
#  'schneite',
#  'Abend',
#  'Abend',
#  'Jahres',
#  'Kälte',
#  'Finsterniß',
#  'Straße',
#  'Mädchen',
#  'bloßem',
#  'Kopfe',
#  'Füßen',
#  'Haus',
#  'verließ',
#  'Pantoffeln',
#  'angehabt',
#  'Pantoffeln',
#  'Mutter',
#  'Kleine',
#  'verlor',
#  'Straße',
#  'huschte',
#  'Wagen',
#  'vorüberrollten',
#  'Pantoffel',
#  'Junge',
#  'erwischt',
#  'Wiege',
#  'Kinder',
#  'Mädchen',
#  'Füßen',
#  'Kälte',
#  'Schürze',
#  'trug',
#  'Menge',
#  'Schwefelhölzer',
#  'Bund',
#  'Hand',
#  'Niemand',
#  'Tag',
#  'abgekauft',
#  'Niemand',
#  'Pfennig',
#  'Zitternd',
#  'Kälte',
#  'Hunger',
#  'einher',
#  'Bild',
#  'Jammers',
#  'arme',
#  'Kleine',
#  'Schneeflocken',
#  'bedeckten',
#  'langes',
#  'Haar',
#  'Locken',
#  'Hals',
#  'Fenstern',
#  'glänzten',
#  'Gänsebraten',
#  'Ja',
#  'Winkel',
#  'Häusern',
#  'vorsprang',
#  'Füße',
#  'fror',
#  'mehr',
#  'Hause',
#  'wagte',
#  'Geld',
#  'Vater',
#  'gewiß',
#  'Schläge',
#  'Hause',
#  'Dach',
#  'Wind',
#  'Spalten',
#  'Stroh',
#  'Lumpen',
#  'zugestopft',
#  'Hände',
#  'Kälte',
#  'erstarrt',
#  'Ach',
#  'einziges',
#  'Bunde',
#  'herausziehen',
#  'Wand',
#  'Finger',
#  'Rrscht',
#  'sprühte',
#  'brannte',
#  'Flamme',
#  'Hände',
#  'Mädchen',
#  'Ofen',
#  'polirten',
#  'Messingfüßen',
#  'messingenen',
#  'Aufsatze',
#  'Feuer',
#  'brannte',
#  'gesegnet',
#  'wärmte',
#  'Kleine',
#  'Füße',
#  'Flämmchen',
#  'Ofen',
#  'Ueberreste',
#  'Schwefelhölzchens',
#  'Hand',
#  'Wand',
#  'leuchtete',
#  'Schein',
#  'Mauer',
#  'Schleier',
#  'hineinsehen',
#  'schneeweißes',
#  'Tischtuch',
#  'ausgebreitet',
#  'glänzendes',
#  'Porzellangeschirr',
#  'Gans',
#  'Aepfeln',
#  'getrockneten',
#  'Pflaumen',
#  'prächtiger',
#  'hüpfte',
#  'Schüssel',
#  'herunter',
#  'wackelte',
#  'Fußboden',
#  'Messer',
#  'Gabel',
#  'Brust',
#  'Mädchen',
#  'blieb',
#  'dicke',
#  'feuchtkalte',
#  'Mauer',
#  'zündete',
#  'herrlichsten',
#  'Christbaume',
#  'geputzter',
#  'Glasthüre',
#  'Kaufmanne',
#  'Tausende',
#  'brannten',
#  'Zweigen',
#  'Bilder',
#  'Schaufenstern',
#  'herab',
#  'Kleine',
#  'Hände',
#  'Weihnachtslichter',
#  'stiegen',
#  'Sterne',
#  'Himmel',
#  'herunter',
#  'Feuerstreifen',
#  'Jetzt',
#  'Mädchen',
#  'Großmutter',
#  'Einzige',
#  'gehabt',
#  'Stern',
#  'herunterfällt',
#  'Seele',
#  'Gott',
#  'strich',
#  'Mauer',
#  'Glanze',
#  'Großmutter',
#  'schimmernd',
#  'Großmutter',
#  'Kleine',
#  'O',
#  'nimm',
#  'Du',
#  'entfernst',
#  'Du',
#  'Ofen',
#  'Gänsebraten',
#  'prächtige',
#  'Weihnachtsbaum',
#  'strich',
#  'Bund',
#  'Großmutter',
#  'leuchteten',
#  'Glanze',
#  'Tage',
#  'Großmutter',
#  'Mädchen',
#  'Arme',
#  'Glanz',
#  'Freude',
#  'Kälte',
#  'Hunger',
#  'Angst',
#  'Gott',
#  'Winkel',
#  'Mauer',
#  'Morgenstunde',
#  'Mädchen',
#  'rothen',
#  'Backen',
#  'erfroren',
#  'Jahres',
#  'Abend',
#  'Neujahrssonne',
#  'Leiche',
#  'Kind',
#  'Bund',
#  'abgebrannt',
#  'Niemand',
#  'ahnte',
#  'Schönes',
#  'Glanze',
#  'Großmutter',
#  'Neujahrsfreude',
#  'Hans',
#  'Christian',
#  'Andersen']

# %%
import os
import nltk
from nltk.probability import FreqDist

# %%
FreqDist(substantive)
# Out:
# FreqDist({'Mädchen': 8, 'Großmutter': 6, 'Kälte': 5, 'Kleine': 5, 'Mauer': 4, 'Abend': 3, 'Bund': 3, 'Niemand': 3, 'Hände': 3, 'Ofen': 3, ...})

# %%
#adjektive

# %%
#verben

# %% [markdown]
# # WORDLE

# %% [markdown]
# words = word_tokenize(maerchen)
# #words_german =[word.lower() for word in words if word.isalpha()]
# words_german =[word for word in words if word.isalpha()]
#
# lemma = nltk.WordNetLemmatizer()  # besser mit Textblob
# lemmas = [lemma.lemmatize(i) for i in words_german]
# clean_blob = lemmas

# %%
blob = TextBlobDE(maerchen, parser=PatternParser(pprint=False, lemmata=True))
blob.tags
# Out:
# [('Hans', 'NNP'),
#  ('Christian', 'NNP'),
#  ('Andersen', 'NNP'),
#  ('Sämtliche', 'JJ'),
#  ('Märchen', 'NN'),
#  ('1862', 'CD'),
#  ('Das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('den', 'DT'),
#  ('Schwefelhölzchen', 'VB'),
#  ('Es', 'PRP'),
#  ('war', 'RB'),
#  ('entsetzlich', 'JJ'),
#  ('kalt', 'JJ'),
#  ('es', 'PRP'),
#  ('schneite', 'NN'),
#  ('und', 'CC'),
#  ('war', 'VB'),
#  ('beinahe', 'RB'),
#  ('schon', 'RB'),
#  ('ganz', 'RB'),
#  ('dunkel', 'JJ'),
#  ('und', 'CC'),
#  ('Abend', 'NN'),
#  ('der', 'DT'),
#  ('letzte', 'JJ'),
#  ('Abend', 'NN'),
#  ('des', 'DT'),
#  ('Jahres', 'NN'),
#  ('In', 'IN'),
#  ('dieser', 'DT'),
#  ('Kälte', 'NN'),
#  ('und', 'CC'),
#  ('Finsterniß', 'NN'),
#  ('ging', 'VB'),
#  ('auf', 'IN'),
#  ('der', 'DT'),
#  ('Straße', 'NN'),
#  ('ein', 'DT'),
#  ('kleines', 'VB'),
#  ('armes', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('bloßem', 'NN'),
#  ('Kopfe', 'NN'),
#  ('und', 'CC'),
#  ('nackten', 'JJ'),
#  ('Füßen', 'NNP'),
#  ('Als', 'IN'),
#  ('sie', 'PRP'),
#  ('das', 'DT'),
#  ('Haus', 'NN'),
#  ('verließ', 'NN'),
#  ('hatte', 'VB'),
#  ('sie', 'PRP'),
#  ('freilich', 'IN'),
#  ('Pantoffeln', 'NN'),
#  ('angehabt', 'NN'),
#  ('aber', 'RB'),
#  ('was', 'WDT'),
#  ('half', 'VB'),
#  ('das', 'DT'),
#  ('Es', 'PRP'),
#  ('waren', 'VB'),
#  ('sehr', 'RB'),
#  ('große', 'JJ'),
#  ('Pantoffeln', 'NN'),
#  ('gewesen', 'VBN'),
#  ('die', 'DT'),
#  ('ihre', 'PRP$'),
#  ('Mutter', 'NN'),
#  ('bisher', 'RB'),
#  ('benutzt', 'VBN'),
#  ('hatte', 'VB'),
#  ('so', 'RB'),
#  ('groß', 'JJ'),
#  ('waren', 'VB'),
#  ('sie', 'PRP'),
#  ('Die', 'DT'),
#  ('Kleine', 'NN'),
#  ('aber', 'IN'),
#  ('verlor', 'NN'),
#  ('dieselben', 'DT'),
#  ('als', 'IN'),
#  ('sie', 'PRP'),
#  ('über', 'IN'),
#  ('die', 'DT'),
#  ('Straße', 'NN'),
#  ('weg', 'IN'),
#  ('huschte', 'NN'),
#  ('weil', 'IN'),
#  ('zwei', 'CD'),
#  ('Wagen', 'NN'),
#  ('schrecklich', 'JJ'),
#  ('schnell', 'JJ'),
#  ('vorüberrollten', 'NN'),
#  ('Der', 'DT'),
#  ('eine', 'DT'),
#  ('Pantoffel', 'NN'),
#  ('war', 'VB'),
#  ('nicht', 'RB'),
#  ('wieder', 'RB'),
#  ('zu', 'TO'),
#  ('finden', 'VB'),
#  ('den', 'WDT'),
#  ('andern', 'DT'),
#  ('hatte', 'VB'),
#  ('ein', 'DT'),
#  ('Junge', 'NN'),
#  ('erwischt', 'NN'),
#  ('und', 'CC'),
#  ('lief', 'VB'),
#  ('damit', 'RB'),
#  ('fort', 'RP'),
#  ('er', 'PRP'),
#  ('meinte', 'VB'),
#  ('er', 'PRP'),
#  ('könne', 'VB'),
#  ('ihn', 'PRP'),
#  ('recht', 'RB'),
#  ('gut', 'JJ'),
#  ('als', 'IN'),
#  ('Wiege', 'NN'),
#  ('benutzen', 'VB'),
#  ('wenn', 'RB'),
#  ('er', 'PRP'),
#  ('selbst', 'JJ'),
#  ('erst', 'IN'),
#  ('Kinder', 'NN'),
#  ('hätte', 'VB'),
#  ('Da', 'IN'),
#  ('ging', 'VB'),
#  ('nun', 'RB'),
#  ('das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('den', 'DT'),
#  ('kleinen', 'VB'),
#  ('nackten', 'JJ'),
#  ('Füßen', 'NNP'),
#  ('die', 'WDT'),
#  ('ganz', 'RB'),
#  ('rot', 'JJ'),
#  ('und', 'CC'),
#  ('blau', 'JJ'),
#  ('vor', 'IN'),
#  ('Kälte', 'NN'),
#  ('waren', 'VB'),
#  ('In', 'IN'),
#  ('einer', 'DT'),
#  ('alten', 'JJ'),
#  ('Schürze', 'NN'),
#  ('trug', 'NN'),
#  ('sie', 'PRP'),
#  ('eine', 'DT'),
#  ('Menge', 'NN'),
#  ('Schwefelhölzer', 'NN'),
#  ('und', 'CC'),
#  ('ein', 'DT'),
#  ('Bund', 'NN'),
#  ('davon', 'VB'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Hand', 'NN'),
#  ('Niemand', 'NN'),
#  ('hatte', 'VB'),
#  ('den', 'DT'),
#  ('ganzen', 'JJ'),
#  ('langen', 'JJ'),
#  ('Tag', 'NN'),
#  ('ihr', 'PRP'),
#  ('etwas', 'JJ'),
#  ('abgekauft', 'NN'),
#  ('Niemand', 'NN'),
#  ('ihr', 'PRP'),
#  ('einen', 'DT'),
#  ('Pfennig', 'NN'),
#  ('geschenkt', 'RP'),
#  ('Zitternd', 'NN'),
#  ('vor', 'IN'),
#  ('Kälte', 'NN'),
#  ('und', 'CC'),
#  ('Hunger', 'NN'),
#  ('schlich', 'JJ'),
#  ('sie', 'PRP'),
#  ('einher', 'NN'),
#  ('ein', 'DT'),
#  ('Bild', 'NN'),
#  ('des', 'DT'),
#  ('Jammers', 'NN'),
#  ('die', 'DT'),
#  ('arme', 'NN'),
#  ('Kleine', 'NN'),
#  ('Die', 'DT'),
#  ('Schneeflocken', 'NNP'),
#  ('bedeckten', 'NNP'),
#  ('ihr', 'PRP'),
#  ('langes', 'NN'),
#  ('blondes', 'JJ'),
#  ('Haar', 'NN'),
#  ('welches', 'WDT'),
#  ('in', 'TO'),
#  ('schönen', 'PRP$'),
#  ('Locken', 'NN'),
#  ('um', 'IN'),
#  ('den', 'DT'),
#  ('Hals', 'NN'),
#  ('fiel', 'VB'),
#  ('aber', 'RB'),
#  ('daran', 'RB'),
#  ('dachte', 'VB'),
#  ('sie', 'PRP'),
#  ('nun', 'RB'),
#  ('freilich', 'RB'),
#  ('nicht', 'RB'),
#  ('Aus', 'IN'),
#  ('allen', 'JJ'),
#  ('Fenstern', 'NN'),
#  ('glänzten', 'NN'),
#  ('die', 'DT'),
#  ('Lichter', 'JJ'),
#  ('und', 'CC'),
#  ('es', 'PRP'),
#  ('roch', 'RB'),
#  ('ganz', 'RB'),
#  ('herrlich', 'JJ'),
#  ('nach', 'IN'),
#  ('Gänsebraten', 'NN'),
#  ('es', 'PRP'),
#  ('war', 'VB'),
#  ('ja', 'RB'),
#  ('Sylvesterabend', 'JJ'),
#  ('Ja', 'NN'),
#  ('daran', 'RB'),
#  ('dachte', 'VB'),
#  ('sie', 'PRP'),
#  ('In', 'IN'),
#  ('einem', 'DT'),
#  ('Winkel', 'NN'),
#  ('von', 'IN'),
#  ('zwei', 'CD'),
#  ('Häusern', 'NN'),
#  ('gebildet', 'VBN'),
#  ('von', 'IN'),
#  ('denen', 'WDT'),
#  ('das', 'DT'),
#  ('eine', 'DT'),
#  ('etwas', 'DT'),
#  ('mehr', 'IN'),
#  ('vorsprang', 'NN'),
#  ('als', 'IN'),
#  ('das', 'WDT'),
#  ('andere', 'VB'),
#  ('setzte', 'RB'),
#  ('sie', 'PRP'),
#  ('sich', 'PRP'),
#  ('hin', 'IN'),
#  ('und', 'CC'),
#  ('kauerte', 'VB'),
#  ('sich', 'PRP'),
#  ('zusammen', 'RP'),
#  ('Die', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Füße', 'NNS'),
#  ('hatte', 'VB'),
#  ('sie', 'PRP'),
#  ('an', 'IN'),
#  ('sich', 'PRP'),
#  ('gezogen', 'VBN'),
#  ('aber', 'WRB'),
#  ('es', 'PRP'),
#  ('fror', 'NN'),
#  ('sie', 'PRP'),
#  ('noch', 'RB'),
#  ('mehr', 'RP'),
#  ('und', 'CC'),
#  ('nach', 'IN'),
#  ('Hause', 'NN'),
#  ('zu', 'IN'),
#  ('gehen', 'PRP$'),
#  ('wagte', 'NN'),
#  ('sie', 'PRP'),
#  ('nicht', 'RB'),
#  ('sie', 'PRP'),
#  ('hatte', 'VB'),
#  ('ja', 'RB'),
#  ('keine', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('verkauft', 'VB'),
#  ('und', 'CC'),
#  ('brachte', 'RB'),
#  ('keinen', 'JJ'),
#  ('Pfennig', 'JJ'),
#  ('Geld', 'NN'),
#  ('Von', 'IN'),
#  ('ihrem', 'PRP$'),
#  ('Vater', 'NN'),
#  ('würde', 'VB'),
#  ('sie', 'PRP'),
#  ('gewiß', 'NN'),
#  ('Schläge', 'NN'),
#  ('bekommen', 'VB'),
#  ('und', 'CC'),
#  ('zu', 'IN'),
#  ('Hause', 'NN'),
#  ('war', 'VB'),
#  ('es', 'PRP'),
#  ('auch', 'RB'),
#  ('kalt', 'JJ'),
#  ('über', 'IN'),
#  ('sich', 'PRP'),
#  ('hatten', 'VB'),
#  ('sie', 'PRP'),
#  ('nur', 'RB'),
#  ('das', 'DT'),
#  ('Dach', 'NN'),
#  ('durch', 'IN'),
#  ('welches', 'WDT'),
#  ('der', 'DT'),
#  ('Wind', 'NN'),
#  ('pfiff', 'NN'),
#  ('wenn', 'IN'),
#  ('auch', 'RB'),
#  ('die', 'DT'),
#  ('größten', 'JJ'),
#  ('Spalten', 'NNS'),
#  ('mit', 'IN'),
#  ('Stroh', 'NN'),
#  ('und', 'CC'),
#  ('Lumpen', 'NN'),
#  ('zugestopft', 'NN'),
#  ('waren', 'VB'),
#  ('Ihre', 'PRP$'),
#  ('kleinen', 'JJ'),
#  ('Hände', 'NN'),
#  ('waren', 'VB'),
#  ('beinahe', 'RB'),
#  ('vor', 'IN'),
#  ('Kälte', 'JJ'),
#  ('erstarrt', 'NN'),
#  ('Ach', 'NN'),
#  ('ein', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('konnte', 'VB'),
#  ('ihr', 'PRP'),
#  ('gar', 'RB'),
#  ('wohl', 'RB'),
#  ('thun', 'VB'),
#  ('wenn', 'IN'),
#  ('sie', 'JJ'),
#  ('nur', 'RB'),
#  ('ein', 'DT'),
#  ('einziges', 'NN'),
#  ('aus', 'IN'),
#  ('dem', 'DT'),
#  ('Bunde', 'NN'),
#  ('herausziehen', 'NN'),
#  ('es', 'PRP'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Wand', 'NN'),
#  ('streichen', 'VB'),
#  ('und', 'CC'),
#  ('sich', 'PRP'),
#  ('die', 'DT'),
#  ('Finger', 'NN'),
#  ('erwärmen', 'VB'),
#  ('dürfte', 'VB'),
#  ('Sie', 'PRP'),
#  ('zog', 'VB'),
#  ('eins', 'CD'),
#  ('heraus', 'RP'),
#  ('Rrscht', 'NN'),
#  ('wie', 'IN'),
#  ('sprühte', 'NN'),
#  ('wie', 'IN'),
#  ('brannte', 'NN'),
#  ('es', 'PRP'),
#  ('Es', 'PRP'),
#  ('war', 'VB'),
#  ('eine', 'DT'),
#  ('warme', 'VB'),
#  ('helle', 'JJ'),
#  ('Flamme', 'NN'),
#  ('wie', 'IN'),
#  ('ein', 'DT'),
#  ('Lichtchen', 'VB'),
#  ('als', 'IN'),
#  ('sie', 'PRP'),
#  ('die', 'DT'),
#  ('Hände', 'NN'),
#  ('darüber', 'VB'),
#  ('hielt', 'RB'),
#  ('es', 'PRP'),
#  ('war', 'VB'),
#  ('ein', 'DT'),
#  ('wunderbares', 'JJ'),
#  ('Lichtchen', 'JJ'),
#  ('Es', 'PRP'),
#  ('schien', 'VB'),
#  ('wirklich', 'JJ'),
#  ('dem', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('als', 'IN'),
#  ('säße', 'JJ'),
#  ('sie', 'PRP'),
#  ('vor', 'IN'),
#  ('einem', 'DT'),
#  ('großen', 'VB'),
#  ('eisernen', 'JJ'),
#  ('Ofen', 'NN'),
#  ('mit', 'IN'),
#  ('polirten', 'NN'),
#  ('Messingfüßen', 'NN'),
#  ('und', 'CC'),
#  ('einem', 'DT'),
#  ('messingenen', 'JJ'),
#  ('Aufsatze', 'NN'),
#  ('Das', 'DT'),
#  ('Feuer', 'NN'),
#  ('brannte', 'NN'),
#  ('so', 'IN'),
#  ('gesegnet', 'NN'),
#  ('es', 'PRP'),
#  ('wärmte', 'NN'),
#  ('so', 'RB'),
#  ('schön', 'JJ'),
#  ('die', 'DT'),
#  ('Kleine', 'NN'),
#  ('streckte', 'VB'),
#  ('schon', 'RB'),
#  ('die', 'DT'),
#  ('Füße', 'NNS'),
#  ('aus', 'RP'),
#  ('um', 'IN'),
#  ('auch', 'RB'),
#  ('diese', 'DT'),
#  ('zu', 'TO'),
#  ('wärmen', 'VB'),
#  ('doch', 'RB'),
#  ('da', 'IN'),
#  ('erlosch', 'VB'),
#  ('das', 'DT'),
#  ('Flämmchen', 'NN'),
#  ('der', 'DT'),
#  ('Ofen', 'NN'),
#  ('verschwand', 'VB'),
#  ('sie', 'PRP'),
#  ('hatte', 'VB'),
#  ('nur', 'RB'),
#  ('die', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Ueberreste', 'NN'),
#  ('des', 'DT'),
#  ('abgebrannten', 'JJ'),
#  ('Schwefelhölzchens', 'NN'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Hand', 'NN'),
#  ('Ein', 'DT'),
#  ('zweites', 'VB'),
#  ('wurde', 'VB'),
#  ('an', 'IN'),
#  ('der', 'DT'),
#  ('Wand', 'NN'),
#  ('abgestrichen', 'JJ'),
#  ('es', 'PRP'),
#  ('leuchtete', 'NN'),
#  ('und', 'CC'),
#  ('wo', 'WRB'),
#  ('der', 'DT'),
#  ('Schein', 'NN'),
#  ('auf', 'IN'),
#  ('die', 'DT'),
#  ('Mauer', 'NN'),
#  ('fiel', 'VB'),
#  ('wurde', 'VB'),
#  ('diese', 'WDT'),
#  ('durchsichtig', 'JJ'),
#  ('wie', 'IN'),
#  ('ein', 'DT'),
#  ('Schleier', 'NN'),
#  ('sie', 'PRP'),
#  ('konnte', 'VB'),
#  ('in', 'IN'),
#  ('das', 'DT'),
#  ('Zimmer', 'JJ'),
#  ('hineinsehen', 'NN'),
#  ('Auf', 'IN'),
#  ('dem', 'DT'),
#  ('Tische', 'JJ'),
#  ('war', 'VB'),
#  ('ein', 'DT'),
#  ('schneeweißes', 'NN'),
#  ('Tischtuch', 'NN'),
#  ('ausgebreitet', 'NN'),
#  ('darauf', 'RB'),
#  ('stand', 'VB'),
#  ('glänzendes', 'NN'),
#  ('Porzellangeschirr', 'NN'),
#  ('und', 'CC'),
#  ('herrlich', 'JJ'),
#  ('dampfte', 'VB'),
#  ('die', 'DT'),
#  ('gebratene', 'NN'),
#  ('Gans', 'NN'),
#  ('mit', 'IN'),
#  ('Aepfeln', 'NN'),
#  ('und', 'CC'),
#  ('getrockneten', 'NN'),
#  ('Pflaumen', 'NN'),
#  ('gefüllt', 'RP'),
#  ('Und', 'CC'),
#  ('was', 'WP'),
#  ('noch', 'RB'),
#  ('prächtiger', 'NNP'),
#  ('anzusehen', 'VB'),
#  ('war', 'VB'),
#  ('die', 'DT'),
#  ('Gans', 'JJ'),
#  ('hüpfte', 'NN'),
#  ('von', 'IN'),
#  ('der', 'DT'),
#  ('Schüssel', 'NN'),
#  ('herunter', 'NNP'),
#  ('und', 'CC'),
#  ('wackelte', 'NNP'),
#  ('auf', 'IN'),
#  ('dem', 'DT'),
#  ('Fußboden', 'NN'),
#  ('Messer', 'NN'),
#  ('und', 'CC'),
#  ('Gabel', 'NN'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('Brust', 'NN'),
#  ('bis', 'IN'),
#  ('zu', 'IN'),
#  ('dem', 'DT'),
#  ('armen', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('hin', 'IN'),
#  ('Da', 'IN'),
#  ('erlosch', 'VB'),
#  ('das', 'DT'),
#  ('Schwefelhölzchen', 'VB'),
#  ('und', 'CC'),
#  ('es', 'PRP'),
#  ('blieb', 'NN'),
#  ('nur', 'RB'),
#  ('die', 'DT'),
#  ('dicke', 'NN'),
#  ('feuchtkalte', 'NN'),
#  ('Mauer', 'NNP'),
#  ('zurück', 'RP'),
#  ('Sie', 'PRP'),
#  ('zündete', 'NN'),
#  ('noch', 'RB'),
#  ('ein', 'DT'),
#  ('Hölzchen', 'JJ'),
#  ('an', 'RP'),
#  ('Da', 'IN'),
#  ('saß', 'VB'),
#  ('sie', 'PRP'),
#  ('nun', 'RB'),
#  ('unter', 'IN'),
#  ('dem', 'DT'),
#  ('herrlichsten', 'NN'),
#  ('Christbaume', 'NN'),
#  ('er', 'PRP'),
#  ('war', 'VB'),
#  ('noch', 'RB'),
#  ('größer', 'JJ'),
#  ('und', 'CC'),
#  ('geputzter', 'NN'),
#  ('als', 'IN'),
#  ('der', 'DT'),
#  ('den', 'WDT'),
#  ('sie', 'PRP'),
#  ('durch', 'IN'),
#  ('die', 'DT'),
#  ('Glasthüre', 'NN'),
#  ('bei', 'IN'),
#  ('dem', 'DT'),
#  ('reichen', 'PRP$'),
#  ('Kaufmanne', 'NN'),
#  ('gesehen', 'VB'),
#  ('hatte', 'VB'),
#  ('Tausende', 'NNS'),
#  ('von', 'IN'),
#  ('Lichterchen', 'JJ'),
#  ('brannten', 'NN'),
#  ('auf', 'IN'),
#  ('den', 'DT'),
#  ('grünen', 'PRP$'),
#  ('Zweigen', 'NN'),
#  ('und', 'CC'),
#  ('bunte', 'JJ'),
#  ('Bilder', 'NN'),
#  ('wie', 'IN'),
#  ('sie', 'JJ'),
#  ('an', 'IN'),
#  ('Schaufenstern', 'NN'),
#  ('zu', 'TO'),
#  ('sehen', 'VB'),
#  ('waren', 'VB'),
#  ('blickten', 'RB'),
#  ('auf', 'IN'),
#  ('sie', 'PRP'),
#  ('herab', 'NN'),
#  ('Die', 'DT'),
#  ('Kleine', 'NN'),
#  ('streckte', 'VB'),
#  ('ihre', 'PRP$'),
#  ('Hände', 'NN'),
#  ('danach', 'VB'),
#  ('aus', 'RP'),
#  ('da', 'RB'),
#  ('erlosch', 'VB'),
#  ('das', 'DT'),
#  ('Schwefelhölzchen', 'RB'),
#  ('Die', 'DT'),
#  ('Weihnachtslichter', 'NN'),
#  ('stiegen', 'NN'),
#  ('höher', 'JJ'),
#  ('und', 'CC'),
#  ('höher', 'JJ'),
#  ('sie', 'PRP'),
#  ('sah', 'VB'),
#  ('sie', 'PRP'),
#  ('jetzt', 'RB'),
#  ('als', 'IN'),
#  ('Sterne', 'NNS'),
#  ('am', 'IN'),
#  ('Himmel', 'NN'),
#  ('einer', 'DT'),
#  ('davon', 'RB'),
#  ('fiel', 'VB'),
#  ('herunter', 'NNP'),
#  ('und', 'CC'),
#  ('bildete', 'VB'),
#  ('einen', 'DT'),
#  ('langen', 'JJ'),
#  ('Feuerstreifen', 'NN'),
#  ('``', 'NN'),
#  ('Jetzt', 'NN'),
#  ('stirbt', 'VB'),
#  ('Jemand', 'RB'),
#  ("''", 'NN'),
#  ('dachte', 'VB'),
#  ('das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('denn', 'RB'),
#  ('ihre', 'PRP$'),
#  ('alte', 'JJ'),
#  ('Großmutter', 'NN'),
#  ('die', 'DT'),
#  ('Einzige', 'NN'),
#  ('die', 'WDT'),
#  ('sie', 'PRP'),
#  ('lieb', 'JJ'),
#  ('gehabt', 'NN'),
#  ('hatte', 'VB'),
#  ('und', 'CC'),
#  ('die', 'DT'),
#  ('jetzt', 'RB'),
#  ('gestorben', 'VBN'),
#  ('war', 'VB'),
#  ('hatte', 'VB'),
#  ('ihr', 'PRP'),
#  ('erzählt', 'VBN'),
#  ('daß', 'IN'),
#  ('wenn', 'IN'),
#  ('ein', 'DT'),
#  ('Stern', 'NN'),
#  ('herunterfällt', 'NN'),
#  ('eine', 'DT'),
#  ('Seele', 'NN'),
#  ('zu', 'IN'),
#  ('Gott', 'NN'),
#  ('emporsteigt', 'RP'),
#  ('Sie', 'PRP'),
#  ('strich', 'NNP'),
#  ('wieder', 'RB'),
#  ('ein', 'DT'),
#  ('Hölzchen', 'JJ'),
#  ('an', 'IN'),
#  ('der', 'DT'),
#  ('Mauer', 'NN'),
#  ('ab', 'RP'),
#  ('es', 'PRP'),
#  ('wurde', 'VB'),
#  ('wieder', 'RB'),
#  ('hell', 'JJ'),
#  ('und', 'CC'),
#  ('in', 'IN'),
#  ('dem', 'DT'),
#  ('Glanze', 'NN'),
#  ('stand', 'VB'),
#  ('die', 'DT'),
#  ('alte', 'JJ'),
#  ('Großmutter', 'NN'),
#  ('so', 'RB'),
#  ('klar', 'JJ'),
#  ('und', 'CC'),
#  ('schimmernd', 'NN'),
#  ('so', 'RB'),
#  ('mild', 'JJ'),
#  ('und', 'CC'),
#  ('liebevoll', 'JJ'),
#  ('``', 'NN'),
#  ('Großmutter', 'NN'),
#  ("''", 'NN'),
#  ('rief', 'VB'),
#  ('die', 'DT'),
#  ('Kleine', 'NN'),
#  ('``', 'NN'),
#  ('O', 'NN'),
#  ('nimm', 'NN'),
#  ('mich', 'PRP'),
#  ('mit', 'IN'),
#  ('Ich', 'PRP'),
#  ('weiß', 'VB'),
#  ('Du', 'NN'),
#  ('entfernst', 'NNP'),
#  ('Dich', 'NNP'),
#  ('wenn', 'IN'),
#  ('das', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('erlischt', 'VB'),
#  ('Du', 'NN'),
#  ('verschwindest', 'VB'),
#  ('wie', 'IN'),
#  ('der', 'DT'),
#  ('warme', 'JJ'),
#  ('Ofen', 'NN'),
#  ('wie', 'IN'),
#  ('der', 'DT'),
#  ('herrliche', 'JJ'),
#  ('Gänsebraten', 'NN'),
#  ('und', 'CC'),
#  ('der', 'DT'),
#  ('große', 'VB'),
#  ('prächtige', 'NN'),
#  ('Weihnachtsbaum', 'NNP'),
#  ("''", 'NN'),
#  ('Und', 'RB'),
#  ('sie', 'PRP'),
#  ('strich', 'NNP'),
#  ('schnell', 'JJ'),
#  ('das', 'DT'),
#  ('ganze', 'JJ'),
#  ('Bund', 'NN'),
#  ('Schwefelhölzchen', 'VB'),
#  ('denn', 'WRB'),
#  ('sie', 'PRP'),
#  ('wollte', 'MD'),
#  ('die', 'DT'),
#  ('Großmutter', 'NN'),
#  ('recht', 'VB'),
#  ('fest', 'JJ'),
#  ('halten', 'VB'),
#  ('Und', 'CC'),
#  ('die', 'DT'),
#  ('Schwefelhölzchen', 'JJ'),
#  ('leuchteten', 'NN'),
#  ('mit', 'IN'),
#  ('einem', 'DT'),
#  ('solchen', 'DT'),
#  ('Glanze', 'NN'),
#  ('daß', 'IN'),
#  ('es', 'JJ'),
#  ('heller', 'VB'),
#  ('wurde', 'VB'),
#  ('als', 'IN'),
#  ('mitten', 'RB'),
#  ('am', 'IN'),
#  ('Tage', 'NN'),
#  ('die', 'DT'),
#  ('Großmutter', 'NN'),
#  ('war', 'VB'),
#  ('nie', 'RB'),
#  ('früher', 'RB'),
#  ('so', 'RB'),
#  ('schön', 'JJ'),
#  ('so', 'RB'),
#  ('groß', 'JJ'),
#  ('gewesen', 'VBN'),
#  ('sie', 'PRP'),
#  ('nahm', 'VB'),
#  ('das', 'DT'),
#  ('kleine', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('auf', 'IN'),
#  ('ihre', 'PRP$'),
#  ('Arme', 'NNS'),
#  ('und', 'CC'),
#  ('Beide', 'DT'),
#  ('flogen', 'VB'),
#  ('in', 'IN'),
#  ('Glanz', 'NN'),
#  ('und', 'CC'),
#  ('Freude', 'NN'),
#  ('so', 'RB'),
#  ('hoch', 'JJ'),
#  ('so', 'RB'),
#  ('hoch', 'JJ'),
#  ('und', 'CC'),
#  ('dort', 'RB'),
#  ('war', 'VB'),
#  ('weder', 'CC'),
#  ('Kälte', 'NN'),
#  ('noch', 'IN'),
#  ('Hunger', 'NN'),
#  ('noch', 'IN'),
#  ('Angst', 'NN'),
#  ('sie', 'PRP'),
#  ('waren', 'VB'),
#  ('bei', 'IN'),
#  ('Gott', 'NN'),
#  ('Aber', 'CC'),
#  ('im', 'IN'),
#  ('Winkel', 'NN'),
#  ('an', 'IN'),
#  ('die', 'DT'),
#  ('Mauer', 'NN'),
#  ('gelehnt', 'VB'),
#  ('saß', 'RB'),
#  ('in', 'IN'),
#  ('der', 'DT'),
#  ('kalten', 'JJ'),
#  ('Morgenstunde', 'NN'),
#  ('das', 'DT'),
#  ('arme', 'JJ'),
#  ('Mädchen', 'NN'),
#  ('mit', 'IN'),
#  ('rothen', 'NN'),
#  ('Backen', 'NN'),
#  ('und', 'CC'),
#  ('mit', 'IN'),
#  ('lächelndem', 'RB'),
#  ('Munde', 'NN'),
#  ('erfroren', 'NN'),
#  ('an', 'IN'),
#  ('des', 'DT'),
#  ('alten', 'JJ'),
#  ('Jahres', 'NN'),
#  ('letztem', 'JJ'),
#  ('Abend', 'NN'),
#  ('Die', 'DT'),
#  ('Neujahrssonne', 'NN'),
#  ('ging', 'VB'),
#  ('auf', 'IN'),
#  ('über', 'IN'),
#  ('der', 'DT'),
#  ('kleinen', 'JJ'),
#  ('Leiche', 'NN'),
#  ('Starr', 'JJ'),
#  ('saß', 'VB'),
#  ('das', 'DT'),
#  ('Kind', 'NN'),
#  ('dort', 'RB'),
#  ('mit', 'IN'),
#  ('den', 'DT'),
#  ('Schwefelhölzchen', 'VB'),
#  ('von', 'IN'),
#  ('denen', 'WDT'),
#  ('ein', 'DT'),
#  ('Bund', 'NN'),
#  ('abgebrannt', 'NN'),
#  ('war', 'VB'),
#  ('``', 'NN'),
#  ('Sie', 'PRP'),
#  ('hat', 'VB'),
#  ('sich', 'PRP'),
#  ('erwärmen', 'VB'),
#  ('wollen', 'MD'),
#  ("''", 'NN'),
#  ('sagte', 'VB'),
#  ('man', 'DT'),
#  ('Niemand', 'NN'),
#  ('ahnte', 'NN'),
#  ('was', 'WDT'),
#  ('sie', 'PRP'),
#  ('Schönes', 'NN'),
#  ('gesehen', 'VBN'),
#  ('hatte', 'VB'),
#  ('in', 'IN'),
#  ('welchem', 'WP'),
#  ('Glanze', 'NN'),
#  ('sie', 'PRP'),
#  ('mit', 'IN'),
#  ('der', 'DT'),
#  ('Großmutter', 'NN'),
#  ('zur', 'IN'),
#  ('Neujahrsfreude', 'NN'),
#  ('eingegangen', 'VBN'),
#  ('war', 'VB'),
#  ('Hans', 'NNP'),
#  ('Christian', 'NNP'),
#  ('Andersen', 'NNP'),
#  ('1805-1875', 'CD')]

# %%
substantive = []
blob = TextBlobDE(maerchen, parser=PatternParser(pprint=False, lemmata=True))     ## mit text, nicht liste
for word in blob.tags:
    if "NN" in word[1]:
        substantive.append(word[0])

# %%
substantive
# Out:
# ['Hans',
#  'Christian',
#  'Andersen',
#  'Märchen',
#  'Mädchen',
#  'schneite',
#  'Abend',
#  'Abend',
#  'Jahres',
#  'Kälte',
#  'Finsterniß',
#  'Straße',
#  'Mädchen',
#  'bloßem',
#  'Kopfe',
#  'Füßen',
#  'Haus',
#  'verließ',
#  'Pantoffeln',
#  'angehabt',
#  'Pantoffeln',
#  'Mutter',
#  'Kleine',
#  'verlor',
#  'Straße',
#  'huschte',
#  'Wagen',
#  'vorüberrollten',
#  'Pantoffel',
#  'Junge',
#  'erwischt',
#  'Wiege',
#  'Kinder',
#  'Mädchen',
#  'Füßen',
#  'Kälte',
#  'Schürze',
#  'trug',
#  'Menge',
#  'Schwefelhölzer',
#  'Bund',
#  'Hand',
#  'Niemand',
#  'Tag',
#  'abgekauft',
#  'Niemand',
#  'Pfennig',
#  'Zitternd',
#  'Kälte',
#  'Hunger',
#  'einher',
#  'Bild',
#  'Jammers',
#  'arme',
#  'Kleine',
#  'Schneeflocken',
#  'bedeckten',
#  'langes',
#  'Haar',
#  'Locken',
#  'Hals',
#  'Fenstern',
#  'glänzten',
#  'Gänsebraten',
#  'Ja',
#  'Winkel',
#  'Häusern',
#  'vorsprang',
#  'Füße',
#  'fror',
#  'Hause',
#  'wagte',
#  'Geld',
#  'Vater',
#  'gewiß',
#  'Schläge',
#  'Hause',
#  'Dach',
#  'Wind',
#  'pfiff',
#  'Spalten',
#  'Stroh',
#  'Lumpen',
#  'zugestopft',
#  'Hände',
#  'erstarrt',
#  'Ach',
#  'einziges',
#  'Bunde',
#  'herausziehen',
#  'Wand',
#  'Finger',
#  'Rrscht',
#  'sprühte',
#  'brannte',
#  'Flamme',
#  'Hände',
#  'Mädchen',
#  'Ofen',
#  'polirten',
#  'Messingfüßen',
#  'Aufsatze',
#  'Feuer',
#  'brannte',
#  'gesegnet',
#  'wärmte',
#  'Kleine',
#  'Füße',
#  'Flämmchen',
#  'Ofen',
#  'Ueberreste',
#  'Schwefelhölzchens',
#  'Hand',
#  'Wand',
#  'leuchtete',
#  'Schein',
#  'Mauer',
#  'Schleier',
#  'hineinsehen',
#  'schneeweißes',
#  'Tischtuch',
#  'ausgebreitet',
#  'glänzendes',
#  'Porzellangeschirr',
#  'gebratene',
#  'Gans',
#  'Aepfeln',
#  'getrockneten',
#  'Pflaumen',
#  'prächtiger',
#  'hüpfte',
#  'Schüssel',
#  'herunter',
#  'wackelte',
#  'Fußboden',
#  'Messer',
#  'Gabel',
#  'Brust',
#  'Mädchen',
#  'blieb',
#  'dicke',
#  'feuchtkalte',
#  'Mauer',
#  'zündete',
#  'herrlichsten',
#  'Christbaume',
#  'geputzter',
#  'Glasthüre',
#  'Kaufmanne',
#  'Tausende',
#  'brannten',
#  'Zweigen',
#  'Bilder',
#  'Schaufenstern',
#  'herab',
#  'Kleine',
#  'Hände',
#  'Weihnachtslichter',
#  'stiegen',
#  'Sterne',
#  'Himmel',
#  'herunter',
#  'Feuerstreifen',
#  '``',
#  'Jetzt',
#  "''",
#  'Mädchen',
#  'Großmutter',
#  'Einzige',
#  'gehabt',
#  'Stern',
#  'herunterfällt',
#  'Seele',
#  'Gott',
#  'strich',
#  'Mauer',
#  'Glanze',
#  'Großmutter',
#  'schimmernd',
#  '``',
#  'Großmutter',
#  "''",
#  'Kleine',
#  '``',
#  'O',
#  'nimm',
#  'Du',
#  'entfernst',
#  'Dich',
#  'Du',
#  'Ofen',
#  'Gänsebraten',
#  'prächtige',
#  'Weihnachtsbaum',
#  "''",
#  'strich',
#  'Bund',
#  'Großmutter',
#  'leuchteten',
#  'Glanze',
#  'Tage',
#  'Großmutter',
#  'Mädchen',
#  'Arme',
#  'Glanz',
#  'Freude',
#  'Kälte',
#  'Hunger',
#  'Angst',
#  'Gott',
#  'Winkel',
#  'Mauer',
#  'Morgenstunde',
#  'Mädchen',
#  'rothen',
#  'Backen',
#  'Munde',
#  'erfroren',
#  'Jahres',
#  'Abend',
#  'Neujahrssonne',
#  'Leiche',
#  'Kind',
#  'Bund',
#  'abgebrannt',
#  '``',
#  "''",
#  'Niemand',
#  'ahnte',
#  'Schönes',
#  'Glanze',
#  'Großmutter',
#  'Neujahrsfreude',
#  'Hans',
#  'Christian',
#  'Andersen']

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/pc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
mylist = stopwords.words('german')
mylist
# Out:
# ['aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'also',
#  'am',
#  'an',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'der',
#  'den',
#  'des',
#  'dem',
#  'die',
#  'das',
#  'dass',
#  'daß',
#  'derselbe',
#  'derselben',
#  'denselben',
#  'desselben',
#  'demselben',
#  'dieselbe',
#  'dieselben',
#  'dasselbe',
#  'dazu',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'denn',
#  'derer',
#  'dessen',
#  'dich',
#  'dir',
#  'du',
#  'dies',
#  'diese',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'doch',
#  'dort',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einiges',
#  'einmal',
#  'er',
#  'ihn',
#  'ihm',
#  'es',
#  'etwas',
#  'euer',
#  'eure',
#  'eurem',
#  'euren',
#  'eurer',
#  'eures',
#  'für',
#  'gegen',
#  'gewesen',
#  'hab',
#  'habe',
#  'haben',
#  'hat',
#  'hatte',
#  'hatten',
#  'hier',
#  'hin',
#  'hinter',
#  'ich',
#  'mich',
#  'mir',
#  'ihr',
#  'ihre',
#  'ihrem',
#  'ihren',
#  'ihrer',
#  'ihres',
#  'euch',
#  'im',
#  'in',
#  'indem',
#  'ins',
#  'ist',
#  'jede',
#  'jedem',
#  'jeden',
#  'jeder',
#  'jedes',
#  'jene',
#  'jenem',
#  'jenen',
#  'jener',
#  'jenes',
#  'jetzt',
#  'kann',
#  'kein',
#  'keine',
#  'keinem',
#  'keinen',
#  'keiner',
#  'keines',
#  'können',
#  'könnte',
#  'machen',
#  'man',
#  'manche',
#  'manchem',
#  'manchen',
#  'mancher',
#  'manches',
#  'mein',
#  'meine',
#  'meinem',
#  'meinen',
#  'meiner',
#  'meines',
#  'mit',
#  'muss',
#  'musste',
#  'nach',
#  'nicht',
#  'nichts',
#  'noch',
#  'nun',
#  'nur',
#  'ob',
#  'oder',
#  'ohne',
#  'sehr',
#  'sein',
#  'seine',
#  'seinem',
#  'seinen',
#  'seiner',
#  'seines',
#  'selbst',
#  'sich',
#  'sie',
#  'ihnen',
#  'sind',
#  'so',
#  'solche',
#  'solchem',
#  'solchen',
#  'solcher',
#  'solches',
#  'soll',
#  'sollte',
#  'sondern',
#  'sonst',
#  'über',
#  'um',
#  'und',
#  'uns',
#  'unsere',
#  'unserem',
#  'unseren',
#  'unser',
#  'unseres',
#  'unter',
#  'viel',
#  'vom',
#  'von',
#  'vor',
#  'während',
#  'war',
#  'waren',
#  'warst',
#  'was',
#  'weg',
#  'weil',
#  'weiter',
#  'welche',
#  'welchem',
#  'welchen',
#  'welcher',
#  'welches',
#  'wenn',
#  'werde',
#  'werden',
#  'wie',
#  'wieder',
#  'will',
#  'wir',
#  'wird',
#  'wirst',
#  'wo',
#  'wollen',
#  'wollte',
#  'würde',
#  'würden',
#  'zu',
#  'zum',
#  'zur',
#  'zwar',
#  'zwischen']

# %%
from nltk.corpus import stopwords
#words_alpha =[word.lower() for word in clean_blob if word.isalpha()]
words_alpha =[word for word in clean_blob if word.isalpha()]

stopwords = stopwords.words('german')
stopwords.append("e")
stopwords.append("de")
stopwords.append("al")
stopwords.append("wa")
#stopwords.append("rasch")

result = [word for word in words_alpha if word not in stopwords]
result[0:100]
# Out:
# ['Hans',
#  'Christian',
#  'Andersen',
#  'Sämmtliche',
#  'Märchen',
#  'Das',
#  'kleine',
#  'Mädchen',
#  'Schwefelhölzchen',
#  'Es',
#  'entsetzlich',
#  'kalt',
#  'schneite',
#  'beinahe',
#  'schon',
#  'ganz',
#  'dunkel',
#  'Abend',
#  'letzte',
#  'Abend',
#  'Jahres',
#  'In',
#  'Kälte',
#  'Finsterniß',
#  'ging',
#  'Straße',
#  'kleines',
#  'armes',
#  'Mädchen',
#  'bloßem',
#  'Kopfe',
#  'nackten',
#  'Füßen',
#  'Als',
#  'Haus',
#  'verließ',
#  'freilich',
#  'Pantoffeln',
#  'angehabt',
#  'half',
#  'Es',
#  'große',
#  'Pantoffeln',
#  'Mutter',
#  'bisher',
#  'benutzt',
#  'groß',
#  'Die',
#  'Kleine',
#  'verlor',
#  'Straße',
#  'huschte',
#  'zwei',
#  'Wagen',
#  'schrecklich',
#  'schnell',
#  'vorüberrollten',
#  'Der',
#  'Pantoffel',
#  'finden',
#  'Junge',
#  'erwischt',
#  'lief',
#  'fort',
#  'meinte',
#  'könne',
#  'recht',
#  'gut',
#  'Wiege',
#  'benutzen',
#  'erst',
#  'Kinder',
#  'hätte',
#  'Da',
#  'ging',
#  'kleine',
#  'Mädchen',
#  'kleinen',
#  'nackten',
#  'Füßen',
#  'ganz',
#  'rot',
#  'blau',
#  'Kälte',
#  'In',
#  'alten',
#  'Schürze',
#  'trug',
#  'Menge',
#  'Schwefelhölzer',
#  'Bund',
#  'davon',
#  'Hand',
#  'Niemand',
#  'ganzen',
#  'langen',
#  'Tag',
#  'abgekauft',
#  'Niemand',
#  'Pfennig']

# %%
textfuerbild = (" ").join(result)

# %%
textfuerbild
# Out:
# 'Hans Christian Andersen Sämmtliche Märchen Das kleine Mädchen Schwefelhölzchen Es entsetzlich kalt schneite beinahe schon ganz dunkel Abend letzte Abend Jahres In Kälte Finsterniß ging Straße kleines armes Mädchen bloßem Kopfe nackten Füßen Als Haus verließ freilich Pantoffeln angehabt half Es große Pantoffeln Mutter bisher benutzt groß Die Kleine verlor Straße huschte zwei Wagen schrecklich schnell vorüberrollten Der Pantoffel finden Junge erwischt lief fort meinte könne recht gut Wiege benutzen erst Kinder hätte Da ging kleine Mädchen kleinen nackten Füßen ganz rot blau Kälte In alten Schürze trug Menge Schwefelhölzer Bund davon Hand Niemand ganzen langen Tag abgekauft Niemand Pfennig geschenkt Zitternd Kälte Hunger schlich einher Bild Jammers arme Kleine Die Schneeflocken bedeckten lange blonde Haar schönen Locken Hals fiel daran dachte freilich Aus Fenstern glänzten Lichter roch ganz herrlich Gänsebraten ja Sylvesterabend Ja daran dachte In Winkel zwei Häusern gebildet denen mehr vorsprang setzte kauerte zusammen Die kleinen Füße gezogen fror mehr Hause gehen wagte ja Schwefelhölzchen verkauft brachte Pfennig Geld Von Vater gewiß Schläge bekommen Hause kalt Dach Wind pfiff größten Spalten Stroh Lumpen zugestopft Ihre kleinen Hände beinahe Kälte erstarrt Ach Schwefelhölzchen konnte gar wohl thun einziges au Bunde herausziehen Wand streichen Finger erwärmen dürfte Sie zog eins heraus Rrscht sprühte brannte Es warme helle Flamme Lichtchen Hände darüber hielt wunderbares Lichtchen Es schien wirklich kleinen Mädchen säße großen eisernen Ofen polirten Messingfüßen messingenen Aufsatze Das Feuer brannte gesegnet wärmte schön Kleine streckte schon Füße au wärmen erlosch Flämmchen Ofen verschwand kleinen Ueberreste abgebrannten Schwefelhölzchens Hand Ein zweites wurde Wand abgestrichen leuchtete Schein Mauer fiel wurde durchsichtig Schleier konnte Zimmer hineinsehen Auf Tische schneeweißes Tischtuch ausgebreitet darauf stand glänzendes Porzellangeschirr herrlich dampfte gebratene Gans Aepfeln getrockneten Pflaumen gefüllt Und prächtiger anzusehen Gans hüpfte Schüssel herunter wackelte Fußboden Messer Gabel Brust bi armen Mädchen Da erlosch Schwefelhölzchen blieb dicke feuchtkalte Mauer zurück Sie zündete Hölzchen Da saß herrlichsten Christbaume größer geputzter Glasthüre reichen Kaufmanne gesehen Tausende Lichterchen brannten grünen Zweigen bunte Bilder Schaufenstern sehen blickten herab Die Kleine streckte Hände danach au erlosch Schwefelhölzchen Die Weihnachtslichter stiegen höher höher sah Sterne Himmel davon fiel herunter bildete langen Feuerstreifen Jetzt stirbt Jemand dachte kleine Mädchen alte Großmutter Einzige lieb gehabt gestorben erzählt Stern herunterfällt Seele Gott emporsteigt Sie strich Hölzchen Mauer ab wurde hell Glanze stand alte Großmutter klar schimmernd mild liebevoll Großmutter rief Kleine O nimm Ich weiß Du entfernst Dich Schwefelhölzchen erlischt Du verschwindest warme Ofen herrliche Gänsebraten große prächtige Weihnachtsbaum Und strich schnell ganze Bund Schwefelhölzchen Großmutter recht fest halten Und Schwefelhölzchen leuchteten Glanze heller wurde mitten Tage Großmutter nie früher schön groß nahm kleine Mädchen Arme Beide flogen Glanz Freude hoch hoch weder Kälte Hunger Angst Gott Aber Winkel Mauer gelehnt saß kalten Morgenstunde arme Mädchen rothen Backen lächelndem Munde erfroren alten Jahres letztem Abend Die Neujahrssonne ging kleinen Leiche Starr saß Kind Schwefelhölzchen denen Bund abgebrannt Sie erwärmen sagte Niemand ahnte Schönes gesehen Glanze Großmutter Neujahrsfreude eingegangen Hans Christian Andersen'

# %%
# %matplotlib inline
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
from os import path
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

maske = np.array(Image.open(path.join(d, "maske.png")))

wc = WordCloud(background_color="white", max_words=2000, mask=maske, contour_width=1, contour_color='black',collocations=False, normalize_plurals=False)
wc.generate(textfuerbild)
plt.figure(figsize=(20,20))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
#plt.savefig("test.png")

# %% [markdown]
# # Bilddatei abspeichern

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(range(10))
fig.savefig(‘temp.png’, dpi=fig.dpi)
